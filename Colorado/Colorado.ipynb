# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from textblob import TextBlob
from scipy import stats
import folium as folium
from IPython.display import display
import geopandas as gpd
from shapely.geometry import Point
import contextily as ctx

# %% [markdown]
# ### Lectura del archivo Massachusetts.json

# %%
df= pd.read_json(r"C:\Users\jessi\Desktop\Horizon_Project\Massachusetts\Massachusetts.json",lines=True)

# %%
df.head()
# Out:
#         user_id                name  rating  \
# 0  1.127958e+20                 S C       1
# 1  1.169626e+20    Khodour Al Kadry       1
# 2  1.135448e+20  Ignacio Cetrangolo       1
# 3  1.104995e+20     pablo rodriguez       5
# 4  1.166612e+20         Misa Torres       3
#
#                                                 text  resp  \
# 0  I think this business is gone, now it's anothe...  None
# 1  If I can give this place a 0 I would have done...  None
# 2  I wish I could rate this 0/5 stars. Honestly t...  None
# 3  Ir you love dim sum like I do. This is your pl...  None
# 4  The food was salty and the portions were small...  None
#
#                                  gmap_id
# 0  0x89e465c09b874879:0xd318f9cc0b6b39a6
# 1  0x89e465c09b874879:0xd318f9cc0b6b39a6
# 2  0x89e465c09b874879:0xd318f9cc0b6b39a6
# 3  0x89e465c09b874879:0xd318f9cc0b6b39a6
# 4  0x89e465c09b874879:0xd318f9cc0b6b39a6

# %% [markdown]
# ### Lectura del archivo "df_gastronomico_ciudades.json "

# %%
df2=pd.read_json(r"C:\Users\jessi\Desktop\Horizon_Project\Washington\df_gastronomico_ciudades.json",lines=True)

# %%
df2.head()
# Out:
#                            nombre_local                     direccion  \
# 0  Creole Orleans Catering & Food Truck  2841 Greenbriar Pkwy SW N317
# 1               Biswas Grocery and Cafe            2853 Buford Hwy NE
# 2                           Noodle Cafe        233 Peachtree St # B70
# 3  Creole Orleans Catering & Food Truck  2841 Greenbriar Pkwy SW N317
# 4               Biswas Grocery and Cafe            2853 Buford Hwy NE
#
#     ciudad codigo_postal_cod_ciudad codigo_ciudad codigo_postal  \
# 0  Atlanta                 GA 30331            GA         30331
# 1  Atlanta                 GA 30329            GA         30329
# 2  Atlanta                 GA 30303            GA         30303
# 3  Atlanta                 GA 30331            GA         30331
# 4  Atlanta                 GA 30329            GA         30329
#
#                                  gmap_id   latitude  longitude  \
# 0  0x88f503d71429c049:0xef40e07a5479b1c2  33.689032 -84.495097
# 1  0x88f507f3e1cde31d:0x1bcd2bb2f0555399  33.831454 -84.341647
# 2  0x88f5047831dfc86d:0x985e3a6645f5ca4f  33.760404 -84.386319
# 3  0x88f503d71429c049:0xef40e07a5479b1c2  33.689032 -84.495097
# 4  0x88f507f3e1cde31d:0x1bcd2bb2f0555399  33.831454 -84.341647
#
#                                             category  avg_rating  \
# 0  [Creole restaurant, Caribbean restaurant, Cate...         4.7
# 1  [Organic food store, Convenience store, Phone ...         4.7
# 2                      [Thai restaurant, Restaurant]         4.2
# 3  [Creole restaurant, Caribbean restaurant, Cate...         4.7
# 4  [Organic food store, Convenience store, Phone ...         4.7
#
#    num_of_reviews price                                               MISC
# 0              31  None  {'Service options': ['Delivery', 'Takeout', 'D...
# 1              25  None  {'Service options': ['Delivery', 'In-store sho...
# 2              35  None  {'Service options': ['Takeout', 'Dine-in', 'De...
# 3              31  None  {'Service options': ['Delivery', 'Takeout', 'D...
# 4              25  None  {'Service options': ['Delivery', 'In-store sho...

# %% [markdown]
# ### Informacion General

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3281 entries, 0 to 3280
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   user_id  3281 non-null   float64
#  1   name     3281 non-null   object
#  2   rating   3281 non-null   int64
#  3   text     1831 non-null   object
#  4   resp     135 non-null    object
#  5   gmap_id  3281 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 153.9+ KB
# None

# %%
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18037 entries, 0 to 18036
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   nombre_local              18037 non-null  object
#  1   direccion                 18037 non-null  object
#  2   ciudad                    18037 non-null  object
#  3   codigo_postal_cod_ciudad  18037 non-null  object
#  4   codigo_ciudad             18037 non-null  object
#  5   codigo_postal             18037 non-null  object
#  6   gmap_id                   18037 non-null  object
#  7   latitude                  18037 non-null  float64
#  8   longitude                 18037 non-null  float64
#  9   category                  18037 non-null  object
#  10  avg_rating                18037 non-null  float64
#  11  num_of_reviews            18037 non-null  int64
#  12  price                     8690 non-null   object
#  13  MISC                      17614 non-null  object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 1.9+ MB
# None

# %% [markdown]
# ### Descripción de los dataframe

# %%
df['rating'].describe()
# Out:
# count    3281.000000
# mean        4.017678
# std         1.262375
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         5.000000
# max         5.000000
# Name: rating, dtype: float64

# %%
df2.describe()
# Out:
#            latitude     longitude    avg_rating  num_of_reviews
# count  18037.000000  18037.000000  18037.000000    18037.000000
# mean      38.290007    -92.404179      4.137573       70.622276
# std        4.948144     18.621202      0.575608      143.090909
# min       25.993710   -122.805295      1.000000        1.000000
# 25%       34.055071   -118.186637      3.900000       17.000000
# 50%       39.943207    -86.808270      4.200000       38.000000
# 75%       40.831310    -74.145373      4.500000       78.000000
# max       47.682747    -71.145040      5.000000     5321.000000

# %% [markdown]
# ### Análisis de Datos Nulos

# %%
print(df.isnull().sum())
# Out:
# user_id       0
# name          0
# rating        0
# text       1450
# resp       3146
# gmap_id       0
# dtype: int64

# %%
print(df2.isnull().sum())
# Out:
# nombre_local                   0
# direccion                      0
# ciudad                         0
# codigo_postal_cod_ciudad       0
# codigo_ciudad                  0
# codigo_postal                  0
# gmap_id                        0
# latitude                       0
# longitude                      0
# category                       0
# avg_rating                     0
# num_of_reviews                 0
# price                       9347
# MISC                         423
# dtype: int64

# %% [markdown]
# ### Outliers

# %%
rating = df['rating']

# Calcular el IQR para la columna 'rating'
Q1 = rating.quantile(0.25)
Q3 = rating.quantile(0.75)
IQR = Q3 - Q1

# Identificar outliers usando IQR
outliers_iqr = rating[(rating < (Q1 - 1.5 * IQR)) | (rating > (Q3 + 1.5 * IQR))]
print("Outliers en la columna 'rating' usando IQR:")
print(outliers_iqr)

# Calcular Z-score para la columna 'rating'
z_scores = stats.zscore(rating)
abs_z_scores = abs(z_scores)

# Identificar outliers con Z-score mayor que 3
outliers_z = rating[abs_z_scores > 3]
print("Outliers en la columna 'rating' usando Z-score:")
print(outliers_z)

# Graficar el boxplot para 'rating'
plt.figure(figsize=(10, 6))
sns.boxplot(x=rating)
plt.title('Boxplot de rating')
plt.show()
# Out:
# Outliers en la columna 'rating' usando IQR:
# Series([], Name: rating, dtype: int64)
# Outliers en la columna 'rating' usando Z-score:
# Series([], Name: rating, dtype: int64)

# %%
columns_to_check = ['avg_rating']

Q1 = df2[columns_to_check].quantile(0.25)
Q3 = df2[columns_to_check].quantile(0.75)
IQR = Q3 - Q1

outliers_iqr = df2[(df2[columns_to_check] < (Q1 - 1.5 * IQR)) | (df2[columns_to_check] > (Q3 + 1.5 * IQR))]

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.boxplot(x=df2['avg_rating'])
plt.title('Outliers de Average Rating')



plt.show()

# %%
num_of_reviews = df2['num_of_reviews']

Q1 = num_of_reviews.quantile(0.25)
Q3 = num_of_reviews.quantile(0.75)
IQR = Q3 - Q1

outliers_iqr = num_of_reviews[(num_of_reviews < (Q1 - 1.5 * IQR)) | (num_of_reviews > (Q3 + 1.5 * IQR))]
print("Outliers en la columna 'num_of_reviews' usando IQR:")
print(outliers_iqr)

z_scores = stats.zscore(num_of_reviews)
abs_z_scores = abs(z_scores)

outliers_z = num_of_reviews[abs_z_scores > 3]
print("Outliers en la columna 'num_of_reviews' usando Z-score:")
print(outliers_z)

plt.figure(figsize=(10, 6))
sns.boxplot(x=num_of_reviews)
plt.title('Outliers Número de Reviews')
plt.show()
# Out:
# Outliers en la columna 'num_of_reviews' usando IQR:
# 124      798
# 206      178
# 217      496
# 224      214
# 229      768
#         ...
# 18019    238
# 18024    244
# 18027    292
# 18029    178
# 18031    238
# Name: num_of_reviews, Length: 1371, dtype: int64
# Outliers en la columna 'num_of_reviews' usando Z-score:
# 124       798
# 229       768
# 233      1018
# 237      3128
# 238      1373
#          ...
# 17884     798
# 17890    1108
# 17892    1208
# 17893    1351
# 17901     624
# Name: num_of_reviews, Length: 171, dtype: int64

# %% [markdown]
# ### Histogramas de distribución

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['rating'], bins=10)
plt.title('Distribución de Raiting DF')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
avg_rating = df2['avg_rating']
num_of_reviews = df2['num_of_reviews']

plt.figure(figsize=(14, 12))

plt.subplot(2, 2, 1)
sns.histplot(avg_rating, bins=30, kde=False)
plt.title('Histograma de puntaje promedio')
plt.xlabel('avg_rating')
plt.ylabel('Frecuencia')

plt.subplot(2, 2, 3)
sns.histplot(num_of_reviews, bins=20, kde=False)
plt.title('Histograma de número de reviews')
plt.xlabel('num_of_reviews')
plt.ylabel('Frecuencia')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Análisis de sentimientos

# %%
df['text'] = df['text'].fillna('')

# %%
def get_sentiment(text):
    return TextBlob(text).sentiment.polarity

df['review_sentiment'] = df['text'].apply(get_sentiment)

print(df[['text', 'review_sentiment']].head())
# Out:
#                                                 text  review_sentiment
# 0  I think this business is gone, now it's anothe...          0.100617
# 1  If I can give this place a 0 I would have done...         -0.450000
# 2  I wish I could rate this 0/5 stars. Honestly t...         -0.100000
# 3  Ir you love dim sum like I do. This is your pl...          0.300000
# 4  The food was salty and the portions were small...         -0.125000

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.histplot(df['review_sentiment'], bins=10, kde=True)
plt.title('Distribución de Sentimientos en Reviews')
plt.xlabel('Sentimiento')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ### Unión de datasets

# %%
merged_df = pd.merge(df, df2, on='gmap_id', how='inner')

# %%
merged_df
# Out:
#            user_id                name  rating  \
# 0     1.127958e+20                 S C       1
# 1     1.169626e+20    Khodour Al Kadry       1
# 2     1.135448e+20  Ignacio Cetrangolo       1
# 3     1.104995e+20     pablo rodriguez       5
# 4     1.166612e+20         Misa Torres       3
# ...            ...                 ...     ...
# 3276  1.075418e+20         Judy Cahill       5
# 3277  1.146438e+20       Robert Ingram       4
# 3278  1.172860e+20        Jack Sheehan       5
# 3279  1.033326e+20    Anthony McKinney       5
# 3280  1.059178e+20       khuong nguyen       5
#
#                                                    text  resp  \
# 0     I think this business is gone, now it's anothe...  None
# 1     If I can give this place a 0 I would have done...  None
# 2     I wish I could rate this 0/5 stars. Honestly t...  None
# 3     Ir you love dim sum like I do. This is your pl...  None
# 4     The food was salty and the portions were small...  None
# ...                                                 ...   ...
# 3276                                                     None
# 3277                                                     None
# 3278                                                     None
# 3279                                                     None
# 3280                                                     None
#
#                                     gmap_id  review_sentiment  \
# 0     0x89e465c09b874879:0xd318f9cc0b6b39a6          0.100617
# 1     0x89e465c09b874879:0xd318f9cc0b6b39a6         -0.450000
# 2     0x89e465c09b874879:0xd318f9cc0b6b39a6         -0.100000
# 3     0x89e465c09b874879:0xd318f9cc0b6b39a6          0.300000
# 4     0x89e465c09b874879:0xd318f9cc0b6b39a6         -0.125000
# ...                                     ...               ...
# 3276  0x89e47a1837cac75b:0x5a24279825a82cbc          0.000000
# 3277  0x89e47a1837cac75b:0x5a24279825a82cbc          0.000000
# 3278  0x89e47a1837cac75b:0x5a24279825a82cbc          0.000000
# 3279  0x89e47a1837cac75b:0x5a24279825a82cbc          0.000000
# 3280  0x89e47a1837cac75b:0x5a24279825a82cbc          0.000000
#
#             nombre_local         direccion    ciudad codigo_postal_cod_ciudad  \
# 0     Jump Asian Express     1 Outlet Blvd  Wrentham                 MA 02093
# 1     Jump Asian Express     1 Outlet Blvd  Wrentham                 MA 02093
# 2     Jump Asian Express     1 Outlet Blvd  Wrentham                 MA 02093
# 3     Jump Asian Express     1 Outlet Blvd  Wrentham                 MA 02093
# 4     Jump Asian Express     1 Outlet Blvd  Wrentham                 MA 02093
# ...                  ...               ...       ...                      ...
# 3276   Saigon Restaurant  18 Exchange St D    Millis                 MA 02054
# 3277   Saigon Restaurant  18 Exchange St D    Millis                 MA 02054
# 3278   Saigon Restaurant  18 Exchange St D    Millis                 MA 02054
# 3279   Saigon Restaurant  18 Exchange St D    Millis                 MA 02054
# 3280   Saigon Restaurant  18 Exchange St D    Millis                 MA 02054
#
#      codigo_ciudad codigo_postal   latitude  longitude  \
# 0               MA         02093  42.039907 -71.354742
# 1               MA         02093  42.039907 -71.354742
# 2               MA         02093  42.039907 -71.354742
# 3               MA         02093  42.039907 -71.354742
# 4               MA         02093  42.039907 -71.354742
# ...            ...           ...        ...        ...
# 3276            MA         02054  42.166519 -71.361338
# 3277            MA         02054  42.166519 -71.361338
# 3278            MA         02054  42.166519 -71.361338
# 3279            MA         02054  42.166519 -71.361338
# 3280            MA         02054  42.166519 -71.361338
#
#                                                category  avg_rating  \
# 0                                    [Asian restaurant]         2.2
# 1                                    [Asian restaurant]         2.2
# 2                                    [Asian restaurant]         2.2
# 3                                    [Asian restaurant]         2.2
# 4                                    [Asian restaurant]         2.2
# ...                                                 ...         ...
# 3276  [Vietnamese restaurant, Asian restaurant, Rest...         4.1
# 3277  [Vietnamese restaurant, Asian restaurant, Rest...         4.1
# 3278  [Vietnamese restaurant, Asian restaurant, Rest...         4.1
# 3279  [Vietnamese restaurant, Asian restaurant, Rest...         4.1
# 3280  [Vietnamese restaurant, Asian restaurant, Rest...         4.1
#
#       num_of_reviews price                                               MISC
# 0                 28  None                  {'Service options': ['Delivery']}
# 1                 28  None                  {'Service options': ['Delivery']}
# 2                 28  None                  {'Service options': ['Delivery']}
# 3                 28  None                  {'Service options': ['Delivery']}
# 4                 28  None                  {'Service options': ['Delivery']}
# ...              ...   ...                                                ...
# 3276              86  None  {'Service options': ['Takeout'], 'Highlights':...
# 3277              86  None  {'Service options': ['Takeout'], 'Highlights':...
# 3278              86  None  {'Service options': ['Takeout'], 'Highlights':...
# 3279              86  None  {'Service options': ['Takeout'], 'Highlights':...
# 3280              86  None  {'Service options': ['Takeout'], 'Highlights':...
#
# [3281 rows x 20 columns]

# %% [markdown]
# ### Gráfico de los 20 restaurants con más reviews

# %%
local_comment_counts = merged_df['nombre_local'].value_counts().reset_index()
local_comment_counts.columns = ['nombre_local', 'num_of_reviews']

# Seleccionar los 20 locales con más comentarios
top_locals = local_comment_counts.head(20)

# Mostrar el ranking
print(top_locals)
# Out:
#                                   nombre_local  num_of_reviews
# 0                                      Dunkin'             565
# 1                                   McDonald's             495
# 2                                       Subway             192
# 3                               Domino's Pizza             100
# 4                  Evviva Trattoria - Wrentham              96
# 5                               The Grape Leaf              93
# 6                               Quan's Kitchen              93
# 7                                     1A Pizza              90
# 8                Sombrero's Mexican Restaurant              85
# 9                     Mansfield House of Pizza              82
# 10                      Foxboro House of Pizza              82
# 11                          Outback Steakhouse              74
# 12                               Kihei Dynasty              65
# 13  D & D Breakfast & Lunch + Ice cream Parlor              65
# 14                             Family Pizzeria              57
# 15                                      Pho 29              56
# 16                                       Thyme              51
# 17                             Piezoni's Pizza              49
# 18                               Mandarin Chef              48
# 19                    The Square Kitchen & Bar              47

# %%
plt.figure(figsize=(12, 8))
plt.bar(top_locals['nombre_local'], top_locals['num_of_reviews'], color='skyblue')

plt.xlabel('Nombre del Local')
plt.ylabel('Número de Comentarios')
plt.title('Top 20 Locales con Más Comentarios')
plt.xticks(rotation=90)  

plt.tight_layout()
plt.show()

# %%
local_comment_counts = merged_df.groupby('nombre_local').agg(
    num_of_reviews=('nombre_local', 'count'),
    avg_rating=('avg_rating', 'mean')
).reset_index()

top_locals = local_comment_counts.sort_values(by='num_of_reviews', ascending=False).head(20)

plt.figure(figsize=(14, 8))
plt.bar(top_locals['nombre_local'], top_locals['avg_rating'], color='skyblue')

plt.xlabel('Nombre del Local')
plt.ylabel('Promedio de Calificación')
plt.title('Top 20 Locales y su Promedio de Calificación')
plt.xticks(rotation=90)  

plt.tight_layout()
plt.show()

# %%
merged_df.to_csv(r"C:\Users\jessi\Desktop\Proyecto Final Henry\Colorado.csv", index=False)
