# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from textblob import TextBlob
from scipy import stats
import folium as folium
from IPython.display import display
import geopandas as gpd
from shapely.geometry import Point
import contextily as ctx

# %% [markdown]
# ### Lectura del archivo Oregon.json

# %%
df= pd.read_json(r"C:\Users\jessi\Desktop\Horizon_Project\Oregon\Oregon.json",lines=True)

# %%
df.head()
# Out:
#         user_id                  name  rating  \
# 0  1.027736e+20              Mary Lao       3
# 1  1.084151e+20        Jennifer Moser       4
# 2  1.048040e+20  Veronica Lona Torres       3
# 3  1.106057e+20     Susana Betancourt       1
# 4  1.139821e+20              LESLIE S       4
#
#                                                 text  resp  \
# 0  Their spaghetti sucks. It's plain and it's wat...  None
# 1  They need better recipes for the desserts  oth...  None
# 2  I love the foods there. It's has all different...  None
# 3  Gross! I found hair in two dishes that I picke...  None
# 4  love this place been going there for about 5 y...  None
#
#                                  gmap_id
# 0  0x5495a02207a696d1:0x59705a9df8b151dd
# 1  0x5495a02207a696d1:0x59705a9df8b151dd
# 2  0x5495a02207a696d1:0x59705a9df8b151dd
# 3  0x5495a02207a696d1:0x59705a9df8b151dd
# 4  0x5495a02207a696d1:0x59705a9df8b151dd

# %% [markdown]
# ### Lectura del archivo "df_gastronomico_ciudades.json "

# %%
df2=pd.read_json(r"C:\Users\jessi\Desktop\Horizon_Project\Washington\df_gastronomico_ciudades.json",lines=True)

# %%
df2.head()
# Out:
#                            nombre_local                     direccion  \
# 0  Creole Orleans Catering & Food Truck  2841 Greenbriar Pkwy SW N317
# 1               Biswas Grocery and Cafe            2853 Buford Hwy NE
# 2                           Noodle Cafe        233 Peachtree St # B70
# 3  Creole Orleans Catering & Food Truck  2841 Greenbriar Pkwy SW N317
# 4               Biswas Grocery and Cafe            2853 Buford Hwy NE
#
#     ciudad codigo_postal_cod_ciudad codigo_ciudad codigo_postal  \
# 0  Atlanta                 GA 30331            GA         30331
# 1  Atlanta                 GA 30329            GA         30329
# 2  Atlanta                 GA 30303            GA         30303
# 3  Atlanta                 GA 30331            GA         30331
# 4  Atlanta                 GA 30329            GA         30329
#
#                                  gmap_id   latitude  longitude  \
# 0  0x88f503d71429c049:0xef40e07a5479b1c2  33.689032 -84.495097
# 1  0x88f507f3e1cde31d:0x1bcd2bb2f0555399  33.831454 -84.341647
# 2  0x88f5047831dfc86d:0x985e3a6645f5ca4f  33.760404 -84.386319
# 3  0x88f503d71429c049:0xef40e07a5479b1c2  33.689032 -84.495097
# 4  0x88f507f3e1cde31d:0x1bcd2bb2f0555399  33.831454 -84.341647
#
#                                             category  avg_rating  \
# 0  [Creole restaurant, Caribbean restaurant, Cate...         4.7
# 1  [Organic food store, Convenience store, Phone ...         4.7
# 2                      [Thai restaurant, Restaurant]         4.2
# 3  [Creole restaurant, Caribbean restaurant, Cate...         4.7
# 4  [Organic food store, Convenience store, Phone ...         4.7
#
#    num_of_reviews price                                               MISC
# 0              31  None  {'Service options': ['Delivery', 'Takeout', 'D...
# 1              25  None  {'Service options': ['Delivery', 'In-store sho...
# 2              35  None  {'Service options': ['Takeout', 'Dine-in', 'De...
# 3              31  None  {'Service options': ['Delivery', 'Takeout', 'D...
# 4              25  None  {'Service options': ['Delivery', 'In-store sho...

# %% [markdown]
# ### Informacion General

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32546 entries, 0 to 32545
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   user_id  32546 non-null  float64
#  1   name     32546 non-null  object
#  2   rating   32546 non-null  int64
#  3   text     20577 non-null  object
#  4   resp     3717 non-null   object
#  5   gmap_id  32546 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.5+ MB
# None

# %%
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18037 entries, 0 to 18036
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   nombre_local              18037 non-null  object
#  1   direccion                 18037 non-null  object
#  2   ciudad                    18037 non-null  object
#  3   codigo_postal_cod_ciudad  18037 non-null  object
#  4   codigo_ciudad             18037 non-null  object
#  5   codigo_postal             18037 non-null  object
#  6   gmap_id                   18037 non-null  object
#  7   latitude                  18037 non-null  float64
#  8   longitude                 18037 non-null  float64
#  9   category                  18037 non-null  object
#  10  avg_rating                18037 non-null  float64
#  11  num_of_reviews            18037 non-null  int64
#  12  price                     8690 non-null   object
#  13  MISC                      17614 non-null  object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 1.9+ MB
# None

# %% [markdown]
# ### Descripción de los dataframe

# %%
df['rating'].describe()
# Out:
# count    32546.000000
# mean         4.265010
# std          1.097733
# min          1.000000
# 25%          4.000000
# 50%          5.000000
# 75%          5.000000
# max          5.000000
# Name: rating, dtype: float64

# %%
df2.describe()
# Out:
#            latitude     longitude    avg_rating  num_of_reviews
# count  18037.000000  18037.000000  18037.000000    18037.000000
# mean      38.290007    -92.404179      4.137573       70.622276
# std        4.948144     18.621202      0.575608      143.090909
# min       25.993710   -122.805295      1.000000        1.000000
# 25%       34.055071   -118.186637      3.900000       17.000000
# 50%       39.943207    -86.808270      4.200000       38.000000
# 75%       40.831310    -74.145373      4.500000       78.000000
# max       47.682747    -71.145040      5.000000     5321.000000

# %% [markdown]
# ### Análisis de Datos Nulos

# %%
print(df.isnull().sum())
# Out:
# user_id        0
# name           0
# rating         0
# text       11969
# resp       28829
# gmap_id        0
# dtype: int64

# %%
print(df2.isnull().sum())
# Out:
# nombre_local                   0
# direccion                      0
# ciudad                         0
# codigo_postal_cod_ciudad       0
# codigo_ciudad                  0
# codigo_postal                  0
# gmap_id                        0
# latitude                       0
# longitude                      0
# category                       0
# avg_rating                     0
# num_of_reviews                 0
# price                       9347
# MISC                         423
# dtype: int64

# %% [markdown]
# ### Outliers

# %%
rating = df['rating']

# Calcular el IQR para la columna 'rating'
Q1 = rating.quantile(0.25)
Q3 = rating.quantile(0.75)
IQR = Q3 - Q1

# Identificar outliers usando IQR
outliers_iqr = rating[(rating < (Q1 - 1.5 * IQR)) | (rating > (Q3 + 1.5 * IQR))]
print("Outliers en la columna 'rating' usando IQR:")
print(outliers_iqr)

# Calcular Z-score para la columna 'rating'
z_scores = stats.zscore(rating)
abs_z_scores = abs(z_scores)

# Identificar outliers con Z-score mayor que 3
outliers_z = rating[abs_z_scores > 3]
print("Outliers en la columna 'rating' usando Z-score:")
print(outliers_z)

# Graficar el boxplot para 'rating'
plt.figure(figsize=(10, 6))
sns.boxplot(x=rating)
plt.title('Boxplot de rating')
plt.show()
# Out:
# Outliers en la columna 'rating' usando IQR:
# 3        1
# 6        1
# 30       1
# 33       1
# 59       1
#         ..
# 32442    2
# 32476    2
# 32491    2
# 32512    1
# 32514    1
# Name: rating, Length: 2794, dtype: int64
# Outliers en la columna 'rating' usando Z-score:
# Series([], Name: rating, dtype: int64)

# %%
columns_to_check = ['avg_rating']

Q1 = df2[columns_to_check].quantile(0.25)
Q3 = df2[columns_to_check].quantile(0.75)
IQR = Q3 - Q1

outliers_iqr = df2[(df2[columns_to_check] < (Q1 - 1.5 * IQR)) | (df2[columns_to_check] > (Q3 + 1.5 * IQR))]

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.boxplot(x=df2['avg_rating'])
plt.title('Outliers de Average Rating')



plt.show()

# %%
num_of_reviews = df2['num_of_reviews']

Q1 = num_of_reviews.quantile(0.25)
Q3 = num_of_reviews.quantile(0.75)
IQR = Q3 - Q1

outliers_iqr = num_of_reviews[(num_of_reviews < (Q1 - 1.5 * IQR)) | (num_of_reviews > (Q3 + 1.5 * IQR))]
print("Outliers en la columna 'num_of_reviews' usando IQR:")
print(outliers_iqr)

z_scores = stats.zscore(num_of_reviews)
abs_z_scores = abs(z_scores)

outliers_z = num_of_reviews[abs_z_scores > 3]
print("Outliers en la columna 'num_of_reviews' usando Z-score:")
print(outliers_z)

plt.figure(figsize=(10, 6))
sns.boxplot(x=num_of_reviews)
plt.title('Outliers Número de Reviews')
plt.show()
# Out:
# Outliers en la columna 'num_of_reviews' usando IQR:
# 124      798
# 206      178
# 217      496
# 224      214
# 229      768
#         ...
# 18019    238
# 18024    244
# 18027    292
# 18029    178
# 18031    238
# Name: num_of_reviews, Length: 1371, dtype: int64
# Outliers en la columna 'num_of_reviews' usando Z-score:
# 124       798
# 229       768
# 233      1018
# 237      3128
# 238      1373
#          ...
# 17884     798
# 17890    1108
# 17892    1208
# 17893    1351
# 17901     624
# Name: num_of_reviews, Length: 171, dtype: int64

# %% [markdown]
# ### Histogramas de distribución

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['rating'], bins=10)
plt.title('Distribución de Raiting DF')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
avg_rating = df2['avg_rating']
num_of_reviews = df2['num_of_reviews']

plt.figure(figsize=(14, 12))

plt.subplot(2, 2, 1)
sns.histplot(avg_rating, bins=30, kde=False)
plt.title('Histograma de puntaje promedio')
plt.xlabel('avg_rating')
plt.ylabel('Frecuencia')

plt.subplot(2, 2, 3)
sns.histplot(num_of_reviews, bins=20, kde=False)
plt.title('Histograma de número de reviews')
plt.xlabel('num_of_reviews')
plt.ylabel('Frecuencia')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Análisis de sentimientos

# %%
df['text'] = df['text'].fillna('')

# %%
def get_sentiment(text):
    return TextBlob(text).sentiment.polarity

df['review_sentiment'] = df['text'].apply(get_sentiment)

print(df[['text', 'review_sentiment']].head())
# Out:
#                                                 text  review_sentiment
# 0  Their spaghetti sucks. It's plain and it's wat...          0.115696
# 1  They need better recipes for the desserts  oth...          0.187500
# 2  I love the foods there. It's has all different...          0.366667
# 3  Gross! I found hair in two dishes that I picke...          0.312500
# 4  love this place been going there for about 5 y...          0.500000

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.histplot(df['review_sentiment'], bins=10, kde=True)
plt.title('Distribución de Sentimientos en Reviews')
plt.xlabel('Sentimiento')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ### Unión de datasets

# %%
merged_df = pd.merge(df, df2, on='gmap_id', how='inner')

# %%
merged_df
# Out:
#             user_id                          name  rating  \
# 0      1.027736e+20                      Mary Lao       3
# 1      1.027736e+20                      Mary Lao       3
# 2      1.084151e+20                Jennifer Moser       4
# 3      1.084151e+20                Jennifer Moser       4
# 4      1.048040e+20          Veronica Lona Torres       3
# ...             ...                           ...     ...
# 32595  1.173347e+20                 Haltestelle 7       5
# 32596  1.144839e+20  Hyacinth & Aparicio Baltazar       5
# 32597  1.030218e+20                  Brenda Rocha       4
# 32598  1.114784e+20                    Raghu Kona       5
# 32599  1.178610e+20             Katelyn Schiesser       5
#
#                                                     text  resp  \
# 0      Their spaghetti sucks. It's plain and it's wat...  None
# 1      Their spaghetti sucks. It's plain and it's wat...  None
# 2      They need better recipes for the desserts  oth...  None
# 3      They need better recipes for the desserts  oth...  None
# 4      I love the foods there. It's has all different...  None
# ...                                                  ...   ...
# 32595                                                     None
# 32596                                                     None
# 32597                                                     None
# 32598                                                     None
# 32599                                                     None
#
#                                      gmap_id  review_sentiment  \
# 0      0x5495a02207a696d1:0x59705a9df8b151dd          0.115696
# 1      0x5495a02207a696d1:0x59705a9df8b151dd          0.115696
# 2      0x5495a02207a696d1:0x59705a9df8b151dd          0.187500
# 3      0x5495a02207a696d1:0x59705a9df8b151dd          0.187500
# 4      0x5495a02207a696d1:0x59705a9df8b151dd          0.366667
# ...                                      ...               ...
# 32595  0x54950c252d2c081f:0x8df89e9607aedf83          0.000000
# 32596  0x54950c252d2c081f:0x8df89e9607aedf83          0.000000
# 32597  0x54950c252d2c081f:0x8df89e9607aedf83          0.000000
# 32598  0x54950c252d2c081f:0x8df89e9607aedf83          0.000000
# 32599  0x54950c252d2c081f:0x8df89e9607aedf83          0.000000
#
#           nombre_local               direccion        ciudad  \
# 0      HomeTown Buffet       11358 SE 82nd Ave  Happy Valley
# 1      HomeTown Buffet       11358 SE 82nd Ave  Happy Valley
# 2      HomeTown Buffet       11358 SE 82nd Ave  Happy Valley
# 3      HomeTown Buffet       11358 SE 82nd Ave  Happy Valley
# 4      HomeTown Buffet       11358 SE 82nd Ave  Happy Valley
# ...                ...                     ...           ...
# 32595    Alvaros Tacos  6050-6056 SW Hall Blvd     Beaverton
# 32596    Alvaros Tacos  6050-6056 SW Hall Blvd     Beaverton
# 32597    Alvaros Tacos  6050-6056 SW Hall Blvd     Beaverton
# 32598    Alvaros Tacos  6050-6056 SW Hall Blvd     Beaverton
# 32599    Alvaros Tacos  6050-6056 SW Hall Blvd     Beaverton
#
#       codigo_postal_cod_ciudad codigo_ciudad codigo_postal   latitude  \
# 0                     OR 97086            OR         97086  45.442189
# 1                     OR 97086            OR         97086  45.442189
# 2                     OR 97086            OR         97086  45.442189
# 3                     OR 97086            OR         97086  45.442189
# 4                     OR 97086            OR         97086  45.442189
# ...                        ...           ...           ...        ...
# 32595                 OR 97008            OR         97008  45.475866
# 32596                 OR 97008            OR         97008  45.475866
# 32597                 OR 97008            OR         97008  45.475866
# 32598                 OR 97008            OR         97008  45.475866
# 32599                 OR 97008            OR         97008  45.475866
#
#         longitude                                           category  \
# 0     -122.576936  [Buffet restaurant, American restaurant, Break...
# 1     -122.576936  [Buffet restaurant, American restaurant, Break...
# 2     -122.576936  [Buffet restaurant, American restaurant, Break...
# 3     -122.576936  [Buffet restaurant, American restaurant, Break...
# 4     -122.576936  [Buffet restaurant, American restaurant, Break...
# ...           ...                                                ...
# 32595 -122.805295                                  [Taco restaurant]
# 32596 -122.805295                                  [Taco restaurant]
# 32597 -122.805295                                  [Taco restaurant]
# 32598 -122.805295                                  [Taco restaurant]
# 32599 -122.805295                                  [Taco restaurant]
#
#        avg_rating  num_of_reviews price  \
# 0             2.8              28  None
# 1             2.8              28  None
# 2             2.8              28  None
# 3             2.8              28  None
# 4             2.8              28  None
# ...           ...             ...   ...
# 32595         4.6              58     $
# 32596         4.6              58     $
# 32597         4.6              58     $
# 32598         4.6              58     $
# 32599         4.6              58     $
#
#                                                     MISC
# 0      {'Service options': ['Delivery'], 'Highlights'...
# 1      {'Service options': ['Delivery'], 'Highlights'...
# 2      {'Service options': ['Delivery'], 'Highlights'...
# 3      {'Service options': ['Delivery'], 'Highlights'...
# 4      {'Service options': ['Delivery'], 'Highlights'...
# ...                                                  ...
# 32595  {'Service options': ['Takeout', 'Delivery'], '...
# 32596  {'Service options': ['Takeout', 'Delivery'], '...
# 32597  {'Service options': ['Takeout', 'Delivery'], '...
# 32598  {'Service options': ['Takeout', 'Delivery'], '...
# 32599  {'Service options': ['Takeout', 'Delivery'], '...
#
# [32600 rows x 20 columns]

# %% [markdown]
# ### Gráfico de los 20 restaurants con más reviews

# %%
local_comment_counts = merged_df['nombre_local'].value_counts().reset_index()
local_comment_counts.columns = ['nombre_local', 'num_of_reviews']

# Seleccionar los 20 locales con más comentarios
top_locals = local_comment_counts.head(20)

# Mostrar el ranking
print(top_locals)
# Out:
#                            nombre_local  num_of_reviews
# 0                               Denny's            1306
# 1            Henry's 12th Street Tavern            1081
# 2                 The Original Dinerant             968
# 3                       Jack in the Box             908
# 4                             Starbucks             892
# 5   Red Robin Gourmet Burgers and Brews             741
# 6                             Taco Bell             596
# 7                                Arby's             584
# 8                               Wendy's             524
# 9                        Domino's Pizza             524
# 10                      Lauretta Jean's             491
# 11          Lucky Labrador Public House             457
# 12                               Subway             338
# 13                            Pizza Hut             333
# 14                    a Cena Ristorante             319
# 15                Kwang Chow Restaurant             311
# 16                    Taqueria Portland             199
# 17                            Sanborn's             193
# 18                               La Taq             189
# 19                         E'Njoni Cafe             182

# %%
plt.figure(figsize=(12, 8))
plt.bar(top_locals['nombre_local'], top_locals['num_of_reviews'], color='skyblue')

plt.xlabel('Nombre del Local')
plt.ylabel('Número de Comentarios')
plt.title('Top 20 Locales con Más Comentarios')
plt.xticks(rotation=90)  

plt.tight_layout()
plt.show()

# %%
local_comment_counts = merged_df.groupby('nombre_local').agg(
    num_of_reviews=('nombre_local', 'count'),
    avg_rating=('avg_rating', 'mean')
).reset_index()

top_locals = local_comment_counts.sort_values(by='num_of_reviews', ascending=False).head(20)

plt.figure(figsize=(14, 8))
plt.bar(top_locals['nombre_local'], top_locals['avg_rating'], color='skyblue')

plt.xlabel('Nombre del Local')
plt.ylabel('Promedio de Calificación')
plt.title('Top 20 Locales y su Promedio de Calificación')
plt.xticks(rotation=90)  

plt.tight_layout()
plt.show()

# %%
merged_df.to_csv(r"C:\Users\jessi\Desktop\Proyecto Final Henry\Oregon.csv", index=False)
