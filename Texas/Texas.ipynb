# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from textblob import TextBlob
from scipy import stats
import folium as folium
from IPython.display import display
import geopandas as gpd
from shapely.geometry import Point
import contextily as ctx

# %% [markdown]
# ### Lectura del archivo Texas.json

# %%
df= pd.read_json(r"C:\Users\jessi\Desktop\Horizon_Project\Texas\Texas.json",lines=True)

# %%
df.head()
# Out:
#         user_id                                 name  rating  \
# 0  1.089735e+20                           Candi Redd       3
# 1  1.181307e+20  Bookie Hunter (The Running Bushman)       5
# 2  1.106401e+20                          Nikki Jones       5
# 3  1.132866e+20                              Kris Ty       5
# 4  1.061506e+20                        Steve Granson       5
#
#                                                 text  resp  \
# 0  Went here for the live music and R&B performan...  None
# 1  Only been on Friday night, good vibes, live ba...  None
# 2                                               None  None
# 3                                               None  None
# 4                                               None  None
#
#                                  gmap_id
# 0  0x8640bf47ce0af871:0xbf9af8f0c2a8f35c
# 1  0x8640bf47ce0af871:0xbf9af8f0c2a8f35c
# 2  0x8640bf47ce0af871:0xbf9af8f0c2a8f35c
# 3  0x8640bf47ce0af871:0xbf9af8f0c2a8f35c
# 4  0x8640bf47ce0af871:0xbf9af8f0c2a8f35c

# %% [markdown]
# ### Lectura del archivo "df_gastronomico_ciudades.json "

# %%
df2=pd.read_json(r"C:\Users\jessi\Desktop\Horizon_Project\Washington\df_gastronomico_ciudades.json",lines=True)

# %%
df2.head()
# Out:
#                            nombre_local                     direccion  \
# 0  Creole Orleans Catering & Food Truck  2841 Greenbriar Pkwy SW N317
# 1               Biswas Grocery and Cafe            2853 Buford Hwy NE
# 2                           Noodle Cafe        233 Peachtree St # B70
# 3  Creole Orleans Catering & Food Truck  2841 Greenbriar Pkwy SW N317
# 4               Biswas Grocery and Cafe            2853 Buford Hwy NE
#
#     ciudad codigo_postal_cod_ciudad codigo_ciudad codigo_postal  \
# 0  Atlanta                 GA 30331            GA         30331
# 1  Atlanta                 GA 30329            GA         30329
# 2  Atlanta                 GA 30303            GA         30303
# 3  Atlanta                 GA 30331            GA         30331
# 4  Atlanta                 GA 30329            GA         30329
#
#                                  gmap_id   latitude  longitude  \
# 0  0x88f503d71429c049:0xef40e07a5479b1c2  33.689032 -84.495097
# 1  0x88f507f3e1cde31d:0x1bcd2bb2f0555399  33.831454 -84.341647
# 2  0x88f5047831dfc86d:0x985e3a6645f5ca4f  33.760404 -84.386319
# 3  0x88f503d71429c049:0xef40e07a5479b1c2  33.689032 -84.495097
# 4  0x88f507f3e1cde31d:0x1bcd2bb2f0555399  33.831454 -84.341647
#
#                                             category  avg_rating  \
# 0  [Creole restaurant, Caribbean restaurant, Cate...         4.7
# 1  [Organic food store, Convenience store, Phone ...         4.7
# 2                      [Thai restaurant, Restaurant]         4.2
# 3  [Creole restaurant, Caribbean restaurant, Cate...         4.7
# 4  [Organic food store, Convenience store, Phone ...         4.7
#
#    num_of_reviews price                                               MISC
# 0              31  None  {'Service options': ['Delivery', 'Takeout', 'D...
# 1              25  None  {'Service options': ['Delivery', 'In-store sho...
# 2              35  None  {'Service options': ['Takeout', 'Dine-in', 'De...
# 3              31  None  {'Service options': ['Delivery', 'Takeout', 'D...
# 4              25  None  {'Service options': ['Delivery', 'In-store sho...

# %% [markdown]
# ### Informacion General

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29308 entries, 0 to 29307
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   user_id  29308 non-null  float64
#  1   name     29308 non-null  object
#  2   rating   29308 non-null  int64
#  3   text     18144 non-null  object
#  4   resp     2675 non-null   object
#  5   gmap_id  29308 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.3+ MB
# None

# %%
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18037 entries, 0 to 18036
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   nombre_local              18037 non-null  object
#  1   direccion                 18037 non-null  object
#  2   ciudad                    18037 non-null  object
#  3   codigo_postal_cod_ciudad  18037 non-null  object
#  4   codigo_ciudad             18037 non-null  object
#  5   codigo_postal             18037 non-null  object
#  6   gmap_id                   18037 non-null  object
#  7   latitude                  18037 non-null  float64
#  8   longitude                 18037 non-null  float64
#  9   category                  18037 non-null  object
#  10  avg_rating                18037 non-null  float64
#  11  num_of_reviews            18037 non-null  int64
#  12  price                     8690 non-null   object
#  13  MISC                      17614 non-null  object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 1.9+ MB
# None

# %% [markdown]
# ### Descripción de los dataframe

# %%
df['rating'].describe()
# Out:
# count    29308.000000
# mean         4.268254
# std          1.126414
# min          1.000000
# 25%          4.000000
# 50%          5.000000
# 75%          5.000000
# max          5.000000
# Name: rating, dtype: float64

# %%
df2.describe()
# Out:
#            latitude     longitude    avg_rating  num_of_reviews
# count  18037.000000  18037.000000  18037.000000    18037.000000
# mean      38.290007    -92.404179      4.137573       70.622276
# std        4.948144     18.621202      0.575608      143.090909
# min       25.993710   -122.805295      1.000000        1.000000
# 25%       34.055071   -118.186637      3.900000       17.000000
# 50%       39.943207    -86.808270      4.200000       38.000000
# 75%       40.831310    -74.145373      4.500000       78.000000
# max       47.682747    -71.145040      5.000000     5321.000000

# %% [markdown]
# ### Análisis de Datos Nulos

# %%
print(df.isnull().sum())
# Out:
# user_id        0
# name           0
# rating         0
# text       11164
# resp       26633
# gmap_id        0
# dtype: int64

# %%
print(df2.isnull().sum())
# Out:
# nombre_local                   0
# direccion                      0
# ciudad                         0
# codigo_postal_cod_ciudad       0
# codigo_ciudad                  0
# codigo_postal                  0
# gmap_id                        0
# latitude                       0
# longitude                      0
# category                       0
# avg_rating                     0
# num_of_reviews                 0
# price                       9347
# MISC                         423
# dtype: int64

# %% [markdown]
# ### Outliers

# %%
rating = df['rating']

# Calcular el IQR para la columna 'rating'
Q1 = rating.quantile(0.25)
Q3 = rating.quantile(0.75)
IQR = Q3 - Q1

# Identificar outliers usando IQR
outliers_iqr = rating[(rating < (Q1 - 1.5 * IQR)) | (rating > (Q3 + 1.5 * IQR))]
print("Outliers en la columna 'rating' usando IQR:")
print(outliers_iqr)

# Calcular Z-score para la columna 'rating'
z_scores = stats.zscore(rating)
abs_z_scores = abs(z_scores)

# Identificar outliers con Z-score mayor que 3
outliers_z = rating[abs_z_scores > 3]
print("Outliers en la columna 'rating' usando Z-score:")
print(outliers_z)

# Graficar el boxplot para 'rating'
plt.figure(figsize=(10, 6))
sns.boxplot(x=rating)
plt.title('Boxplot de rating')
plt.show()
# Out:
# Outliers en la columna 'rating' usando IQR:
# 11       2
# 14       2
# 15       1
# 17       1
# 38       1
#         ..
# 29295    1
# 29296    1
# 29298    1
# 29301    1
# 29303    1
# Name: rating, Length: 2710, dtype: int64
# Outliers en la columna 'rating' usando Z-score:
# Series([], Name: rating, dtype: int64)

# %%
columns_to_check = ['avg_rating']

Q1 = df2[columns_to_check].quantile(0.25)
Q3 = df2[columns_to_check].quantile(0.75)
IQR = Q3 - Q1

outliers_iqr = df2[(df2[columns_to_check] < (Q1 - 1.5 * IQR)) | (df2[columns_to_check] > (Q3 + 1.5 * IQR))]

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.boxplot(x=df2['avg_rating'])
plt.title('Outliers de Average Rating')



plt.show()

# %%
num_of_reviews = df2['num_of_reviews']

Q1 = num_of_reviews.quantile(0.25)
Q3 = num_of_reviews.quantile(0.75)
IQR = Q3 - Q1

outliers_iqr = num_of_reviews[(num_of_reviews < (Q1 - 1.5 * IQR)) | (num_of_reviews > (Q3 + 1.5 * IQR))]
print("Outliers en la columna 'num_of_reviews' usando IQR:")
print(outliers_iqr)

z_scores = stats.zscore(num_of_reviews)
abs_z_scores = abs(z_scores)

outliers_z = num_of_reviews[abs_z_scores > 3]
print("Outliers en la columna 'num_of_reviews' usando Z-score:")
print(outliers_z)

plt.figure(figsize=(10, 6))
sns.boxplot(x=num_of_reviews)
plt.title('Outliers Número de Reviews')
plt.show()
# Out:
# Outliers en la columna 'num_of_reviews' usando IQR:
# 124      798
# 206      178
# 217      496
# 224      214
# 229      768
#         ...
# 18019    238
# 18024    244
# 18027    292
# 18029    178
# 18031    238
# Name: num_of_reviews, Length: 1371, dtype: int64
# Outliers en la columna 'num_of_reviews' usando Z-score:
# 124       798
# 229       768
# 233      1018
# 237      3128
# 238      1373
#          ...
# 17884     798
# 17890    1108
# 17892    1208
# 17893    1351
# 17901     624
# Name: num_of_reviews, Length: 171, dtype: int64

# %% [markdown]
# ### Histogramas de distribución

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['rating'], bins=10)
plt.title('Distribución de Raiting DF')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
avg_rating = df2['avg_rating']
num_of_reviews = df2['num_of_reviews']

plt.figure(figsize=(14, 12))

plt.subplot(2, 2, 1)
sns.histplot(avg_rating, bins=30, kde=False)
plt.title('Histograma de puntaje promedio')
plt.xlabel('avg_rating')
plt.ylabel('Frecuencia')

plt.subplot(2, 2, 3)
sns.histplot(num_of_reviews, bins=20, kde=False)
plt.title('Histograma de número de reviews')
plt.xlabel('num_of_reviews')
plt.ylabel('Frecuencia')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Análisis de sentimientos

# %%
df['text'] = df['text'].fillna('')

# %%
def get_sentiment(text):
    return TextBlob(text).sentiment.polarity

df['review_sentiment'] = df['text'].apply(get_sentiment)

print(df[['text', 'review_sentiment']].head())
# Out:
#                                                 text  review_sentiment
# 0  Went here for the live music and R&B performan...          0.351571
# 1  Only been on Friday night, good vibes, live ba...          0.409091
# 2                                                             0.000000
# 3                                                             0.000000
# 4                                                             0.000000

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.histplot(df['review_sentiment'], bins=10, kde=True)
plt.title('Distribución de Sentimientos en Reviews')
plt.xlabel('Sentimiento')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ### Unión de datasets

# %%
merged_df = pd.merge(df, df2, on='gmap_id', how='inner')

# %%
merged_df
# Out:
#             user_id                                 name  rating  \
# 0      1.089735e+20                           Candi Redd       3
# 1      1.089735e+20                           Candi Redd       3
# 2      1.181307e+20  Bookie Hunter (The Running Bushman)       5
# 3      1.181307e+20  Bookie Hunter (The Running Bushman)       5
# 4      1.106401e+20                          Nikki Jones       5
# ...             ...                                  ...     ...
# 29515  1.005046e+20                           Ravi Kumar       1
# 29516  1.010719e+20                       Elnaz Khaleghi       4
# 29517  1.103479e+20                        Joseph Xavier       5
# 29518  1.155027e+20                   esfandiar baharloo       5
# 29519  1.163587e+20                   Karthik Mannepalli       4
#
#                                                     text  \
# 0      Went here for the live music and R&B performan...
# 1      Went here for the live music and R&B performan...
# 2      Only been on Friday night, good vibes, live ba...
# 3      Only been on Friday night, good vibes, live ba...
# 4
# ...                                                  ...
# 29515  They charge for printing shipping labels. I ha...
# 29516
# 29517
# 29518
# 29519
#
#                                                     resp  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 29515  {'time': 1503679157307, 'text': 'We apologize ...
# 29516                                               None
# 29517                                               None
# 29518                                               None
# 29519                                               None
#
#                                      gmap_id  review_sentiment   nombre_local  \
# 0      0x8640bf47ce0af871:0xbf9af8f0c2a8f35c          0.351571    Vino Lounge
# 1      0x8640bf47ce0af871:0xbf9af8f0c2a8f35c          0.351571    Vino Lounge
# 2      0x8640bf47ce0af871:0xbf9af8f0c2a8f35c          0.409091    Vino Lounge
# 3      0x8640bf47ce0af871:0xbf9af8f0c2a8f35c          0.409091    Vino Lounge
# 4      0x8640bf47ce0af871:0xbf9af8f0c2a8f35c          0.000000    Vino Lounge
# ...                                      ...               ...            ...
# 29515  0x8640c0e61d0ca81b:0x927cb75525843d86          0.137500  The UPS Store
# 29516  0x8640c0e61d0ca81b:0x927cb75525843d86          0.000000  The UPS Store
# 29517  0x8640c0e61d0ca81b:0x927cb75525843d86          0.000000  The UPS Store
# 29518  0x8640c0e61d0ca81b:0x927cb75525843d86          0.000000  The UPS Store
# 29519  0x8640c0e61d0ca81b:0x927cb75525843d86          0.000000  The UPS Store
#
#                 direccion   ciudad codigo_postal_cod_ciudad codigo_ciudad  \
# 0          2416 Pierce St  Houston                 TX 77003            TX
# 1          2416 Pierce St  Houston                 TX 77003            TX
# 2          2416 Pierce St  Houston                 TX 77003            TX
# 3          2416 Pierce St  Houston                 TX 77003            TX
# 4          2416 Pierce St  Houston                 TX 77003            TX
# ...                   ...      ...                      ...           ...
# 29515  3262 Westheimer Rd  Houston                 TX 77098            TX
# 29516  3262 Westheimer Rd  Houston                 TX 77098            TX
# 29517  3262 Westheimer Rd  Houston                 TX 77098            TX
# 29518  3262 Westheimer Rd  Houston                 TX 77098            TX
# 29519  3262 Westheimer Rd  Houston                 TX 77098            TX
#
#       codigo_postal   latitude  longitude  \
# 0             77003  29.741734 -95.358251
# 1             77003  29.741734 -95.358251
# 2             77003  29.741734 -95.358251
# 3             77003  29.741734 -95.358251
# 4             77003  29.741734 -95.358251
# ...             ...        ...        ...
# 29515         77098  29.742495 -95.425401
# 29516         77098  29.742495 -95.425401
# 29517         77098  29.742495 -95.425401
# 29518         77098  29.742495 -95.425401
# 29519         77098  29.742495 -95.425401
#
#                                                 category  avg_rating  \
# 0                            [Wine bar, Bar, Hookah bar]         4.7
# 1                            [Wine bar, Bar, Hookah bar]         4.7
# 2                            [Wine bar, Bar, Hookah bar]         4.7
# 3                            [Wine bar, Bar, Hookah bar]         4.7
# 4                            [Wine bar, Bar, Hookah bar]         4.7
# ...                                                  ...         ...
# 29515  [Shipping and mailing service, Business center...         3.0
# 29516  [Shipping and mailing service, Business center...         3.0
# 29517  [Shipping and mailing service, Business center...         3.0
# 29518  [Shipping and mailing service, Business center...         3.0
# 29519  [Shipping and mailing service, Business center...         3.0
#
#        num_of_reviews price                                               MISC
# 0                   6  None  {'Service options': ['Dine-in', 'Delivery'], '...
# 1                   6  None  {'Service options': ['Dine-in', 'Delivery'], '...
# 2                   6  None  {'Service options': ['Dine-in', 'Delivery'], '...
# 3                   6  None  {'Service options': ['Dine-in', 'Delivery'], '...
# 4                   6  None  {'Service options': ['Dine-in', 'Delivery'], '...
# ...               ...   ...                                                ...
# 29515              38  None  {'Accessibility': ['Wheelchair accessible entr...
# 29516              38  None  {'Accessibility': ['Wheelchair accessible entr...
# 29517              38  None  {'Accessibility': ['Wheelchair accessible entr...
# 29518              38  None  {'Accessibility': ['Wheelchair accessible entr...
# 29519              38  None  {'Accessibility': ['Wheelchair accessible entr...
#
# [29520 rows x 20 columns]

# %% [markdown]
# ### Gráfico de los 20 restaurants con más reviews

# %%
local_comment_counts = merged_df['nombre_local'].value_counts().reset_index()
local_comment_counts.columns = ['nombre_local', 'num_of_reviews']

# Seleccionar los 20 locales con más comentarios
top_locals = local_comment_counts.head(20)

# Mostrar el ranking
print(top_locals)
# Out:
#                             nombre_local  num_of_reviews
# 0                        In-N-Out Burger            2901
# 1                      Main Event Frisco            1507
# 2                            Whataburger            1381
# 3                            Lucky's Pub            1140
# 4           Chicago Italian Beef & Pizza            1093
# 5                       Huynh Restaurant            1077
# 6   The Moonshiners Southern Table + Bar             994
# 7               Sparkles Burger & Daiqur             976
# 8                            Crepe Crazy             765
# 9                 Zen Japanese Food Fast             611
# 10                               Chago's             543
# 11                             Hopfields             519
# 12                     Wakefield Crowbar             498
# 13                       Honest McKinney             481
# 14                             MOD Pizza             434
# 15                         Ben & Jerry’s             419
# 16                          El Tacorrido             404
# 17                Chipotle Mexican Grill             359
# 18                                Subway             339
# 19                              Paperboy             335

# %%
plt.figure(figsize=(12, 8))
plt.bar(top_locals['nombre_local'], top_locals['num_of_reviews'], color='skyblue')

plt.xlabel('Nombre del Local')
plt.ylabel('Número de Comentarios')
plt.title('Top 20 Locales con Más Comentarios')
plt.xticks(rotation=90)  

plt.tight_layout()
plt.show()

# %%
local_comment_counts = merged_df.groupby('nombre_local').agg(
    num_of_reviews=('nombre_local', 'count'),
    avg_rating=('avg_rating', 'mean')
).reset_index()

top_locals = local_comment_counts.sort_values(by='num_of_reviews', ascending=False).head(20)

plt.figure(figsize=(14, 8))
plt.bar(top_locals['nombre_local'], top_locals['avg_rating'], color='skyblue')

plt.xlabel('Nombre del Local')
plt.ylabel('Promedio de Calificación')
plt.title('Top 20 Locales y su Promedio de Calificación')
plt.xticks(rotation=90)  

plt.tight_layout()
plt.show()

# %%
merged_df.to_csv(r"C:\Users\jessi\Desktop\Proyecto Final Henry\Texas.csv", index=False)
