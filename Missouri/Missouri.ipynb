# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from textblob import TextBlob
from scipy import stats
import folium as folium
from IPython.display import display
import geopandas as gpd
from shapely.geometry import Point
import contextily as ctx

# %% [markdown]
# ### Lectura del archivo Missouri.json

# %%
df= pd.read_json(r"C:\Users\jessi\Desktop\Horizon_Project\Missouri\Missouri.json",lines=True)

# %%
df.head()
# Out:
#         user_id                       name  rating  \
# 0  1.056639e+20  CryStyles By Stylz Wilson       5
# 1  1.067784e+20             Jason Goldkamp       2
# 2  1.094327e+20            Joseph Tehandon       5
# 3  1.088725e+20           Cheryle Robinson       3
# 4  1.034449e+20         Jeannette Copeland       1
#
#                                                 text  resp  \
# 0  Taco Tuesdays is when I go and they are really...  None
# 1  The food is 4.5 stars. Really tasty. But don't...  None
# 2  Food was real good and the drinks kept coming,...  None
# 3  Service is extremely slow but good food. Love ...  None
# 4  Made a drive out to Cherokee st this evening a...  None
#
#                                  gmap_id
# 0  0x87d8b473f54a5c5b:0x435f2a4495096c0d
# 1  0x87d8b473f54a5c5b:0x435f2a4495096c0d
# 2  0x87d8b473f54a5c5b:0x435f2a4495096c0d
# 3  0x87d8b473f54a5c5b:0x435f2a4495096c0d
# 4  0x87d8b473f54a5c5b:0x435f2a4495096c0d

# %% [markdown]
# ### Lectura del archivo "df_gastronomico_ciudades.json "

# %%
df2=pd.read_json(r"C:\Users\jessi\Desktop\Horizon_Project\Washington\df_gastronomico_ciudades.json",lines=True)

# %%
df2.head()
# Out:
#                            nombre_local                     direccion  \
# 0  Creole Orleans Catering & Food Truck  2841 Greenbriar Pkwy SW N317
# 1               Biswas Grocery and Cafe            2853 Buford Hwy NE
# 2                           Noodle Cafe        233 Peachtree St # B70
# 3  Creole Orleans Catering & Food Truck  2841 Greenbriar Pkwy SW N317
# 4               Biswas Grocery and Cafe            2853 Buford Hwy NE
#
#     ciudad codigo_postal_cod_ciudad codigo_ciudad codigo_postal  \
# 0  Atlanta                 GA 30331            GA         30331
# 1  Atlanta                 GA 30329            GA         30329
# 2  Atlanta                 GA 30303            GA         30303
# 3  Atlanta                 GA 30331            GA         30331
# 4  Atlanta                 GA 30329            GA         30329
#
#                                  gmap_id   latitude  longitude  \
# 0  0x88f503d71429c049:0xef40e07a5479b1c2  33.689032 -84.495097
# 1  0x88f507f3e1cde31d:0x1bcd2bb2f0555399  33.831454 -84.341647
# 2  0x88f5047831dfc86d:0x985e3a6645f5ca4f  33.760404 -84.386319
# 3  0x88f503d71429c049:0xef40e07a5479b1c2  33.689032 -84.495097
# 4  0x88f507f3e1cde31d:0x1bcd2bb2f0555399  33.831454 -84.341647
#
#                                             category  avg_rating  \
# 0  [Creole restaurant, Caribbean restaurant, Cate...         4.7
# 1  [Organic food store, Convenience store, Phone ...         4.7
# 2                      [Thai restaurant, Restaurant]         4.2
# 3  [Creole restaurant, Caribbean restaurant, Cate...         4.7
# 4  [Organic food store, Convenience store, Phone ...         4.7
#
#    num_of_reviews price                                               MISC
# 0              31  None  {'Service options': ['Delivery', 'Takeout', 'D...
# 1              25  None  {'Service options': ['Delivery', 'In-store sho...
# 2              35  None  {'Service options': ['Takeout', 'Dine-in', 'De...
# 3              31  None  {'Service options': ['Delivery', 'Takeout', 'D...
# 4              25  None  {'Service options': ['Delivery', 'In-store sho...

# %% [markdown]
# ### Informacion General

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13040 entries, 0 to 13039
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   user_id  13040 non-null  float64
#  1   name     13040 non-null  object
#  2   rating   13040 non-null  int64
#  3   text     7790 non-null   object
#  4   resp     1160 non-null   object
#  5   gmap_id  13040 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 611.4+ KB
# None

# %%
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18037 entries, 0 to 18036
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   nombre_local              18037 non-null  object
#  1   direccion                 18037 non-null  object
#  2   ciudad                    18037 non-null  object
#  3   codigo_postal_cod_ciudad  18037 non-null  object
#  4   codigo_ciudad             18037 non-null  object
#  5   codigo_postal             18037 non-null  object
#  6   gmap_id                   18037 non-null  object
#  7   latitude                  18037 non-null  float64
#  8   longitude                 18037 non-null  float64
#  9   category                  18037 non-null  object
#  10  avg_rating                18037 non-null  float64
#  11  num_of_reviews            18037 non-null  int64
#  12  price                     8690 non-null   object
#  13  MISC                      17614 non-null  object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 1.9+ MB
# None

# %% [markdown]
# ### Descripción de los dataframe

# %%
df['rating'].describe()
# Out:
# count    13040.000000
# mean         4.279678
# std          1.120989
# min          1.000000
# 25%          4.000000
# 50%          5.000000
# 75%          5.000000
# max          5.000000
# Name: rating, dtype: float64

# %%
df2.describe()
# Out:
#            latitude     longitude    avg_rating  num_of_reviews
# count  18037.000000  18037.000000  18037.000000    18037.000000
# mean      38.290007    -92.404179      4.137573       70.622276
# std        4.948144     18.621202      0.575608      143.090909
# min       25.993710   -122.805295      1.000000        1.000000
# 25%       34.055071   -118.186637      3.900000       17.000000
# 50%       39.943207    -86.808270      4.200000       38.000000
# 75%       40.831310    -74.145373      4.500000       78.000000
# max       47.682747    -71.145040      5.000000     5321.000000

# %% [markdown]
# ### Análisis de Datos Nulos

# %%
print(df.isnull().sum())
# Out:
# user_id        0
# name           0
# rating         0
# text        5250
# resp       11880
# gmap_id        0
# dtype: int64

# %%
print(df2.isnull().sum())
# Out:
# nombre_local                   0
# direccion                      0
# ciudad                         0
# codigo_postal_cod_ciudad       0
# codigo_ciudad                  0
# codigo_postal                  0
# gmap_id                        0
# latitude                       0
# longitude                      0
# category                       0
# avg_rating                     0
# num_of_reviews                 0
# price                       9347
# MISC                         423
# dtype: int64

# %% [markdown]
# ### Outliers

# %%
rating = df['rating']

# Calcular el IQR para la columna 'rating'
Q1 = rating.quantile(0.25)
Q3 = rating.quantile(0.75)
IQR = Q3 - Q1

# Identificar outliers usando IQR
outliers_iqr = rating[(rating < (Q1 - 1.5 * IQR)) | (rating > (Q3 + 1.5 * IQR))]
print("Outliers en la columna 'rating' usando IQR:")
print(outliers_iqr)

# Calcular Z-score para la columna 'rating'
z_scores = stats.zscore(rating)
abs_z_scores = abs(z_scores)

# Identificar outliers con Z-score mayor que 3
outliers_z = rating[abs_z_scores > 3]
print("Outliers en la columna 'rating' usando Z-score:")
print(outliers_z)

# Graficar el boxplot para 'rating'
plt.figure(figsize=(10, 6))
sns.boxplot(x=rating)
plt.title('Boxplot de rating')
plt.show()
# Out:
# Outliers en la columna 'rating' usando IQR:
# 1        2
# 4        1
# 6        2
# 8        1
# 12       2
#         ..
# 12870    1
# 12881    2
# 12904    2
# 12959    2
# 13014    1
# Name: rating, Length: 1179, dtype: int64
# Outliers en la columna 'rating' usando Z-score:
# Series([], Name: rating, dtype: int64)

# %%
columns_to_check = ['avg_rating']

Q1 = df2[columns_to_check].quantile(0.25)
Q3 = df2[columns_to_check].quantile(0.75)
IQR = Q3 - Q1

outliers_iqr = df2[(df2[columns_to_check] < (Q1 - 1.5 * IQR)) | (df2[columns_to_check] > (Q3 + 1.5 * IQR))]

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.boxplot(x=df2['avg_rating'])
plt.title('Outliers de Average Rating')



plt.show()

# %%
num_of_reviews = df2['num_of_reviews']

Q1 = num_of_reviews.quantile(0.25)
Q3 = num_of_reviews.quantile(0.75)
IQR = Q3 - Q1

outliers_iqr = num_of_reviews[(num_of_reviews < (Q1 - 1.5 * IQR)) | (num_of_reviews > (Q3 + 1.5 * IQR))]
print("Outliers en la columna 'num_of_reviews' usando IQR:")
print(outliers_iqr)

z_scores = stats.zscore(num_of_reviews)
abs_z_scores = abs(z_scores)

outliers_z = num_of_reviews[abs_z_scores > 3]
print("Outliers en la columna 'num_of_reviews' usando Z-score:")
print(outliers_z)

plt.figure(figsize=(10, 6))
sns.boxplot(x=num_of_reviews)
plt.title('Outliers Número de Reviews')
plt.show()
# Out:
# Outliers en la columna 'num_of_reviews' usando IQR:
# 124      798
# 206      178
# 217      496
# 224      214
# 229      768
#         ...
# 18019    238
# 18024    244
# 18027    292
# 18029    178
# 18031    238
# Name: num_of_reviews, Length: 1371, dtype: int64
# Outliers en la columna 'num_of_reviews' usando Z-score:
# 124       798
# 229       768
# 233      1018
# 237      3128
# 238      1373
#          ...
# 17884     798
# 17890    1108
# 17892    1208
# 17893    1351
# 17901     624
# Name: num_of_reviews, Length: 171, dtype: int64

# %% [markdown]
# ### Histogramas de distribución

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['rating'], bins=10)
plt.title('Distribución de Raiting DF')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
avg_rating = df2['avg_rating']
num_of_reviews = df2['num_of_reviews']

plt.figure(figsize=(14, 12))

plt.subplot(2, 2, 1)
sns.histplot(avg_rating, bins=30, kde=False)
plt.title('Histograma de puntaje promedio')
plt.xlabel('avg_rating')
plt.ylabel('Frecuencia')

plt.subplot(2, 2, 3)
sns.histplot(num_of_reviews, bins=20, kde=False)
plt.title('Histograma de número de reviews')
plt.xlabel('num_of_reviews')
plt.ylabel('Frecuencia')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Análisis de sentimientos

# %%
df['text'] = df['text'].fillna('')

# %%
def get_sentiment(text):
    return TextBlob(text).sentiment.polarity

df['review_sentiment'] = df['text'].apply(get_sentiment)

print(df[['text', 'review_sentiment']].head())
# Out:
#                                                 text  review_sentiment
# 0  Taco Tuesdays is when I go and they are really...          0.650000
# 1  The food is 4.5 stars. Really tasty. But don't...         -0.003935
# 2  Food was real good and the drinks kept coming,...          0.900000
# 3  Service is extremely slow but good food. Love ...          0.300000
# 4  Made a drive out to Cherokee st this evening a...         -0.550000

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.histplot(df['review_sentiment'], bins=10, kde=True)
plt.title('Distribución de Sentimientos en Reviews')
plt.xlabel('Sentimiento')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ### Unión de datasets

# %%
merged_df = pd.merge(df, df2, on='gmap_id', how='inner')

# %%
merged_df
# Out:
#             user_id                       name  rating  \
# 0      1.056639e+20  CryStyles By Stylz Wilson       5
# 1      1.056639e+20  CryStyles By Stylz Wilson       5
# 2      1.067784e+20             Jason Goldkamp       2
# 3      1.067784e+20             Jason Goldkamp       2
# 4      1.094327e+20            Joseph Tehandon       5
# ...             ...                        ...     ...
# 13057  1.154172e+20               Spencer Nash       5
# 13058  1.152271e+20                Rich Shelby       5
# 13059  1.100035e+20           Michael Lonergan       5
# 13060  1.106560e+20                  amy jones       5
# 13061  1.043326e+20                jen Ritchie       5
#
#                                                     text  \
# 0      Taco Tuesdays is when I go and they are really...
# 1      Taco Tuesdays is when I go and they are really...
# 2      The food is 4.5 stars. Really tasty. But don't...
# 3      The food is 4.5 stars. Really tasty. But don't...
# 4      Food was real good and the drinks kept coming,...
# ...                                                  ...
# 13057
# 13058
# 13059
# 13060
# 13061
#
#                                                     resp  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 13057       {'time': 1549814730555, 'text': 'Thank you'}
# 13058       {'time': 1491678669167, 'text': 'Thank you'}
# 13059  {'time': 1568657638006, 'text': 'Thank you Mic...
# 13060   {'time': 1582834035109, 'text': 'Thank you Amy'}
# 13061       {'time': 1545750345170, 'text': 'Thank you'}
#
#                                      gmap_id  review_sentiment  \
# 0      0x87d8b473f54a5c5b:0x435f2a4495096c0d          0.650000
# 1      0x87d8b473f54a5c5b:0x435f2a4495096c0d          0.650000
# 2      0x87d8b473f54a5c5b:0x435f2a4495096c0d         -0.003935
# 3      0x87d8b473f54a5c5b:0x435f2a4495096c0d         -0.003935
# 4      0x87d8b473f54a5c5b:0x435f2a4495096c0d          0.900000
# ...                                      ...               ...
# 13057  0x87d8b68daff7f5e9:0x27d97ffea5caa24d          0.000000
# 13058  0x87d8b68daff7f5e9:0x27d97ffea5caa24d          0.000000
# 13059  0x87d8b68daff7f5e9:0x27d97ffea5caa24d          0.000000
# 13060  0x87d8b68daff7f5e9:0x27d97ffea5caa24d          0.000000
# 13061  0x87d8b68daff7f5e9:0x27d97ffea5caa24d          0.000000
#
#                    nombre_local         direccion     ciudad  \
# 0      Taco Truck Bar and Grill  2737 Cherokee St  St. Louis
# 1      Taco Truck Bar and Grill  2737 Cherokee St  St. Louis
# 2      Taco Truck Bar and Grill  2737 Cherokee St  St. Louis
# 3      Taco Truck Bar and Grill  2737 Cherokee St  St. Louis
# 4      Taco Truck Bar and Grill  2737 Cherokee St  St. Louis
# ...                         ...               ...        ...
# 13057                    Bar:PM   7109 S Broadway  St. Louis
# 13058                    Bar:PM   7109 S Broadway  St. Louis
# 13059                    Bar:PM   7109 S Broadway  St. Louis
# 13060                    Bar:PM   7109 S Broadway  St. Louis
# 13061                    Bar:PM   7109 S Broadway  St. Louis
#
#       codigo_postal_cod_ciudad codigo_ciudad codigo_postal   latitude  \
# 0                     MO 63118            MO         63118  38.593842
# 1                     MO 63118            MO         63118  38.593842
# 2                     MO 63118            MO         63118  38.593842
# 3                     MO 63118            MO         63118  38.593842
# 4                     MO 63118            MO         63118  38.593842
# ...                        ...           ...           ...        ...
# 13057                 MO 63111            MO         63111  38.550923
# 13058                 MO 63111            MO         63111  38.550923
# 13059                 MO 63111            MO         63111  38.550923
# 13060                 MO 63111            MO         63111  38.550923
# 13061                 MO 63111            MO         63111  38.550923
#
#        longitude                           category  avg_rating  \
# 0     -90.229106               [Mexican restaurant]         3.6
# 1     -90.229106               [Mexican restaurant]         3.6
# 2     -90.229106               [Mexican restaurant]         3.6
# 3     -90.229106               [Mexican restaurant]         3.6
# 4     -90.229106               [Mexican restaurant]         3.6
# ...          ...                                ...         ...
# 13057 -90.254215  [Bar, Cocktail bar, Gay bar, Pub]         4.8
# 13058 -90.254215  [Bar, Cocktail bar, Gay bar, Pub]         4.8
# 13059 -90.254215  [Bar, Cocktail bar, Gay bar, Pub]         4.8
# 13060 -90.254215  [Bar, Cocktail bar, Gay bar, Pub]         4.8
# 13061 -90.254215  [Bar, Cocktail bar, Gay bar, Pub]         4.8
#
#        num_of_reviews price                                               MISC
# 0                  18     $  {'Service options': ['Delivery'], 'Amenities':...
# 1                  18     $  {'Service options': ['Delivery'], 'Amenities':...
# 2                  18     $  {'Service options': ['Delivery'], 'Amenities':...
# 3                  18     $  {'Service options': ['Delivery'], 'Amenities':...
# 4                  18     $  {'Service options': ['Delivery'], 'Amenities':...
# ...               ...   ...                                                ...
# 13057             138     $  {'Service options': ['Outdoor seating', 'Deliv...
# 13058             138     $  {'Service options': ['Outdoor seating', 'Deliv...
# 13059             138     $  {'Service options': ['Outdoor seating', 'Deliv...
# 13060             138     $  {'Service options': ['Outdoor seating', 'Deliv...
# 13061             138     $  {'Service options': ['Outdoor seating', 'Deliv...
#
# [13062 rows x 20 columns]

# %% [markdown]
# ### Gráfico de los 20 restaurants con más reviews

# %%
local_comment_counts = merged_df['nombre_local'].value_counts().reset_index()
local_comment_counts.columns = ['nombre_local', 'num_of_reviews']

# Seleccionar los 20 locales con más comentarios
top_locals = local_comment_counts.head(20)

# Mostrar el ranking
print(top_locals)
# Out:
#                         nombre_local  num_of_reviews
# 0                  Seamus McDaniel's             969
# 1    Olympia Kebob House and Taverna             878
# 2                 Taqueria El Bronco             695
# 3                           Hardee's             614
# 4                        Imo's Pizza             375
# 5                             Subway             263
# 6                      Smoothie King             240
# 7                           Wingstop             239
# 8                South Public Market             202
# 9                     Domino's Pizza             194
# 10                 Papa John's Pizza             193
# 11                   Bono's Pizzeria             186
# 12  Mike Talaynas JUKEBOX Restaurant             174
# 13                       Jet's Pizza             164
# 14                      Pickles Deli             158
# 15               St. Louis FatBurger             157
# 16        Cecil Whittaker's Pizzeria             154
# 17                         Pizza Hut             153
# 18                      Asia Gourmet             149
# 19        Louisiana Fish and Chicken             147

# %%
plt.figure(figsize=(12, 8))
plt.bar(top_locals['nombre_local'], top_locals['num_of_reviews'], color='skyblue')

plt.xlabel('Nombre del Local')
plt.ylabel('Número de Comentarios')
plt.title('Top 20 Locales con Más Comentarios')
plt.xticks(rotation=90)  

plt.tight_layout()
plt.show()

# %%
local_comment_counts = merged_df.groupby('nombre_local').agg(
    num_of_reviews=('nombre_local', 'count'),
    avg_rating=('avg_rating', 'mean')
).reset_index()

top_locals = local_comment_counts.sort_values(by='num_of_reviews', ascending=False).head(20)

plt.figure(figsize=(14, 8))
plt.bar(top_locals['nombre_local'], top_locals['avg_rating'], color='skyblue')

plt.xlabel('Nombre del Local')
plt.ylabel('Promedio de Calificación')
plt.title('Top 20 Locales y su Promedio de Calificación')
plt.xticks(rotation=90)  

plt.tight_layout()
plt.show()

# %%
merged_df.to_csv(r"C:\Users\jessi\Desktop\Proyecto Final Henry\Missouri.csv", index=False)
