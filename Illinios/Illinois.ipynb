# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from textblob import TextBlob
from scipy import stats
import folium as folium
from IPython.display import display
import geopandas as gpd
from shapely.geometry import Point
import contextily as ctx

# %% [markdown]
# ### Lectura del archivo Illinois.json

# %%
df= pd.read_json(r"C:\Users\jessi\Desktop\Horizon_Project\Illinios\Illinois.json",lines=True)

# %%
df.head()
# Out:
#         user_id                  name  rating  \
# 0  1.032768e+20          Scott Loring       4
# 1  1.021772e+20      Sean Doe-Simkins       4
# 2  1.066865e+20          Zorin Dobson       4
# 3  1.075252e+20             Ryan Park       2
# 4  1.136892e+20  Mohammad Abdelwassie       4
#
#                                                 text  resp  \
# 0  I ate here with friends for restaurant week. I...  None
# 1  Don't be put off by the fact that it's in a ho...  None
# 2  I have to give fair warning for the next stop ...  None
# 3  Would never go back again.  Had the bouillabas...  None
# 4  I had one of the best experiences in my life i...  None
#
#                                  gmap_id
# 0  0x880e2ca867ab1e83:0x2d74d09c9e2daec6
# 1  0x880e2ca867ab1e83:0x2d74d09c9e2daec6
# 2  0x880e2ca867ab1e83:0x2d74d09c9e2daec6
# 3  0x880e2ca867ab1e83:0x2d74d09c9e2daec6
# 4  0x880e2ca867ab1e83:0x2d74d09c9e2daec6

# %% [markdown]
# ### Lectura del archivo "df_gastronomico_ciudades.json "

# %%
df2=pd.read_json(r"C:\Users\jessi\Desktop\Horizon_Project\Washington\df_gastronomico_ciudades.json",lines=True)

# %%
df2.head()
# Out:
#                            nombre_local                     direccion  \
# 0  Creole Orleans Catering & Food Truck  2841 Greenbriar Pkwy SW N317
# 1               Biswas Grocery and Cafe            2853 Buford Hwy NE
# 2                           Noodle Cafe        233 Peachtree St # B70
# 3  Creole Orleans Catering & Food Truck  2841 Greenbriar Pkwy SW N317
# 4               Biswas Grocery and Cafe            2853 Buford Hwy NE
#
#     ciudad codigo_postal_cod_ciudad codigo_ciudad codigo_postal  \
# 0  Atlanta                 GA 30331            GA         30331
# 1  Atlanta                 GA 30329            GA         30329
# 2  Atlanta                 GA 30303            GA         30303
# 3  Atlanta                 GA 30331            GA         30331
# 4  Atlanta                 GA 30329            GA         30329
#
#                                  gmap_id   latitude  longitude  \
# 0  0x88f503d71429c049:0xef40e07a5479b1c2  33.689032 -84.495097
# 1  0x88f507f3e1cde31d:0x1bcd2bb2f0555399  33.831454 -84.341647
# 2  0x88f5047831dfc86d:0x985e3a6645f5ca4f  33.760404 -84.386319
# 3  0x88f503d71429c049:0xef40e07a5479b1c2  33.689032 -84.495097
# 4  0x88f507f3e1cde31d:0x1bcd2bb2f0555399  33.831454 -84.341647
#
#                                             category  avg_rating  \
# 0  [Creole restaurant, Caribbean restaurant, Cate...         4.7
# 1  [Organic food store, Convenience store, Phone ...         4.7
# 2                      [Thai restaurant, Restaurant]         4.2
# 3  [Creole restaurant, Caribbean restaurant, Cate...         4.7
# 4  [Organic food store, Convenience store, Phone ...         4.7
#
#    num_of_reviews price                                               MISC
# 0              31  None  {'Service options': ['Delivery', 'Takeout', 'D...
# 1              25  None  {'Service options': ['Delivery', 'In-store sho...
# 2              35  None  {'Service options': ['Takeout', 'Dine-in', 'De...
# 3              31  None  {'Service options': ['Delivery', 'Takeout', 'D...
# 4              25  None  {'Service options': ['Delivery', 'In-store sho...

# %% [markdown]
# ### Informacion General

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50066 entries, 0 to 50065
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   user_id  50066 non-null  float64
#  1   name     50066 non-null  object
#  2   rating   50066 non-null  int64
#  3   text     29087 non-null  object
#  4   resp     3474 non-null   object
#  5   gmap_id  50066 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 2.3+ MB
# None

# %%
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18037 entries, 0 to 18036
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   nombre_local              18037 non-null  object
#  1   direccion                 18037 non-null  object
#  2   ciudad                    18037 non-null  object
#  3   codigo_postal_cod_ciudad  18037 non-null  object
#  4   codigo_ciudad             18037 non-null  object
#  5   codigo_postal             18037 non-null  object
#  6   gmap_id                   18037 non-null  object
#  7   latitude                  18037 non-null  float64
#  8   longitude                 18037 non-null  float64
#  9   category                  18037 non-null  object
#  10  avg_rating                18037 non-null  float64
#  11  num_of_reviews            18037 non-null  int64
#  12  price                     8690 non-null   object
#  13  MISC                      17614 non-null  object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 1.9+ MB
# None

# %% [markdown]
# ### Descripción de los dataframe

# %%
df['rating'].describe()
# Out:
# count    50066.000000
# mean         4.235988
# std          1.131720
# min          1.000000
# 25%          4.000000
# 50%          5.000000
# 75%          5.000000
# max          5.000000
# Name: rating, dtype: float64

# %%
df2.describe()
# Out:
#            latitude     longitude    avg_rating  num_of_reviews
# count  18037.000000  18037.000000  18037.000000    18037.000000
# mean      38.290007    -92.404179      4.137573       70.622276
# std        4.948144     18.621202      0.575608      143.090909
# min       25.993710   -122.805295      1.000000        1.000000
# 25%       34.055071   -118.186637      3.900000       17.000000
# 50%       39.943207    -86.808270      4.200000       38.000000
# 75%       40.831310    -74.145373      4.500000       78.000000
# max       47.682747    -71.145040      5.000000     5321.000000

# %% [markdown]
# ### Análisis de Datos Nulos

# %%
print(df.isnull().sum())
# Out:
# user_id        0
# name           0
# rating         0
# text       20979
# resp       46592
# gmap_id        0
# dtype: int64

# %%
print(df2.isnull().sum())
# Out:
# nombre_local                   0
# direccion                      0
# ciudad                         0
# codigo_postal_cod_ciudad       0
# codigo_ciudad                  0
# codigo_postal                  0
# gmap_id                        0
# latitude                       0
# longitude                      0
# category                       0
# avg_rating                     0
# num_of_reviews                 0
# price                       9347
# MISC                         423
# dtype: int64

# %% [markdown]
# ### Outliers

# %%
rating = df['rating']

# Calcular el IQR para la columna 'rating'
Q1 = rating.quantile(0.25)
Q3 = rating.quantile(0.75)
IQR = Q3 - Q1

# Identificar outliers usando IQR
outliers_iqr = rating[(rating < (Q1 - 1.5 * IQR)) | (rating > (Q3 + 1.5 * IQR))]
print("Outliers en la columna 'rating' usando IQR:")
print(outliers_iqr)

# Calcular Z-score para la columna 'rating'
z_scores = stats.zscore(rating)
abs_z_scores = abs(z_scores)

# Identificar outliers con Z-score mayor que 3
outliers_z = rating[abs_z_scores > 3]
print("Outliers en la columna 'rating' usando Z-score:")
print(outliers_z)

# Graficar el boxplot para 'rating'
plt.figure(figsize=(10, 6))
sns.boxplot(x=rating)
plt.title('Boxplot de rating')
plt.show()
# Out:
# Outliers en la columna 'rating' usando IQR:
# 3        2
# 20       2
# 34       1
# 51       2
# 133      2
#         ..
# 49956    2
# 49973    1
# 49981    2
# 50034    1
# 50039    1
# Name: rating, Length: 4638, dtype: int64
# Outliers en la columna 'rating' usando Z-score:
# Series([], Name: rating, dtype: int64)

# %%
columns_to_check = ['avg_rating']

Q1 = df2[columns_to_check].quantile(0.25)
Q3 = df2[columns_to_check].quantile(0.75)
IQR = Q3 - Q1

outliers_iqr = df2[(df2[columns_to_check] < (Q1 - 1.5 * IQR)) | (df2[columns_to_check] > (Q3 + 1.5 * IQR))]

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.boxplot(x=df2['avg_rating'])
plt.title('Outliers de Average Rating')



plt.show()

# %%
num_of_reviews = df2['num_of_reviews']

Q1 = num_of_reviews.quantile(0.25)
Q3 = num_of_reviews.quantile(0.75)
IQR = Q3 - Q1

outliers_iqr = num_of_reviews[(num_of_reviews < (Q1 - 1.5 * IQR)) | (num_of_reviews > (Q3 + 1.5 * IQR))]
print("Outliers en la columna 'num_of_reviews' usando IQR:")
print(outliers_iqr)

z_scores = stats.zscore(num_of_reviews)
abs_z_scores = abs(z_scores)

outliers_z = num_of_reviews[abs_z_scores > 3]
print("Outliers en la columna 'num_of_reviews' usando Z-score:")
print(outliers_z)

plt.figure(figsize=(10, 6))
sns.boxplot(x=num_of_reviews)
plt.title('Outliers Número de Reviews')
plt.show()
# Out:
# Outliers en la columna 'num_of_reviews' usando IQR:
# 124      798
# 206      178
# 217      496
# 224      214
# 229      768
#         ...
# 18019    238
# 18024    244
# 18027    292
# 18029    178
# 18031    238
# Name: num_of_reviews, Length: 1371, dtype: int64
# Outliers en la columna 'num_of_reviews' usando Z-score:
# 124       798
# 229       768
# 233      1018
# 237      3128
# 238      1373
#          ...
# 17884     798
# 17890    1108
# 17892    1208
# 17893    1351
# 17901     624
# Name: num_of_reviews, Length: 171, dtype: int64

# %% [markdown]
# ### Histogramas de distribución

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['rating'], bins=10)
plt.title('Distribución de Raiting DF')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
avg_rating = df2['avg_rating']
num_of_reviews = df2['num_of_reviews']

plt.figure(figsize=(14, 12))

plt.subplot(2, 2, 1)
sns.histplot(avg_rating, bins=30, kde=False)
plt.title('Histograma de puntaje promedio')
plt.xlabel('avg_rating')
plt.ylabel('Frecuencia')

plt.subplot(2, 2, 3)
sns.histplot(num_of_reviews, bins=20, kde=False)
plt.title('Histograma de número de reviews')
plt.xlabel('num_of_reviews')
plt.ylabel('Frecuencia')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Análisis de sentimientos

# %%
df['text'] = df['text'].fillna('')

# %%
def get_sentiment(text):
    return TextBlob(text).sentiment.polarity

df['review_sentiment'] = df['text'].apply(get_sentiment)

print(df[['text', 'review_sentiment']].head())
# Out:
#                                                 text  review_sentiment
# 0  I ate here with friends for restaurant week. I...          0.588889
# 1  Don't be put off by the fact that it's in a ho...          0.470833
# 2  I have to give fair warning for the next stop ...          0.147783
# 3  Would never go back again.  Had the bouillabas...         -0.225000
# 4  I had one of the best experiences in my life i...          1.000000

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.histplot(df['review_sentiment'], bins=10, kde=True)
plt.title('Distribución de Sentimientos en Reviews')
plt.xlabel('Sentimiento')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ### Unión de datasets

# %%
merged_df = pd.merge(df, df2, on='gmap_id', how='inner')

# %%
merged_df
# Out:
#             user_id                                 name  rating  \
# 0      1.032768e+20                         Scott Loring       4
# 1      1.032768e+20                         Scott Loring       4
# 2      1.021772e+20                     Sean Doe-Simkins       4
# 3      1.021772e+20                     Sean Doe-Simkins       4
# 4      1.066865e+20                         Zorin Dobson       4
# ...             ...                                  ...     ...
# 50095  1.083009e+20                     Andrea Lopez-Roa       5
# 50096  1.151016e+20  Nicolás Silva-Santisteban Stevenson       5
# 50097  1.103779e+20                   Christopher Madden       5
# 50098  1.016382e+20               Tykiera Olive-Stalling       4
# 50099  1.021363e+20                         Mayle Kobets       5
#
#                                                     text  resp  \
# 0      I ate here with friends for restaurant week. I...  None
# 1      I ate here with friends for restaurant week. I...  None
# 2      Don't be put off by the fact that it's in a ho...  None
# 3      Don't be put off by the fact that it's in a ho...  None
# 4      I have to give fair warning for the next stop ...  None
# ...                                                  ...   ...
# 50095                                                     None
# 50096                                                     None
# 50097                                                     None
# 50098                                                     None
# 50099                                                     None
#
#                                      gmap_id  review_sentiment  \
# 0      0x880e2ca867ab1e83:0x2d74d09c9e2daec6          0.588889
# 1      0x880e2ca867ab1e83:0x2d74d09c9e2daec6          0.588889
# 2      0x880e2ca867ab1e83:0x2d74d09c9e2daec6          0.470833
# 3      0x880e2ca867ab1e83:0x2d74d09c9e2daec6          0.470833
# 4      0x880e2ca867ab1e83:0x2d74d09c9e2daec6          0.147783
# ...                                      ...               ...
# 50095  0x880fd2cedd896ab5:0xc61f4b43eb7ad0ee          0.000000
# 50096  0x880fd2cedd896ab5:0xc61f4b43eb7ad0ee          0.000000
# 50097  0x880fd2cedd896ab5:0xc61f4b43eb7ad0ee          0.000000
# 50098  0x880fd2cedd896ab5:0xc61f4b43eb7ad0ee          0.000000
# 50099  0x880fd2cedd896ab5:0xc61f4b43eb7ad0ee          0.000000
#
#                  nombre_local           direccion   ciudad  \
# 0                        Aria   200 N Columbus Dr  Chicago
# 1                        Aria   200 N Columbus Dr  Chicago
# 2                        Aria   200 N Columbus Dr  Chicago
# 3                        Aria   200 N Columbus Dr  Chicago
# 4                        Aria   200 N Columbus Dr  Chicago
# ...                       ...                 ...      ...
# 50095  The Lifeway Kefir Shop  1745 W Division St  Chicago
# 50096  The Lifeway Kefir Shop  1745 W Division St  Chicago
# 50097  The Lifeway Kefir Shop  1745 W Division St  Chicago
# 50098  The Lifeway Kefir Shop  1745 W Division St  Chicago
# 50099  The Lifeway Kefir Shop  1745 W Division St  Chicago
#
#       codigo_postal_cod_ciudad codigo_ciudad codigo_postal   latitude  \
# 0                     IL 60601            IL         60601  41.886012
# 1                     IL 60601            IL         60601  41.886012
# 2                     IL 60601            IL         60601  41.886012
# 3                     IL 60601            IL         60601  41.886012
# 4                     IL 60601            IL         60601  41.886012
# ...                        ...           ...           ...        ...
# 50095                 IL 60622            IL         60622  41.903068
# 50096                 IL 60622            IL         60622  41.903068
# 50097                 IL 60622            IL         60622  41.903068
# 50098                 IL 60622            IL         60622  41.903068
# 50099                 IL 60622            IL         60622  41.903068
#
#        longitude                                           category  \
# 0     -87.620938             [Restaurant, American restaurant, Bar]
# 1     -87.620938             [Restaurant, American restaurant, Bar]
# 2     -87.620938             [Restaurant, American restaurant, Bar]
# 3     -87.620938             [Restaurant, American restaurant, Bar]
# 4     -87.620938             [Restaurant, American restaurant, Bar]
# ...          ...                                                ...
# 50095 -87.671701  [Frozen yogurt shop, Cafe, Dessert shop, Froze...
# 50096 -87.671701  [Frozen yogurt shop, Cafe, Dessert shop, Froze...
# 50097 -87.671701  [Frozen yogurt shop, Cafe, Dessert shop, Froze...
# 50098 -87.671701  [Frozen yogurt shop, Cafe, Dessert shop, Froze...
# 50099 -87.671701  [Frozen yogurt shop, Cafe, Dessert shop, Froze...
#
#        avg_rating  num_of_reviews price  \
# 0             3.9              18  None
# 1             3.9              18  None
# 2             3.9              18  None
# 3             3.9              18  None
# 4             3.9              18  None
# ...           ...             ...   ...
# 50095         4.6             102     $
# 50096         4.6             102     $
# 50097         4.6             102     $
# 50098         4.6             102     $
# 50099         4.6             102     $
#
#                                                     MISC
# 0      {'Service options': ['Delivery'], 'Highlights'...
# 1      {'Service options': ['Delivery'], 'Highlights'...
# 2      {'Service options': ['Delivery'], 'Highlights'...
# 3      {'Service options': ['Delivery'], 'Highlights'...
# 4      {'Service options': ['Delivery'], 'Highlights'...
# ...                                                  ...
# 50095  {'Service options': ['Delivery', 'In-store pic...
# 50096  {'Service options': ['Delivery', 'In-store pic...
# 50097  {'Service options': ['Delivery', 'In-store pic...
# 50098  {'Service options': ['Delivery', 'In-store pic...
# 50099  {'Service options': ['Delivery', 'In-store pic...
#
# [50100 rows x 20 columns]

# %% [markdown]
# ### Gráfico de los 20 restaurants con más reviews

# %%
local_comment_counts = merged_df['nombre_local'].value_counts().reset_index()
local_comment_counts.columns = ['nombre_local', 'num_of_reviews']

# Seleccionar los 20 locales con más comentarios
top_locals = local_comment_counts.head(20)

# Mostrar el ranking
print(top_locals)
# Out:
#                     nombre_local  num_of_reviews
# 0               Ponce Restaurant            1654
# 1                         Subway            1345
# 2                      Starbucks            1312
# 3        Mi Tierra En La Villita            1177
# 4                   The Publican            1143
# 5           Devil Dawgs on State            1010
# 6                        Dunkin'             982
# 7               Las Islas Marias             644
# 8                      Taco Bell             527
# 9                   Jimmy John's             472
# 10                 Naf Naf Grill             436
# 11                      Cafecito             396
# 12                     Pizza Hut             368
# 13                      Wingstop             334
# 14             Izalco Restaurant             327
# 15      Machetes Big Quesadillas             311
# 16                   Nepal House             310
# 17                Duk's Red HOTS             304
# 18  Opart Thai House - West Town             294
# 19                     De Pasada             289

# %%
plt.figure(figsize=(12, 8))
plt.bar(top_locals['nombre_local'], top_locals['num_of_reviews'], color='skyblue')

plt.xlabel('Nombre del Local')
plt.ylabel('Número de Comentarios')
plt.title('Top 20 Locales con Más Comentarios')
plt.xticks(rotation=90)  

plt.tight_layout()
plt.show()

# %%
local_comment_counts = merged_df.groupby('nombre_local').agg(
    num_of_reviews=('nombre_local', 'count'),
    avg_rating=('avg_rating', 'mean')
).reset_index()

top_locals = local_comment_counts.sort_values(by='num_of_reviews', ascending=False).head(20)

plt.figure(figsize=(14, 8))
plt.bar(top_locals['nombre_local'], top_locals['avg_rating'], color='skyblue')

plt.xlabel('Nombre del Local')
plt.ylabel('Promedio de Calificación')
plt.title('Top 20 Locales y su Promedio de Calificación')
plt.xticks(rotation=90)  

plt.tight_layout()
plt.show()

# %%
merged_df.to_csv(r"C:\Users\jessi\Desktop\Proyecto Final Henry\Illinois.csv", index=False)
