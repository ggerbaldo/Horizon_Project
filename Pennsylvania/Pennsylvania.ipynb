# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from textblob import TextBlob
from scipy import stats
import folium as folium
from IPython.display import display
import geopandas as gpd
from shapely.geometry import Point
import contextily as ctx

# %% [markdown]
# ### Lectura del archivo Pennsylvania.json

# %%
df= pd.read_json(r"C:\Users\jessi\Desktop\Horizon_Project\Pennsylvania\Pennsylvania.json",lines=True)

# %%
df.head()
# Out:
#         user_id             name  rating  \
# 0  1.076383e+20        Madi Duff       5
# 1  1.123088e+20       Angela Tee       5
# 2  1.152749e+20  Andrew Williams       5
# 3  1.141193e+20     ROD ROBINSON       4
# 4  1.107411e+20              E H       5
#
#                                                 text  resp  \
# 0  i am so excited to have noodle eighty eight ri...  None
# 1  Loving the food!! Had beef pad Thai, xiao long...  None
# 2  Food was delicious. Staff was attentive. And, ...  None
# 3  Highly Recommended, Great Service and Food\nNi...  None
# 4  The Shanghai soup dumplings were so tasty. I e...  None
#
#                                  gmap_id
# 0  0x89c6e9b2f9464d2d:0x67de23671abfae45
# 1  0x89c6e9b2f9464d2d:0x67de23671abfae45
# 2  0x89c6e9b2f9464d2d:0x67de23671abfae45
# 3  0x89c6e9b2f9464d2d:0x67de23671abfae45
# 4  0x89c6e9b2f9464d2d:0x67de23671abfae45

# %% [markdown]
# ### Lectura del archivo "df_gastronomico_ciudades.json "

# %%
df2=pd.read_json(r"C:\Users\jessi\Desktop\Horizon_Project\Washington\df_gastronomico_ciudades.json",lines=True)

# %%
df2.head()
# Out:
#                            nombre_local                     direccion  \
# 0  Creole Orleans Catering & Food Truck  2841 Greenbriar Pkwy SW N317
# 1               Biswas Grocery and Cafe            2853 Buford Hwy NE
# 2                           Noodle Cafe        233 Peachtree St # B70
# 3  Creole Orleans Catering & Food Truck  2841 Greenbriar Pkwy SW N317
# 4               Biswas Grocery and Cafe            2853 Buford Hwy NE
#
#     ciudad codigo_postal_cod_ciudad codigo_ciudad codigo_postal  \
# 0  Atlanta                 GA 30331            GA         30331
# 1  Atlanta                 GA 30329            GA         30329
# 2  Atlanta                 GA 30303            GA         30303
# 3  Atlanta                 GA 30331            GA         30331
# 4  Atlanta                 GA 30329            GA         30329
#
#                                  gmap_id   latitude  longitude  \
# 0  0x88f503d71429c049:0xef40e07a5479b1c2  33.689032 -84.495097
# 1  0x88f507f3e1cde31d:0x1bcd2bb2f0555399  33.831454 -84.341647
# 2  0x88f5047831dfc86d:0x985e3a6645f5ca4f  33.760404 -84.386319
# 3  0x88f503d71429c049:0xef40e07a5479b1c2  33.689032 -84.495097
# 4  0x88f507f3e1cde31d:0x1bcd2bb2f0555399  33.831454 -84.341647
#
#                                             category  avg_rating  \
# 0  [Creole restaurant, Caribbean restaurant, Cate...         4.7
# 1  [Organic food store, Convenience store, Phone ...         4.7
# 2                      [Thai restaurant, Restaurant]         4.2
# 3  [Creole restaurant, Caribbean restaurant, Cate...         4.7
# 4  [Organic food store, Convenience store, Phone ...         4.7
#
#    num_of_reviews price                                               MISC
# 0              31  None  {'Service options': ['Delivery', 'Takeout', 'D...
# 1              25  None  {'Service options': ['Delivery', 'In-store sho...
# 2              35  None  {'Service options': ['Takeout', 'Dine-in', 'De...
# 3              31  None  {'Service options': ['Delivery', 'Takeout', 'D...
# 4              25  None  {'Service options': ['Delivery', 'In-store sho...

# %% [markdown]
# ### Informacion General

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5983 entries, 0 to 5982
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   user_id  5983 non-null   float64
#  1   name     5983 non-null   object
#  2   rating   5983 non-null   int64
#  3   text     3650 non-null   object
#  4   resp     637 non-null    object
#  5   gmap_id  5983 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 280.6+ KB
# None

# %%
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18037 entries, 0 to 18036
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   nombre_local              18037 non-null  object
#  1   direccion                 18037 non-null  object
#  2   ciudad                    18037 non-null  object
#  3   codigo_postal_cod_ciudad  18037 non-null  object
#  4   codigo_ciudad             18037 non-null  object
#  5   codigo_postal             18037 non-null  object
#  6   gmap_id                   18037 non-null  object
#  7   latitude                  18037 non-null  float64
#  8   longitude                 18037 non-null  float64
#  9   category                  18037 non-null  object
#  10  avg_rating                18037 non-null  float64
#  11  num_of_reviews            18037 non-null  int64
#  12  price                     8690 non-null   object
#  13  MISC                      17614 non-null  object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 1.9+ MB
# None

# %% [markdown]
# ### Descripción de los dataframe

# %%
df['rating'].describe()
# Out:
# count    5983.000000
# mean        4.141735
# std         1.228888
# min         1.000000
# 25%         4.000000
# 50%         5.000000
# 75%         5.000000
# max         5.000000
# Name: rating, dtype: float64

# %%
df2.describe()
# Out:
#            latitude     longitude    avg_rating  num_of_reviews
# count  18037.000000  18037.000000  18037.000000    18037.000000
# mean      38.290007    -92.404179      4.137573       70.622276
# std        4.948144     18.621202      0.575608      143.090909
# min       25.993710   -122.805295      1.000000        1.000000
# 25%       34.055071   -118.186637      3.900000       17.000000
# 50%       39.943207    -86.808270      4.200000       38.000000
# 75%       40.831310    -74.145373      4.500000       78.000000
# max       47.682747    -71.145040      5.000000     5321.000000

# %% [markdown]
# ### Análisis de Datos Nulos

# %%
print(df.isnull().sum())
# Out:
# user_id       0
# name          0
# rating        0
# text       2333
# resp       5346
# gmap_id       0
# dtype: int64

# %%
print(df2.isnull().sum())
# Out:
# nombre_local                   0
# direccion                      0
# ciudad                         0
# codigo_postal_cod_ciudad       0
# codigo_ciudad                  0
# codigo_postal                  0
# gmap_id                        0
# latitude                       0
# longitude                      0
# category                       0
# avg_rating                     0
# num_of_reviews                 0
# price                       9347
# MISC                         423
# dtype: int64

# %% [markdown]
# ### Outliers

# %%
rating = df['rating']

# Calcular el IQR para la columna 'rating'
Q1 = rating.quantile(0.25)
Q3 = rating.quantile(0.75)
IQR = Q3 - Q1

# Identificar outliers usando IQR
outliers_iqr = rating[(rating < (Q1 - 1.5 * IQR)) | (rating > (Q3 + 1.5 * IQR))]
print("Outliers en la columna 'rating' usando IQR:")
print(outliers_iqr)

# Calcular Z-score para la columna 'rating'
z_scores = stats.zscore(rating)
abs_z_scores = abs(z_scores)

# Identificar outliers con Z-score mayor que 3
outliers_z = rating[abs_z_scores > 3]
print("Outliers en la columna 'rating' usando Z-score:")
print(outliers_z)

# Graficar el boxplot para 'rating'
plt.figure(figsize=(10, 6))
sns.boxplot(x=rating)
plt.title('Boxplot de rating')
plt.show()
# Out:
# Outliers en la columna 'rating' usando IQR:
# 6       1
# 28      2
# 56      1
# 57      1
# 64      1
#        ..
# 5906    2
# 5909    2
# 5910    2
# 5927    1
# 5973    2
# Name: rating, Length: 712, dtype: int64
# Outliers en la columna 'rating' usando Z-score:
# Series([], Name: rating, dtype: int64)

# %%
columns_to_check = ['avg_rating']

Q1 = df2[columns_to_check].quantile(0.25)
Q3 = df2[columns_to_check].quantile(0.75)
IQR = Q3 - Q1

outliers_iqr = df2[(df2[columns_to_check] < (Q1 - 1.5 * IQR)) | (df2[columns_to_check] > (Q3 + 1.5 * IQR))]

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.boxplot(x=df2['avg_rating'])
plt.title('Outliers de Average Rating')



plt.show()

# %%
num_of_reviews = df2['num_of_reviews']

Q1 = num_of_reviews.quantile(0.25)
Q3 = num_of_reviews.quantile(0.75)
IQR = Q3 - Q1

outliers_iqr = num_of_reviews[(num_of_reviews < (Q1 - 1.5 * IQR)) | (num_of_reviews > (Q3 + 1.5 * IQR))]
print("Outliers en la columna 'num_of_reviews' usando IQR:")
print(outliers_iqr)

z_scores = stats.zscore(num_of_reviews)
abs_z_scores = abs(z_scores)

outliers_z = num_of_reviews[abs_z_scores > 3]
print("Outliers en la columna 'num_of_reviews' usando Z-score:")
print(outliers_z)

plt.figure(figsize=(10, 6))
sns.boxplot(x=num_of_reviews)
plt.title('Outliers Número de Reviews')
plt.show()
# Out:
# Outliers en la columna 'num_of_reviews' usando IQR:
# 124      798
# 206      178
# 217      496
# 224      214
# 229      768
#         ...
# 18019    238
# 18024    244
# 18027    292
# 18029    178
# 18031    238
# Name: num_of_reviews, Length: 1371, dtype: int64
# Outliers en la columna 'num_of_reviews' usando Z-score:
# 124       798
# 229       768
# 233      1018
# 237      3128
# 238      1373
#          ...
# 17884     798
# 17890    1108
# 17892    1208
# 17893    1351
# 17901     624
# Name: num_of_reviews, Length: 171, dtype: int64

# %% [markdown]
# ### Histogramas de distribución

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['rating'], bins=10)
plt.title('Distribución de Raiting DF')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
avg_rating = df2['avg_rating']
num_of_reviews = df2['num_of_reviews']

plt.figure(figsize=(14, 12))

plt.subplot(2, 2, 1)
sns.histplot(avg_rating, bins=30, kde=False)
plt.title('Histograma de puntaje promedio')
plt.xlabel('avg_rating')
plt.ylabel('Frecuencia')

plt.subplot(2, 2, 3)
sns.histplot(num_of_reviews, bins=20, kde=False)
plt.title('Histograma de número de reviews')
plt.xlabel('num_of_reviews')
plt.ylabel('Frecuencia')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Análisis de sentimientos

# %%
df['text'] = df['text'].fillna('')

# %%
def get_sentiment(text):
    return TextBlob(text).sentiment.polarity

df['review_sentiment'] = df['text'].apply(get_sentiment)

print(df[['text', 'review_sentiment']].head())
# Out:
#                                                 text  review_sentiment
# 0  i am so excited to have noodle eighty eight ri...          0.455195
# 1  Loving the food!! Had beef pad Thai, xiao long...          0.375694
# 2  Food was delicious. Staff was attentive. And, ...          0.382778
# 3  Highly Recommended, Great Service and Food\nNi...          0.481667
# 4  The Shanghai soup dumplings were so tasty. I e...          0.340000

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.histplot(df['review_sentiment'], bins=10, kde=True)
plt.title('Distribución de Sentimientos en Reviews')
plt.xlabel('Sentimiento')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ### Unión de datasets

# %%
merged_df = pd.merge(df, df2, on='gmap_id', how='inner')

# %%
merged_df
# Out:
#            user_id                    name  rating  \
# 0     1.076383e+20               Madi Duff       5
# 1     1.123088e+20              Angela Tee       5
# 2     1.152749e+20         Andrew Williams       5
# 3     1.141193e+20            ROD ROBINSON       4
# 4     1.107411e+20                     E H       5
# ...            ...                     ...     ...
# 5978  1.077171e+20              Dent forem       4
# 5979  1.013964e+20            raage hassan       5
# 5980  1.011512e+20              Dwight Lee       5
# 5981  1.022664e+20  Benjamin Mullins-Spann       5
# 5982  1.080758e+20               tmax teah       4
#
#                                                    text  resp  \
# 0     i am so excited to have noodle eighty eight ri...  None
# 1     Loving the food!! Had beef pad Thai, xiao long...  None
# 2     Food was delicious. Staff was attentive. And, ...  None
# 3     Highly Recommended, Great Service and Food\nNi...  None
# 4     The Shanghai soup dumplings were so tasty. I e...  None
# ...                                                 ...   ...
# 5978                                                     None
# 5979                                                     None
# 5980                                                     None
# 5981                                                     None
# 5982                                                     None
#
#                                     gmap_id  review_sentiment  \
# 0     0x89c6e9b2f9464d2d:0x67de23671abfae45          0.455195
# 1     0x89c6e9b2f9464d2d:0x67de23671abfae45          0.375694
# 2     0x89c6e9b2f9464d2d:0x67de23671abfae45          0.382778
# 3     0x89c6e9b2f9464d2d:0x67de23671abfae45          0.481667
# 4     0x89c6e9b2f9464d2d:0x67de23671abfae45          0.340000
# ...                                     ...               ...
# 5978  0x89c6c4072624d2a9:0x4437b2d55e9a5811          0.000000
# 5979  0x89c6c4072624d2a9:0x4437b2d55e9a5811          0.000000
# 5980  0x89c6c4072624d2a9:0x4437b2d55e9a5811          0.000000
# 5981  0x89c6c4072624d2a9:0x4437b2d55e9a5811          0.000000
# 5982  0x89c6c4072624d2a9:0x4437b2d55e9a5811          0.000000
#
#                          nombre_local            direccion        ciudad  \
# 0     Noodle Eighty Eight Springfield  1168 Baltimore Pike   Springfield
# 1     Noodle Eighty Eight Springfield  1168 Baltimore Pike   Springfield
# 2     Noodle Eighty Eight Springfield  1168 Baltimore Pike   Springfield
# 3     Noodle Eighty Eight Springfield  1168 Baltimore Pike   Springfield
# 4     Noodle Eighty Eight Springfield  1168 Baltimore Pike   Springfield
# ...                               ...                  ...           ...
# 5978                          Dunkin'     7000 Chester Ave  Philadelphia
# 5979                          Dunkin'     7000 Chester Ave  Philadelphia
# 5980                          Dunkin'     7000 Chester Ave  Philadelphia
# 5981                          Dunkin'     7000 Chester Ave  Philadelphia
# 5982                          Dunkin'     7000 Chester Ave  Philadelphia
#
#      codigo_postal_cod_ciudad codigo_ciudad codigo_postal   latitude  \
# 0                    PA 19064            PA         19064  39.913744
# 1                    PA 19064            PA         19064  39.913744
# 2                    PA 19064            PA         19064  39.913744
# 3                    PA 19064            PA         19064  39.913744
# 4                    PA 19064            PA         19064  39.913744
# ...                       ...           ...           ...        ...
# 5978                 PA 19142            PA         19142  39.923594
# 5979                 PA 19142            PA         19142  39.923594
# 5980                 PA 19142            PA         19142  39.923594
# 5981                 PA 19142            PA         19142  39.923594
# 5982                 PA 19142            PA         19142  39.923594
#
#       longitude                                           category  \
# 0    -75.347519                                 [Asian restaurant]
# 1    -75.347519                                 [Asian restaurant]
# 2    -75.347519                                 [Asian restaurant]
# 3    -75.347519                                 [Asian restaurant]
# 4    -75.347519                                 [Asian restaurant]
# ...         ...                                                ...
# 5978 -75.245269  [Coffee shop, Bagel shop, Bakery, Breakfast re...
# 5979 -75.245269  [Coffee shop, Bagel shop, Bakery, Breakfast re...
# 5980 -75.245269  [Coffee shop, Bagel shop, Bakery, Breakfast re...
# 5981 -75.245269  [Coffee shop, Bagel shop, Bakery, Breakfast re...
# 5982 -75.245269  [Coffee shop, Bagel shop, Bakery, Breakfast re...
#
#       avg_rating  num_of_reviews price  \
# 0            4.5              28  None
# 1            4.5              28  None
# 2            4.5              28  None
# 3            4.5              28  None
# 4            4.5              28  None
# ...          ...             ...   ...
# 5978         4.0             348     $
# 5979         4.0             348     $
# 5980         4.0             348     $
# 5981         4.0             348     $
# 5982         4.0             348     $
#
#                                                    MISC
# 0     {'Service options': ['Takeout', 'Dine-in', 'De...
# 1     {'Service options': ['Takeout', 'Dine-in', 'De...
# 2     {'Service options': ['Takeout', 'Dine-in', 'De...
# 3     {'Service options': ['Takeout', 'Dine-in', 'De...
# 4     {'Service options': ['Takeout', 'Dine-in', 'De...
# ...                                                 ...
# 5978  {'Service options': ['Delivery', 'Drive-throug...
# 5979  {'Service options': ['Delivery', 'Drive-throug...
# 5980  {'Service options': ['Delivery', 'Drive-throug...
# 5981  {'Service options': ['Delivery', 'Drive-throug...
# 5982  {'Service options': ['Delivery', 'Drive-throug...
#
# [5983 rows x 20 columns]

# %% [markdown]
# ### Gráfico de los 20 restaurants con más reviews

# %%
local_comment_counts = merged_df['nombre_local'].value_counts().reset_index()
local_comment_counts.columns = ['nombre_local', 'num_of_reviews']

# Seleccionar los 20 locales con más comentarios
top_locals = local_comment_counts.head(20)

# Mostrar el ranking
print(top_locals)
# Out:
#                  nombre_local  num_of_reviews
# 0                     Dunkin'             370
# 1                        Wawa             304
# 2              Domino's Pizza             304
# 3        Sciarrino's Pizzeria             185
# 4             Italian Delight             161
# 5                  Just Pizza             158
# 6                  Happy Days             148
# 7       Walt's Pizza & Grille             145
# 8            Zac's Hamburgers             144
# 9                Lupi's Pizza             124
# 10       Slack's Hoagie Shack             118
# 11             Emilio's Pizza             115
# 12               PrimoHoagies             105
# 13                Terry's Too             104
# 14  A.J. Stephen's Crab House              97
# 15           Johnny Paisano's              94
# 16                Dolan's Bar              88
# 17         Visions Restaurant              86
# 18                Arion Pizza              83
# 19                 No 1 China              80

# %%
plt.figure(figsize=(12, 8))
plt.bar(top_locals['nombre_local'], top_locals['num_of_reviews'], color='skyblue')

plt.xlabel('Nombre del Local')
plt.ylabel('Número de Comentarios')
plt.title('Top 20 Locales con Más Comentarios')
plt.xticks(rotation=90)  

plt.tight_layout()
plt.show()

# %%
local_comment_counts = merged_df.groupby('nombre_local').agg(
    num_of_reviews=('nombre_local', 'count'),
    avg_rating=('avg_rating', 'mean')
).reset_index()

top_locals = local_comment_counts.sort_values(by='num_of_reviews', ascending=False).head(20)

plt.figure(figsize=(14, 8))
plt.bar(top_locals['nombre_local'], top_locals['avg_rating'], color='skyblue')

plt.xlabel('Nombre del Local')
plt.ylabel('Promedio de Calificación')
plt.title('Top 20 Locales y su Promedio de Calificación')
plt.xticks(rotation=90)  

plt.tight_layout()
plt.show()

# %%
merged_df.to_csv(r"C:\Users\jessi\Desktop\Proyecto Final Henry\Pennsylvania.csv", index=False)
