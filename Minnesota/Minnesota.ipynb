# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from textblob import TextBlob
from scipy import stats
import folium as folium
from IPython.display import display
import geopandas as gpd
from shapely.geometry import Point
import contextily as ctx

# %% [markdown]
# ### Lectura del archivo Minnesota.json

# %%
df= pd.read_json(r"C:\Users\jessi\Desktop\Horizon_Project\Minnesota\Minnesota.json",lines=True)

# %%
df.head()
# Out:
#         user_id                 name  rating  \
# 0  1.059709e+20    Michelle Tverberg       5
# 1  1.089530e+20           Felix Gill       5
# 2  1.157047e+20          Matt Klemme       5
# 3  1.099249e+20       zane inglorion       5
# 4  1.026137e+20  Christopher T Rogan       5
#
#                                                 text  \
# 0  Brian with Brie Cater at The Bella Room, MN ho...
# 1  Good food. Try the ribs.  Great bartenders, Sa...
# 2  Brie Cater is amazing. My wife and I had anoth...
# 3  great food. great service, great family owned ...
# 4                   Excellent staff, delicious food.
#
#                                                 resp  \
# 0                                               None
# 1  {'time': 1618193751091, 'text': 'Thank you Fel...
# 2  {'time': 1596165482121, 'text': 'Thank you Mat...
# 3                                               None
# 4                                               None
#
#                                  gmap_id
# 0  0x52b32e10e4d6bbd1:0xa4e86205085ba820
# 1  0x52b32e10e4d6bbd1:0xa4e86205085ba820
# 2  0x52b32e10e4d6bbd1:0xa4e86205085ba820
# 3  0x52b32e10e4d6bbd1:0xa4e86205085ba820
# 4  0x52b32e10e4d6bbd1:0xa4e86205085ba820

# %% [markdown]
# ### Lectura del archivo "df_gastronomico_ciudades.json "

# %%
df2=pd.read_json(r"C:\Users\jessi\Desktop\Horizon_Project\Washington\df_gastronomico_ciudades.json",lines=True)

# %%
df2.head()
# Out:
#                            nombre_local                     direccion  \
# 0  Creole Orleans Catering & Food Truck  2841 Greenbriar Pkwy SW N317
# 1               Biswas Grocery and Cafe            2853 Buford Hwy NE
# 2                           Noodle Cafe        233 Peachtree St # B70
# 3  Creole Orleans Catering & Food Truck  2841 Greenbriar Pkwy SW N317
# 4               Biswas Grocery and Cafe            2853 Buford Hwy NE
#
#     ciudad codigo_postal_cod_ciudad codigo_ciudad codigo_postal  \
# 0  Atlanta                 GA 30331            GA         30331
# 1  Atlanta                 GA 30329            GA         30329
# 2  Atlanta                 GA 30303            GA         30303
# 3  Atlanta                 GA 30331            GA         30331
# 4  Atlanta                 GA 30329            GA         30329
#
#                                  gmap_id   latitude  longitude  \
# 0  0x88f503d71429c049:0xef40e07a5479b1c2  33.689032 -84.495097
# 1  0x88f507f3e1cde31d:0x1bcd2bb2f0555399  33.831454 -84.341647
# 2  0x88f5047831dfc86d:0x985e3a6645f5ca4f  33.760404 -84.386319
# 3  0x88f503d71429c049:0xef40e07a5479b1c2  33.689032 -84.495097
# 4  0x88f507f3e1cde31d:0x1bcd2bb2f0555399  33.831454 -84.341647
#
#                                             category  avg_rating  \
# 0  [Creole restaurant, Caribbean restaurant, Cate...         4.7
# 1  [Organic food store, Convenience store, Phone ...         4.7
# 2                      [Thai restaurant, Restaurant]         4.2
# 3  [Creole restaurant, Caribbean restaurant, Cate...         4.7
# 4  [Organic food store, Convenience store, Phone ...         4.7
#
#    num_of_reviews price                                               MISC
# 0              31  None  {'Service options': ['Delivery', 'Takeout', 'D...
# 1              25  None  {'Service options': ['Delivery', 'In-store sho...
# 2              35  None  {'Service options': ['Takeout', 'Dine-in', 'De...
# 3              31  None  {'Service options': ['Delivery', 'Takeout', 'D...
# 4              25  None  {'Service options': ['Delivery', 'In-store sho...

# %% [markdown]
# ### Informacion General

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20448 entries, 0 to 20447
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   user_id  20448 non-null  float64
#  1   name     20448 non-null  object
#  2   rating   20448 non-null  int64
#  3   text     12408 non-null  object
#  4   resp     2299 non-null   object
#  5   gmap_id  20448 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 958.6+ KB
# None

# %%
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18037 entries, 0 to 18036
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   nombre_local              18037 non-null  object
#  1   direccion                 18037 non-null  object
#  2   ciudad                    18037 non-null  object
#  3   codigo_postal_cod_ciudad  18037 non-null  object
#  4   codigo_ciudad             18037 non-null  object
#  5   codigo_postal             18037 non-null  object
#  6   gmap_id                   18037 non-null  object
#  7   latitude                  18037 non-null  float64
#  8   longitude                 18037 non-null  float64
#  9   category                  18037 non-null  object
#  10  avg_rating                18037 non-null  float64
#  11  num_of_reviews            18037 non-null  int64
#  12  price                     8690 non-null   object
#  13  MISC                      17614 non-null  object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 1.9+ MB
# None

# %% [markdown]
# ### Descripción de los dataframe

# %%
df['rating'].describe()
# Out:
# count    20448.000000
# mean         4.253228
# std          1.146969
# min          1.000000
# 25%          4.000000
# 50%          5.000000
# 75%          5.000000
# max          5.000000
# Name: rating, dtype: float64

# %%
df2.describe()
# Out:
#            latitude     longitude    avg_rating  num_of_reviews
# count  18037.000000  18037.000000  18037.000000    18037.000000
# mean      38.290007    -92.404179      4.137573       70.622276
# std        4.948144     18.621202      0.575608      143.090909
# min       25.993710   -122.805295      1.000000        1.000000
# 25%       34.055071   -118.186637      3.900000       17.000000
# 50%       39.943207    -86.808270      4.200000       38.000000
# 75%       40.831310    -74.145373      4.500000       78.000000
# max       47.682747    -71.145040      5.000000     5321.000000

# %% [markdown]
# ### Análisis de Datos Nulos

# %%
print(df.isnull().sum())
# Out:
# user_id        0
# name           0
# rating         0
# text        8040
# resp       18149
# gmap_id        0
# dtype: int64

# %%
print(df2.isnull().sum())
# Out:
# nombre_local                   0
# direccion                      0
# ciudad                         0
# codigo_postal_cod_ciudad       0
# codigo_ciudad                  0
# codigo_postal                  0
# gmap_id                        0
# latitude                       0
# longitude                      0
# category                       0
# avg_rating                     0
# num_of_reviews                 0
# price                       9347
# MISC                         423
# dtype: int64

# %% [markdown]
# ### Outliers

# %%
rating = df['rating']

# Calcular el IQR para la columna 'rating'
Q1 = rating.quantile(0.25)
Q3 = rating.quantile(0.75)
IQR = Q3 - Q1

# Identificar outliers usando IQR
outliers_iqr = rating[(rating < (Q1 - 1.5 * IQR)) | (rating > (Q3 + 1.5 * IQR))]
print("Outliers en la columna 'rating' usando IQR:")
print(outliers_iqr)

# Calcular Z-score para la columna 'rating'
z_scores = stats.zscore(rating)
abs_z_scores = abs(z_scores)

# Identificar outliers con Z-score mayor que 3
outliers_z = rating[abs_z_scores > 3]
print("Outliers en la columna 'rating' usando Z-score:")
print(outliers_z)

# Graficar el boxplot para 'rating'
plt.figure(figsize=(10, 6))
sns.boxplot(x=rating)
plt.title('Boxplot de rating')
plt.show()
# Out:
# Outliers en la columna 'rating' usando IQR:
# 10       2
# 11       1
# 14       1
# 16       1
# 32       2
#         ..
# 20421    1
# 20422    2
# 20424    1
# 20426    2
# 20446    1
# Name: rating, Length: 1981, dtype: int64
# Outliers en la columna 'rating' usando Z-score:
# Series([], Name: rating, dtype: int64)

# %%
columns_to_check = ['avg_rating']

Q1 = df2[columns_to_check].quantile(0.25)
Q3 = df2[columns_to_check].quantile(0.75)
IQR = Q3 - Q1

outliers_iqr = df2[(df2[columns_to_check] < (Q1 - 1.5 * IQR)) | (df2[columns_to_check] > (Q3 + 1.5 * IQR))]

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.boxplot(x=df2['avg_rating'])
plt.title('Outliers de Average Rating')



plt.show()

# %%
num_of_reviews = df2['num_of_reviews']

Q1 = num_of_reviews.quantile(0.25)
Q3 = num_of_reviews.quantile(0.75)
IQR = Q3 - Q1

outliers_iqr = num_of_reviews[(num_of_reviews < (Q1 - 1.5 * IQR)) | (num_of_reviews > (Q3 + 1.5 * IQR))]
print("Outliers en la columna 'num_of_reviews' usando IQR:")
print(outliers_iqr)

z_scores = stats.zscore(num_of_reviews)
abs_z_scores = abs(z_scores)

outliers_z = num_of_reviews[abs_z_scores > 3]
print("Outliers en la columna 'num_of_reviews' usando Z-score:")
print(outliers_z)

plt.figure(figsize=(10, 6))
sns.boxplot(x=num_of_reviews)
plt.title('Outliers Número de Reviews')
plt.show()
# Out:
# Outliers en la columna 'num_of_reviews' usando IQR:
# 124      798
# 206      178
# 217      496
# 224      214
# 229      768
#         ...
# 18019    238
# 18024    244
# 18027    292
# 18029    178
# 18031    238
# Name: num_of_reviews, Length: 1371, dtype: int64
# Outliers en la columna 'num_of_reviews' usando Z-score:
# 124       798
# 229       768
# 233      1018
# 237      3128
# 238      1373
#          ...
# 17884     798
# 17890    1108
# 17892    1208
# 17893    1351
# 17901     624
# Name: num_of_reviews, Length: 171, dtype: int64

# %% [markdown]
# ### Histogramas de distribución

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['rating'], bins=10)
plt.title('Distribución de Raiting DF')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
avg_rating = df2['avg_rating']
num_of_reviews = df2['num_of_reviews']

plt.figure(figsize=(14, 12))

plt.subplot(2, 2, 1)
sns.histplot(avg_rating, bins=30, kde=False)
plt.title('Histograma de puntaje promedio')
plt.xlabel('avg_rating')
plt.ylabel('Frecuencia')

plt.subplot(2, 2, 3)
sns.histplot(num_of_reviews, bins=20, kde=False)
plt.title('Histograma de número de reviews')
plt.xlabel('num_of_reviews')
plt.ylabel('Frecuencia')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Análisis de sentimientos

# %%
df['text'] = df['text'].fillna('')

# %%
def get_sentiment(text):
    return TextBlob(text).sentiment.polarity

df['review_sentiment'] = df['text'].apply(get_sentiment)

print(df[['text', 'review_sentiment']].head())
# Out:
#                                                 text  review_sentiment
# 0  Brian with Brie Cater at The Bella Room, MN ho...          0.457143
# 1  Good food. Try the ribs.  Great bartenders, Sa...          0.666667
# 2  Brie Cater is amazing. My wife and I had anoth...          0.436337
# 3  great food. great service, great family owned ...          0.800000
# 4                   Excellent staff, delicious food.          1.000000

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.histplot(df['review_sentiment'], bins=10, kde=True)
plt.title('Distribución de Sentimientos en Reviews')
plt.xlabel('Sentimiento')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ### Unión de datasets

# %%
merged_df = pd.merge(df, df2, on='gmap_id', how='inner')

# %%
merged_df
# Out:
#             user_id               name  rating  \
# 0      1.059709e+20  Michelle Tverberg       5
# 1      1.059709e+20  Michelle Tverberg       5
# 2      1.089530e+20         Felix Gill       5
# 3      1.089530e+20         Felix Gill       5
# 4      1.157047e+20        Matt Klemme       5
# ...             ...                ...     ...
# 20487  1.017358e+20          Jesse jan       5
# 20488  1.110412e+20   Boris Mishulovin       5
# 20489  1.121501e+20        John Cooper       5
# 20490  1.079208e+20      Tootie Tootie       1
# 20491  1.140125e+20       Blake Brauer       5
#
#                                                     text  \
# 0      Brian with Brie Cater at The Bella Room, MN ho...
# 1      Brian with Brie Cater at The Bella Room, MN ho...
# 2      Good food. Try the ribs.  Great bartenders, Sa...
# 3      Good food. Try the ribs.  Great bartenders, Sa...
# 4      Brie Cater is amazing. My wife and I had anoth...
# ...                                                  ...
# 20487                                     Wonderful food
# 20488                     Always excellent and delicious
# 20489
# 20490
# 20491
#
#                                                     resp  \
# 0                                                   None
# 1                                                   None
# 2      {'time': 1618193751091, 'text': 'Thank you Fel...
# 3      {'time': 1618193751091, 'text': 'Thank you Fel...
# 4      {'time': 1596165482121, 'text': 'Thank you Mat...
# ...                                                  ...
# 20487                                               None
# 20488                                               None
# 20489                                               None
# 20490                                               None
# 20491                                               None
#
#                                      gmap_id  review_sentiment   nombre_local  \
# 0      0x52b32e10e4d6bbd1:0xa4e86205085ba820          0.457143     Brie Cater
# 1      0x52b32e10e4d6bbd1:0xa4e86205085ba820          0.457143     Brie Cater
# 2      0x52b32e10e4d6bbd1:0xa4e86205085ba820          0.666667     Brie Cater
# 3      0x52b32e10e4d6bbd1:0xa4e86205085ba820          0.666667     Brie Cater
# 4      0x52b32e10e4d6bbd1:0xa4e86205085ba820          0.436337     Brie Cater
# ...                                      ...               ...            ...
# 20487  0x52b333cfb085c343:0x20b63a0aae0e254a          1.000000  Vitali’s Cafe
# 20488  0x52b333cfb085c343:0x20b63a0aae0e254a          1.000000  Vitali’s Cafe
# 20489  0x52b333cfb085c343:0x20b63a0aae0e254a          0.000000  Vitali’s Cafe
# 20490  0x52b333cfb085c343:0x20b63a0aae0e254a          0.000000  Vitali’s Cafe
# 20491  0x52b333cfb085c343:0x20b63a0aae0e254a          0.000000  Vitali’s Cafe
#
#                       direccion        ciudad codigo_postal_cod_ciudad  \
# 0               886 Smith Ave S  West St Paul                 MN 55118
# 1               886 Smith Ave S  West St Paul                 MN 55118
# 2               886 Smith Ave S  West St Paul                 MN 55118
# 3               886 Smith Ave S  West St Paul                 MN 55118
# 4               886 Smith Ave S  West St Paul                 MN 55118
# ...                         ...           ...                      ...
# 20487  1300 Nicollet Mall #2270   Minneapolis                 MN 55403
# 20488  1300 Nicollet Mall #2270   Minneapolis                 MN 55403
# 20489  1300 Nicollet Mall #2270   Minneapolis                 MN 55403
# 20490  1300 Nicollet Mall #2270   Minneapolis                 MN 55403
# 20491  1300 Nicollet Mall #2270   Minneapolis                 MN 55403
#
#       codigo_ciudad codigo_postal   latitude  longitude  \
# 0                MN         55118  44.919284 -93.101541
# 1                MN         55118  44.919284 -93.101541
# 2                MN         55118  44.919284 -93.101541
# 3                MN         55118  44.919284 -93.101541
# 4                MN         55118  44.919284 -93.101541
# ...             ...           ...        ...        ...
# 20487            MN         55403  44.970687 -93.278345
# 20488            MN         55403  44.970687 -93.278345
# 20489            MN         55403  44.970687 -93.278345
# 20490            MN         55403  44.970687 -93.278345
# 20491            MN         55403  44.970687 -93.278345
#
#                                                 category  avg_rating  \
# 0      [Caterer, Bar, Box lunch supplier, Mobile cate...         4.8
# 1      [Caterer, Bar, Box lunch supplier, Mobile cate...         4.8
# 2      [Caterer, Bar, Box lunch supplier, Mobile cate...         4.8
# 3      [Caterer, Bar, Box lunch supplier, Mobile cate...         4.8
# 4      [Caterer, Bar, Box lunch supplier, Mobile cate...         4.8
# ...                                                  ...         ...
# 20487                                [Kosher restaurant]         4.8
# 20488                                [Kosher restaurant]         4.8
# 20489                                [Kosher restaurant]         4.8
# 20490                                [Kosher restaurant]         4.8
# 20491                                [Kosher restaurant]         4.8
#
#        num_of_reviews price                                               MISC
# 0                  18  None                                               None
# 1                  18  None                                               None
# 2                  18  None                                               None
# 3                  18  None                                               None
# 4                  18  None                                               None
# ...               ...   ...                                                ...
# 20487              68  None  {'Service options': ['Delivery', 'Takeout'], '...
# 20488              68  None  {'Service options': ['Delivery', 'Takeout'], '...
# 20489              68  None  {'Service options': ['Delivery', 'Takeout'], '...
# 20490              68  None  {'Service options': ['Delivery', 'Takeout'], '...
# 20491              68  None  {'Service options': ['Delivery', 'Takeout'], '...
#
# [20492 rows x 20 columns]

# %% [markdown]
# ### Gráfico de los 20 restaurants con más reviews

# %%
local_comment_counts = merged_df['nombre_local'].value_counts().reset_index()
local_comment_counts.columns = ['nombre_local', 'num_of_reviews']

# Seleccionar los 20 locales con más comentarios
top_locals = local_comment_counts.head(20)

# Mostrar el ranking
print(top_locals)
# Out:
#                               nombre_local  num_of_reviews
# 0                                   Hy-Vee            1646
# 1                               Chimborazo            1470
# 2                                  Wendy's             810
# 3                                   Subway             757
# 4                   Chipotle Mexican Grill             635
# 5                           Domino's Pizza             597
# 6                        Bruegger's Bagels             547
# 7                       Dar's Double Scoop             518
# 8                             Jimmy John's             449
# 9                                  Borough             434
# 10                          Caribou Coffee             412
# 11  Sawatdee Thai Restaurant - Minneapolis             379
# 12  Taqueria y birrieria las cuatro milpas             349
# 13                   Holiday Stationstores             319
# 14                Eggroll Queen Music Cafe             316
# 15                        Korea Restaurant             242
# 16                                Dumpling             236
# 17                              Mim's Cafe             228
# 18                         Homi Restaurant             224
# 19                 Ichiddo Ramen Roseville             213

# %%
plt.figure(figsize=(12, 8))
plt.bar(top_locals['nombre_local'], top_locals['num_of_reviews'], color='skyblue')

plt.xlabel('Nombre del Local')
plt.ylabel('Número de Comentarios')
plt.title('Top 20 Locales con Más Comentarios')
plt.xticks(rotation=90)  

plt.tight_layout()
plt.show()

# %%
local_comment_counts = merged_df.groupby('nombre_local').agg(
    num_of_reviews=('nombre_local', 'count'),
    avg_rating=('avg_rating', 'mean')
).reset_index()

top_locals = local_comment_counts.sort_values(by='num_of_reviews', ascending=False).head(20)

plt.figure(figsize=(14, 8))
plt.bar(top_locals['nombre_local'], top_locals['avg_rating'], color='skyblue')

plt.xlabel('Nombre del Local')
plt.ylabel('Promedio de Calificación')
plt.title('Top 20 Locales y su Promedio de Calificación')
plt.xticks(rotation=90)  

plt.tight_layout()
plt.show()

# %%
merged_df.to_csv(r"C:\Users\jessi\Desktop\Proyecto Final Henry\Minnesota.csv", index=False)
