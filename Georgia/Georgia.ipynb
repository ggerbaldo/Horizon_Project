# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from textblob import TextBlob
from scipy import stats
import folium as folium
from IPython.display import display
import geopandas as gpd
from shapely.geometry import Point
import contextily as ctx

# %% [markdown]
# ### Lectura del archivo Georgia.json

# %%
df= pd.read_json(r"C:\Users\jessi\Desktop\Horizon_Project\Georgia\Georgia.json",lines=True)

# %%
df.head()
# Out:
#         user_id                    name  rating  \
# 0  1.087151e+20            Evan Guthrie       5
# 1  1.095364e+20        Matthew Wamboldt       5
# 2  1.166923e+20         Tenbroeck Smith       5
# 3  1.080147e+20              Déjah King       4
# 4  1.039682e+20  Dr. LaQuanda Jefferson       5
#
#                                                 text  resp  \
# 0  Noodle Cafe at Peachtree Center in Atlanta is ...  None
# 1  Timely service and decent, affordable Thai/Chi...  None
# 2  I have lunch here frequently. I get the lunch ...  None
# 3  Love the food there especially the pad Thai no...  None
# 4  I absolutely loved the food. Thai is one of fa...  None
#
#                                  gmap_id
# 0  0x88f5047831dfc86d:0x985e3a6645f5ca4f
# 1  0x88f5047831dfc86d:0x985e3a6645f5ca4f
# 2  0x88f5047831dfc86d:0x985e3a6645f5ca4f
# 3  0x88f5047831dfc86d:0x985e3a6645f5ca4f
# 4  0x88f5047831dfc86d:0x985e3a6645f5ca4f

# %% [markdown]
# ### Lectura del archivo "df_gastronomico_ciudades.json "

# %%
df2=pd.read_json(r"C:\Users\jessi\Desktop\Horizon_Project\Washington\df_gastronomico_ciudades.json",lines=True)

# %%
df2.head()
# Out:
#                            nombre_local                     direccion  \
# 0  Creole Orleans Catering & Food Truck  2841 Greenbriar Pkwy SW N317
# 1               Biswas Grocery and Cafe            2853 Buford Hwy NE
# 2                           Noodle Cafe        233 Peachtree St # B70
# 3  Creole Orleans Catering & Food Truck  2841 Greenbriar Pkwy SW N317
# 4               Biswas Grocery and Cafe            2853 Buford Hwy NE
#
#     ciudad codigo_postal_cod_ciudad codigo_ciudad codigo_postal  \
# 0  Atlanta                 GA 30331            GA         30331
# 1  Atlanta                 GA 30329            GA         30329
# 2  Atlanta                 GA 30303            GA         30303
# 3  Atlanta                 GA 30331            GA         30331
# 4  Atlanta                 GA 30329            GA         30329
#
#                                  gmap_id   latitude  longitude  \
# 0  0x88f503d71429c049:0xef40e07a5479b1c2  33.689032 -84.495097
# 1  0x88f507f3e1cde31d:0x1bcd2bb2f0555399  33.831454 -84.341647
# 2  0x88f5047831dfc86d:0x985e3a6645f5ca4f  33.760404 -84.386319
# 3  0x88f503d71429c049:0xef40e07a5479b1c2  33.689032 -84.495097
# 4  0x88f507f3e1cde31d:0x1bcd2bb2f0555399  33.831454 -84.341647
#
#                                             category  avg_rating  \
# 0  [Creole restaurant, Caribbean restaurant, Cate...         4.7
# 1  [Organic food store, Convenience store, Phone ...         4.7
# 2                      [Thai restaurant, Restaurant]         4.2
# 3  [Creole restaurant, Caribbean restaurant, Cate...         4.7
# 4  [Organic food store, Convenience store, Phone ...         4.7
#
#    num_of_reviews price                                               MISC
# 0              31  None  {'Service options': ['Delivery', 'Takeout', 'D...
# 1              25  None  {'Service options': ['Delivery', 'In-store sho...
# 2              35  None  {'Service options': ['Takeout', 'Dine-in', 'De...
# 3              31  None  {'Service options': ['Delivery', 'Takeout', 'D...
# 4              25  None  {'Service options': ['Delivery', 'In-store sho...

# %% [markdown]
# ### Informacion General

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16841 entries, 0 to 16840
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   user_id  16841 non-null  float64
#  1   name     16841 non-null  object
#  2   rating   16841 non-null  int64
#  3   text     10571 non-null  object
#  4   resp     1540 non-null   object
#  5   gmap_id  16841 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 789.6+ KB
# None

# %%
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18037 entries, 0 to 18036
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   nombre_local              18037 non-null  object
#  1   direccion                 18037 non-null  object
#  2   ciudad                    18037 non-null  object
#  3   codigo_postal_cod_ciudad  18037 non-null  object
#  4   codigo_ciudad             18037 non-null  object
#  5   codigo_postal             18037 non-null  object
#  6   gmap_id                   18037 non-null  object
#  7   latitude                  18037 non-null  float64
#  8   longitude                 18037 non-null  float64
#  9   category                  18037 non-null  object
#  10  avg_rating                18037 non-null  float64
#  11  num_of_reviews            18037 non-null  int64
#  12  price                     8690 non-null   object
#  13  MISC                      17614 non-null  object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 1.9+ MB
# None

# %% [markdown]
# ### Descripción de los dataframe

# %%
df['rating'].describe()
# Out:
# count    16841.000000
# mean         4.111692
# std          1.246013
# min          1.000000
# 25%          4.000000
# 50%          5.000000
# 75%          5.000000
# max          5.000000
# Name: rating, dtype: float64

# %%
df2.describe()
# Out:
#            latitude     longitude    avg_rating  num_of_reviews
# count  18037.000000  18037.000000  18037.000000    18037.000000
# mean      38.290007    -92.404179      4.137573       70.622276
# std        4.948144     18.621202      0.575608      143.090909
# min       25.993710   -122.805295      1.000000        1.000000
# 25%       34.055071   -118.186637      3.900000       17.000000
# 50%       39.943207    -86.808270      4.200000       38.000000
# 75%       40.831310    -74.145373      4.500000       78.000000
# max       47.682747    -71.145040      5.000000     5321.000000

# %% [markdown]
# ### Análisis de Datos Nulos

# %%
print(df.isnull().sum())
# Out:
# user_id        0
# name           0
# rating         0
# text        6270
# resp       15301
# gmap_id        0
# dtype: int64

# %%
print(df2.isnull().sum())
# Out:
# nombre_local                   0
# direccion                      0
# ciudad                         0
# codigo_postal_cod_ciudad       0
# codigo_ciudad                  0
# codigo_postal                  0
# gmap_id                        0
# latitude                       0
# longitude                      0
# category                       0
# avg_rating                     0
# num_of_reviews                 0
# price                       9347
# MISC                         423
# dtype: int64

# %% [markdown]
# ### Outliers

# %%
rating = df['rating']

# Calcular el IQR para la columna 'rating'
Q1 = rating.quantile(0.25)
Q3 = rating.quantile(0.75)
IQR = Q3 - Q1

# Identificar outliers usando IQR
outliers_iqr = rating[(rating < (Q1 - 1.5 * IQR)) | (rating > (Q3 + 1.5 * IQR))]
print("Outliers en la columna 'rating' usando IQR:")
print(outliers_iqr)

# Calcular Z-score para la columna 'rating'
z_scores = stats.zscore(rating)
abs_z_scores = abs(z_scores)

# Identificar outliers con Z-score mayor que 3
outliers_z = rating[abs_z_scores > 3]
print("Outliers en la columna 'rating' usando Z-score:")
print(outliers_z)

# Graficar el boxplot para 'rating'
plt.figure(figsize=(10, 6))
sns.boxplot(x=rating)
plt.title('Boxplot de rating')
plt.show()
# Out:
# Outliers en la columna 'rating' usando IQR:
# 34       1
# 35       2
# 37       1
# 39       1
# 40       1
#         ..
# 16744    1
# 16745    1
# 16765    1
# 16795    2
# 16803    2
# Name: rating, Length: 2144, dtype: int64
# Outliers en la columna 'rating' usando Z-score:
# Series([], Name: rating, dtype: int64)

# %%
columns_to_check = ['avg_rating']

Q1 = df2[columns_to_check].quantile(0.25)
Q3 = df2[columns_to_check].quantile(0.75)
IQR = Q3 - Q1

outliers_iqr = df2[(df2[columns_to_check] < (Q1 - 1.5 * IQR)) | (df2[columns_to_check] > (Q3 + 1.5 * IQR))]

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.boxplot(x=df2['avg_rating'])
plt.title('Outliers de Average Rating')



plt.show()

# %%
num_of_reviews = df2['num_of_reviews']

Q1 = num_of_reviews.quantile(0.25)
Q3 = num_of_reviews.quantile(0.75)
IQR = Q3 - Q1

outliers_iqr = num_of_reviews[(num_of_reviews < (Q1 - 1.5 * IQR)) | (num_of_reviews > (Q3 + 1.5 * IQR))]
print("Outliers en la columna 'num_of_reviews' usando IQR:")
print(outliers_iqr)

z_scores = stats.zscore(num_of_reviews)
abs_z_scores = abs(z_scores)

outliers_z = num_of_reviews[abs_z_scores > 3]
print("Outliers en la columna 'num_of_reviews' usando Z-score:")
print(outliers_z)

plt.figure(figsize=(10, 6))
sns.boxplot(x=num_of_reviews)
plt.title('Outliers Número de Reviews')
plt.show()
# Out:
# Outliers en la columna 'num_of_reviews' usando IQR:
# 124      798
# 206      178
# 217      496
# 224      214
# 229      768
#         ...
# 18019    238
# 18024    244
# 18027    292
# 18029    178
# 18031    238
# Name: num_of_reviews, Length: 1371, dtype: int64
# Outliers en la columna 'num_of_reviews' usando Z-score:
# 124       798
# 229       768
# 233      1018
# 237      3128
# 238      1373
#          ...
# 17884     798
# 17890    1108
# 17892    1208
# 17893    1351
# 17901     624
# Name: num_of_reviews, Length: 171, dtype: int64

# %% [markdown]
# ### Histogramas de distribución

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['rating'], bins=10)
plt.title('Distribución de Raiting DF')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
avg_rating = df2['avg_rating']
num_of_reviews = df2['num_of_reviews']

plt.figure(figsize=(14, 12))

plt.subplot(2, 2, 1)
sns.histplot(avg_rating, bins=30, kde=False)
plt.title('Histograma de puntaje promedio')
plt.xlabel('avg_rating')
plt.ylabel('Frecuencia')

plt.subplot(2, 2, 3)
sns.histplot(num_of_reviews, bins=20, kde=False)
plt.title('Histograma de número de reviews')
plt.xlabel('num_of_reviews')
plt.ylabel('Frecuencia')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Análisis de sentimientos

# %%
df['text'] = df['text'].fillna('')

# %%
def get_sentiment(text):
    return TextBlob(text).sentiment.polarity

df['review_sentiment'] = df['text'].apply(get_sentiment)

print(df[['text', 'review_sentiment']].head())
# Out:
#                                                 text  review_sentiment
# 0  Noodle Cafe at Peachtree Center in Atlanta is ...          0.390064
# 1  Timely service and decent, affordable Thai/Chi...          0.166667
# 2  I have lunch here frequently. I get the lunch ...          0.190048
# 3  Love the food there especially the pad Thai no...          0.250000
# 4  I absolutely loved the food. Thai is one of fa...          0.464286

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.histplot(df['review_sentiment'], bins=10, kde=True)
plt.title('Distribución de Sentimientos en Reviews')
plt.xlabel('Sentimiento')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ### Unión de datasets

# %%
merged_df = pd.merge(df, df2, on='gmap_id', how='inner')

# %%
merged_df
# Out:
#             user_id                      name  rating  \
# 0      1.087151e+20              Evan Guthrie       5
# 1      1.087151e+20              Evan Guthrie       5
# 2      1.095364e+20          Matthew Wamboldt       5
# 3      1.095364e+20          Matthew Wamboldt       5
# 4      1.166923e+20           Tenbroeck Smith       5
# ...             ...                       ...     ...
# 16868  1.125888e+20                     Ree S       3
# 16869  1.034054e+20             April Okelley       3
# 16870  1.115605e+20  Jarrell Pottinger (Pott)       5
# 16871  1.030506e+20              Kevin Thomas       5
# 16872  1.043976e+20            Peter Williams       4
#
#                                                     text  resp  \
# 0      Noodle Cafe at Peachtree Center in Atlanta is ...  None
# 1      Noodle Cafe at Peachtree Center in Atlanta is ...  None
# 2      Timely service and decent, affordable Thai/Chi...  None
# 3      Timely service and decent, affordable Thai/Chi...  None
# 4      I have lunch here frequently. I get the lunch ...  None
# ...                                                  ...   ...
# 16868                                                     None
# 16869                                                     None
# 16870                                                     None
# 16871                                                     None
# 16872                                                     None
#
#                                      gmap_id  review_sentiment  \
# 0      0x88f5047831dfc86d:0x985e3a6645f5ca4f          0.390064
# 1      0x88f5047831dfc86d:0x985e3a6645f5ca4f          0.390064
# 2      0x88f5047831dfc86d:0x985e3a6645f5ca4f          0.166667
# 3      0x88f5047831dfc86d:0x985e3a6645f5ca4f          0.166667
# 4      0x88f5047831dfc86d:0x985e3a6645f5ca4f          0.190048
# ...                                      ...               ...
# 16868  0x88f50480a0571613:0x672916fa5540972a          0.000000
# 16869  0x88f50480a0571613:0x672916fa5540972a          0.000000
# 16870  0x88f50480a0571613:0x672916fa5540972a          0.000000
# 16871  0x88f50480a0571613:0x672916fa5540972a          0.000000
# 16872  0x88f50480a0571613:0x672916fa5540972a          0.000000
#
#                      nombre_local               direccion   ciudad  \
# 0                     Noodle Cafe  233 Peachtree St # B70  Atlanta
# 1                     Noodle Cafe  233 Peachtree St # B70  Atlanta
# 2                     Noodle Cafe  233 Peachtree St # B70  Atlanta
# 3                     Noodle Cafe  233 Peachtree St # B70  Atlanta
# 4                     Noodle Cafe  233 Peachtree St # B70  Atlanta
# ...                           ...                     ...      ...
# 16868  Encore Hookah Bar & Bistro        320 Luckie St NW  Atlanta
# 16869  Encore Hookah Bar & Bistro        320 Luckie St NW  Atlanta
# 16870  Encore Hookah Bar & Bistro        320 Luckie St NW  Atlanta
# 16871  Encore Hookah Bar & Bistro        320 Luckie St NW  Atlanta
# 16872  Encore Hookah Bar & Bistro        320 Luckie St NW  Atlanta
#
#       codigo_postal_cod_ciudad codigo_ciudad codigo_postal   latitude  \
# 0                     GA 30303            GA         30303  33.760404
# 1                     GA 30303            GA         30303  33.760404
# 2                     GA 30303            GA         30303  33.760404
# 3                     GA 30303            GA         30303  33.760404
# 4                     GA 30303            GA         30303  33.760404
# ...                        ...           ...           ...        ...
# 16868                 GA 30313            GA         30313  33.763189
# 16869                 GA 30313            GA         30313  33.763189
# 16870                 GA 30313            GA         30313  33.763189
# 16871                 GA 30313            GA         30313  33.763189
# 16872                 GA 30313            GA         30313  33.763189
#
#        longitude                       category  avg_rating  num_of_reviews  \
# 0     -84.386319  [Thai restaurant, Restaurant]         4.2              35
# 1     -84.386319  [Thai restaurant, Restaurant]         4.2              35
# 2     -84.386319  [Thai restaurant, Restaurant]         4.2              35
# 3     -84.386319  [Thai restaurant, Restaurant]         4.2              35
# 4     -84.386319  [Thai restaurant, Restaurant]         4.2              35
# ...          ...                            ...         ...             ...
# 16868 -84.396397           [Hookah bar, Lounge]         3.9             398
# 16869 -84.396397           [Hookah bar, Lounge]         3.9             398
# 16870 -84.396397           [Hookah bar, Lounge]         3.9             398
# 16871 -84.396397           [Hookah bar, Lounge]         3.9             398
# 16872 -84.396397           [Hookah bar, Lounge]         3.9             398
#
#       price                                               MISC
# 0      None  {'Service options': ['Takeout', 'Dine-in', 'De...
# 1      None  {'Service options': ['Takeout', 'Dine-in', 'De...
# 2      None  {'Service options': ['Takeout', 'Dine-in', 'De...
# 3      None  {'Service options': ['Takeout', 'Dine-in', 'De...
# 4      None  {'Service options': ['Takeout', 'Dine-in', 'De...
# ...     ...                                                ...
# 16868  None  {'Service options': ['No-contact delivery', 'D...
# 16869  None  {'Service options': ['No-contact delivery', 'D...
# 16870  None  {'Service options': ['No-contact delivery', 'D...
# 16871  None  {'Service options': ['No-contact delivery', 'D...
# 16872  None  {'Service options': ['No-contact delivery', 'D...
#
# [16873 rows x 20 columns]

# %% [markdown]
# ### Gráfico de los 20 restaurants con más reviews

# %%
local_comment_counts = merged_df['nombre_local'].value_counts().reset_index()
local_comment_counts.columns = ['nombre_local', 'num_of_reviews']

# Seleccionar los 20 locales con más comentarios
top_locals = local_comment_counts.head(20)

# Mostrar el ranking
print(top_locals)
# Out:
#                    nombre_local  num_of_reviews
# 0         Twin Peaks Restaurant            1727
# 1                     Five Guys             838
# 2   Torched Hop Brewing Company             833
# 3                        Subway             627
# 4           Jamrock Jerk Center             505
# 5                 American Deli             317
# 6                 king crab atl             273
# 7         Moe's Southwest Grill             263
# 8           Merkerson's Seafood             262
# 9    Encore Hookah Bar & Bistro             209
# 10            Poppin Pita Grill             196
# 11           Carniceria Ramirez             191
# 12          The Heretic Atlanta             184
# 13               Domino's Pizza             184
# 14                    Starbucks             176
# 15          Pyramids Lounge Bar             175
# 16                  Jet's Pizza             175
# 17                 Jimmy John's             174
# 18            Papa John's Pizza             170
# 19             Goodness Grocery             165

# %%
plt.figure(figsize=(12, 8))
plt.bar(top_locals['nombre_local'], top_locals['num_of_reviews'], color='skyblue')

plt.xlabel('Nombre del Local')
plt.ylabel('Número de Comentarios')
plt.title('Top 20 Locales con Más Comentarios')
plt.xticks(rotation=90)  

plt.tight_layout()
plt.show()

# %%
local_comment_counts = merged_df.groupby('nombre_local').agg(
    num_of_reviews=('nombre_local', 'count'),
    avg_rating=('avg_rating', 'mean')
).reset_index()

top_locals = local_comment_counts.sort_values(by='num_of_reviews', ascending=False).head(20)

plt.figure(figsize=(14, 8))
plt.bar(top_locals['nombre_local'], top_locals['avg_rating'], color='skyblue')

plt.xlabel('Nombre del Local')
plt.ylabel('Promedio de Calificación')
plt.title('Top 20 Locales y su Promedio de Calificación')
plt.xticks(rotation=90)  

plt.tight_layout()
plt.show()

# %%
merged_df.to_csv(r"C:\Users\jessi\Desktop\Proyecto Final Henry\Georgia.csv", index=False)
