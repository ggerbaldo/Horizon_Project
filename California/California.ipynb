# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from textblob import TextBlob
from scipy import stats
import folium as folium
from IPython.display import display
import geopandas as gpd
from shapely.geometry import Point
import contextily as ctx

# %% [markdown]
# ### Lectura del archivo California.json

# %%
df= pd.read_json(r"C:\Users\jessi\Desktop\Horizon_Project\California\California.json",lines=True)

# %%
df.head()
# Out:
#         user_id           name  rating  \
# 0  1.089912e+20        Song Ro       5
# 1  1.112903e+20    Rafa Robles       5
# 2  1.126404e+20      David Han       4
# 3  1.174403e+20    Anthony Kim       5
# 4  1.005808e+20  Mario Marzouk       5
#
#                                                text  resp  \
# 0                      Love there korean rice cake.  None
# 1                                    Good very good  None
# 2  They make Korean traditional food very properly.  None
# 3                    Short ribs are very delicious.  None
# 4      Great food and prices the portions are large  None
#
#                                  gmap_id
# 0  0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 1  0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 3  0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 4  0x80c2c778e3b73d33:0xbdc58662a4a97d49

# %% [markdown]
# ### Lectura del archivo "df_gastronomico_ciudades.json "

# %%
df2=pd.read_json(r"C:\Users\jessi\Desktop\Horizon_Project\Washington\df_gastronomico_ciudades.json",lines=True)

# %%
df2.head()
# Out:
#                            nombre_local                     direccion  \
# 0  Creole Orleans Catering & Food Truck  2841 Greenbriar Pkwy SW N317
# 1               Biswas Grocery and Cafe            2853 Buford Hwy NE
# 2                           Noodle Cafe        233 Peachtree St # B70
# 3  Creole Orleans Catering & Food Truck  2841 Greenbriar Pkwy SW N317
# 4               Biswas Grocery and Cafe            2853 Buford Hwy NE
#
#     ciudad codigo_postal_cod_ciudad codigo_ciudad codigo_postal  \
# 0  Atlanta                 GA 30331            GA         30331
# 1  Atlanta                 GA 30329            GA         30329
# 2  Atlanta                 GA 30303            GA         30303
# 3  Atlanta                 GA 30331            GA         30331
# 4  Atlanta                 GA 30329            GA         30329
#
#                                  gmap_id   latitude  longitude  \
# 0  0x88f503d71429c049:0xef40e07a5479b1c2  33.689032 -84.495097
# 1  0x88f507f3e1cde31d:0x1bcd2bb2f0555399  33.831454 -84.341647
# 2  0x88f5047831dfc86d:0x985e3a6645f5ca4f  33.760404 -84.386319
# 3  0x88f503d71429c049:0xef40e07a5479b1c2  33.689032 -84.495097
# 4  0x88f507f3e1cde31d:0x1bcd2bb2f0555399  33.831454 -84.341647
#
#                                             category  avg_rating  \
# 0  [Creole restaurant, Caribbean restaurant, Cate...         4.7
# 1  [Organic food store, Convenience store, Phone ...         4.7
# 2                      [Thai restaurant, Restaurant]         4.2
# 3  [Creole restaurant, Caribbean restaurant, Cate...         4.7
# 4  [Organic food store, Convenience store, Phone ...         4.7
#
#    num_of_reviews price                                               MISC
# 0              31  None  {'Service options': ['Delivery', 'Takeout', 'D...
# 1              25  None  {'Service options': ['Delivery', 'In-store sho...
# 2              35  None  {'Service options': ['Takeout', 'Dine-in', 'De...
# 3              31  None  {'Service options': ['Delivery', 'Takeout', 'D...
# 4              25  None  {'Service options': ['Delivery', 'In-store sho...

# %% [markdown]
# ### Informacion General

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49310 entries, 0 to 49309
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   user_id  49310 non-null  float64
#  1   name     49310 non-null  object
#  2   rating   49310 non-null  int64
#  3   text     28012 non-null  object
#  4   resp     3626 non-null   object
#  5   gmap_id  49310 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 2.3+ MB
# None

# %%
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18037 entries, 0 to 18036
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   nombre_local              18037 non-null  object
#  1   direccion                 18037 non-null  object
#  2   ciudad                    18037 non-null  object
#  3   codigo_postal_cod_ciudad  18037 non-null  object
#  4   codigo_ciudad             18037 non-null  object
#  5   codigo_postal             18037 non-null  object
#  6   gmap_id                   18037 non-null  object
#  7   latitude                  18037 non-null  float64
#  8   longitude                 18037 non-null  float64
#  9   category                  18037 non-null  object
#  10  avg_rating                18037 non-null  float64
#  11  num_of_reviews            18037 non-null  int64
#  12  price                     8690 non-null   object
#  13  MISC                      17614 non-null  object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 1.9+ MB
# None

# %% [markdown]
# ### Descripción de los dataframe

# %%
df['rating'].describe()
# Out:
# count    49310.000000
# mean         4.249909
# std          1.117736
# min          1.000000
# 25%          4.000000
# 50%          5.000000
# 75%          5.000000
# max          5.000000
# Name: rating, dtype: float64

# %%
df2.describe()
# Out:
#            latitude     longitude    avg_rating  num_of_reviews
# count  18037.000000  18037.000000  18037.000000    18037.000000
# mean      38.290007    -92.404179      4.137573       70.622276
# std        4.948144     18.621202      0.575608      143.090909
# min       25.993710   -122.805295      1.000000        1.000000
# 25%       34.055071   -118.186637      3.900000       17.000000
# 50%       39.943207    -86.808270      4.200000       38.000000
# 75%       40.831310    -74.145373      4.500000       78.000000
# max       47.682747    -71.145040      5.000000     5321.000000

# %% [markdown]
# ### Análisis de Datos Nulos

# %%
print(df.isnull().sum())
# Out:
# user_id        0
# name           0
# rating         0
# text       21298
# resp       45684
# gmap_id        0
# dtype: int64

# %%
print(df2.isnull().sum())
# Out:
# nombre_local                   0
# direccion                      0
# ciudad                         0
# codigo_postal_cod_ciudad       0
# codigo_ciudad                  0
# codigo_postal                  0
# gmap_id                        0
# latitude                       0
# longitude                      0
# category                       0
# avg_rating                     0
# num_of_reviews                 0
# price                       9347
# MISC                         423
# dtype: int64

# %% [markdown]
# ### Outliers

# %%
rating = df['rating']

# Calcular el IQR para la columna 'rating'
Q1 = rating.quantile(0.25)
Q3 = rating.quantile(0.75)
IQR = Q3 - Q1

# Identificar outliers usando IQR
outliers_iqr = rating[(rating < (Q1 - 1.5 * IQR)) | (rating > (Q3 + 1.5 * IQR))]
print("Outliers en la columna 'rating' usando IQR:")
print(outliers_iqr)

# Calcular Z-score para la columna 'rating'
z_scores = stats.zscore(rating)
abs_z_scores = abs(z_scores)

# Identificar outliers con Z-score mayor que 3
outliers_z = rating[abs_z_scores > 3]
print("Outliers en la columna 'rating' usando Z-score:")
print(outliers_z)

# Graficar el boxplot para 'rating'
plt.figure(figsize=(10, 6))
sns.boxplot(x=rating)
plt.title('Boxplot de rating')
plt.show()
# Out:
# Outliers en la columna 'rating' usando IQR:
# 7        1
# 16       2
# 17       2
# 19       1
# 41       1
#         ..
# 49182    1
# 49184    1
# 49188    2
# 49265    2
# 49291    1
# Name: rating, Length: 4428, dtype: int64
# Outliers en la columna 'rating' usando Z-score:
# Series([], Name: rating, dtype: int64)

# %%
columns_to_check = ['avg_rating']

Q1 = df2[columns_to_check].quantile(0.25)
Q3 = df2[columns_to_check].quantile(0.75)
IQR = Q3 - Q1

outliers_iqr = df2[(df2[columns_to_check] < (Q1 - 1.5 * IQR)) | (df2[columns_to_check] > (Q3 + 1.5 * IQR))]

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.boxplot(x=df2['avg_rating'])
plt.title('Outliers de Average Rating')



plt.show()

# %%
num_of_reviews = df2['num_of_reviews']

Q1 = num_of_reviews.quantile(0.25)
Q3 = num_of_reviews.quantile(0.75)
IQR = Q3 - Q1

outliers_iqr = num_of_reviews[(num_of_reviews < (Q1 - 1.5 * IQR)) | (num_of_reviews > (Q3 + 1.5 * IQR))]
print("Outliers en la columna 'num_of_reviews' usando IQR:")
print(outliers_iqr)

z_scores = stats.zscore(num_of_reviews)
abs_z_scores = abs(z_scores)

outliers_z = num_of_reviews[abs_z_scores > 3]
print("Outliers en la columna 'num_of_reviews' usando Z-score:")
print(outliers_z)

plt.figure(figsize=(10, 6))
sns.boxplot(x=num_of_reviews)
plt.title('Outliers Número de Reviews')
plt.show()
# Out:
# Outliers en la columna 'num_of_reviews' usando IQR:
# 124      798
# 206      178
# 217      496
# 224      214
# 229      768
#         ...
# 18019    238
# 18024    244
# 18027    292
# 18029    178
# 18031    238
# Name: num_of_reviews, Length: 1371, dtype: int64
# Outliers en la columna 'num_of_reviews' usando Z-score:
# 124       798
# 229       768
# 233      1018
# 237      3128
# 238      1373
#          ...
# 17884     798
# 17890    1108
# 17892    1208
# 17893    1351
# 17901     624
# Name: num_of_reviews, Length: 171, dtype: int64

# %% [markdown]
# ### Histogramas de distribución

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['rating'], bins=10)
plt.title('Distribución de Raiting DF')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
avg_rating = df2['avg_rating']
num_of_reviews = df2['num_of_reviews']

plt.figure(figsize=(14, 12))

plt.subplot(2, 2, 1)
sns.histplot(avg_rating, bins=30, kde=False)
plt.title('Histograma de puntaje promedio')
plt.xlabel('avg_rating')
plt.ylabel('Frecuencia')

plt.subplot(2, 2, 3)
sns.histplot(num_of_reviews, bins=20, kde=False)
plt.title('Histograma de número de reviews')
plt.xlabel('num_of_reviews')
plt.ylabel('Frecuencia')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Análisis de sentimientos

# %%
df['text'] = df['text'].fillna('')

# %%
def get_sentiment(text):
    return TextBlob(text).sentiment.polarity

df['review_sentiment'] = df['text'].apply(get_sentiment)

print(df[['text', 'review_sentiment']].head())
# Out:
#                                                text  review_sentiment
# 0                      Love there korean rice cake.          0.500000
# 1                                    Good very good          0.805000
# 2  They make Korean traditional food very properly.          0.000000
# 3                    Short ribs are very delicious.          0.500000
# 4      Great food and prices the portions are large          0.507143

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.histplot(df['review_sentiment'], bins=10, kde=True)
plt.title('Distribución de Sentimientos en Reviews')
plt.xlabel('Sentimiento')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ### Unión de datasets

# %%
merged_df = pd.merge(df, df2, on='gmap_id', how='inner')

# %%
merged_df
# Out:
#             user_id           name  rating  \
# 0      1.089912e+20        Song Ro       5
# 1      1.089912e+20        Song Ro       5
# 2      1.112903e+20    Rafa Robles       5
# 3      1.112903e+20    Rafa Robles       5
# 4      1.126404e+20      David Han       4
# ...             ...            ...     ...
# 52034  1.066249e+20  Seyar Kalmoni       5
# 52035  1.083197e+20    Levi Spears       4
# 52036  1.002820e+20       Haroon R       5
# 52037  1.008675e+20   Wojtek Poppe       5
# 52038  1.094478e+20    Ahmed Hamdy       5
#
#                                                     text  resp  \
# 0                           Love there korean rice cake.  None
# 1                           Love there korean rice cake.  None
# 2                                         Good very good  None
# 3                                         Good very good  None
# 4       They make Korean traditional food very properly.  None
# ...                                                  ...   ...
# 52034  The Pizza is absolutely amazing, we got one pi...  None
# 52035       Awesome slices, quick service.  Recommended.  None
# 52036         One of my favorite pizza places west of NY  None
# 52037   Awesome slice of pizza. Just like in New York...  None
# 52038                                                     None
#
#                                      gmap_id  review_sentiment  nombre_local  \
# 0      0x80c2c778e3b73d33:0xbdc58662a4a97d49          0.500000  San Soo Dang
# 1      0x80c2c778e3b73d33:0xbdc58662a4a97d49          0.500000  San Soo Dang
# 2      0x80c2c778e3b73d33:0xbdc58662a4a97d49          0.805000  San Soo Dang
# 3      0x80c2c778e3b73d33:0xbdc58662a4a97d49          0.805000  San Soo Dang
# 4      0x80c2c778e3b73d33:0xbdc58662a4a97d49          0.000000  San Soo Dang
# ...                                      ...               ...           ...
# 52034  0x808fb57e5ffcf77f:0xdeb76c221475bdf0          0.440000   Metro Pizza
# 52035  0x808fb57e5ffcf77f:0xdeb76c221475bdf0          0.666667   Metro Pizza
# 52036  0x808fb57e5ffcf77f:0xdeb76c221475bdf0          0.500000   Metro Pizza
# 52037  0x808fb57e5ffcf77f:0xdeb76c221475bdf0          0.568182   Metro Pizza
# 52038  0x808fb57e5ffcf77f:0xdeb76c221475bdf0          0.000000   Metro Pizza
#
#                      direccion       ciudad codigo_postal_cod_ciudad  \
# 0            761 S Vermont Ave  Los Angeles                 CA 90005
# 1            761 S Vermont Ave  Los Angeles                 CA 90005
# 2            761 S Vermont Ave  Los Angeles                 CA 90005
# 3            761 S Vermont Ave  Los Angeles                 CA 90005
# 4            761 S Vermont Ave  Los Angeles                 CA 90005
# ...                        ...          ...                      ...
# 52034  5229 Stevens Creek Blvd  Santa Clara                 CA 95051
# 52035  5229 Stevens Creek Blvd  Santa Clara                 CA 95051
# 52036  5229 Stevens Creek Blvd  Santa Clara                 CA 95051
# 52037  5229 Stevens Creek Blvd  Santa Clara                 CA 95051
# 52038  5229 Stevens Creek Blvd  Santa Clara                 CA 95051
#
#       codigo_ciudad codigo_postal   latitude   longitude             category  \
# 0                CA         90005  34.058092 -118.292130  [Korean restaurant]
# 1                CA         90005  34.058092 -118.292130  [Korean restaurant]
# 2                CA         90005  34.058092 -118.292130  [Korean restaurant]
# 3                CA         90005  34.058092 -118.292130  [Korean restaurant]
# 4                CA         90005  34.058092 -118.292130  [Korean restaurant]
# ...             ...           ...        ...         ...                  ...
# 52034            CA         95051  37.324017 -121.994308   [Pizza restaurant]
# 52035            CA         95051  37.324017 -121.994308   [Pizza restaurant]
# 52036            CA         95051  37.324017 -121.994308   [Pizza restaurant]
# 52037            CA         95051  37.324017 -121.994308   [Pizza restaurant]
# 52038            CA         95051  37.324017 -121.994308   [Pizza restaurant]
#
#        avg_rating  num_of_reviews price  \
# 0             4.4              18  None
# 1             4.4              18  None
# 2             4.4              18  None
# 3             4.4              18  None
# 4             4.4              18  None
# ...           ...             ...   ...
# 52034         4.6              17  None
# 52035         4.6              17  None
# 52036         4.6              17  None
# 52037         4.6              17  None
# 52038         4.6              17  None
#
#                                                     MISC
# 0      {'Service options': ['Takeout', 'Dine-in', 'De...
# 1      {'Service options': ['Takeout', 'Dine-in', 'De...
# 2      {'Service options': ['Takeout', 'Dine-in', 'De...
# 3      {'Service options': ['Takeout', 'Dine-in', 'De...
# 4      {'Service options': ['Takeout', 'Dine-in', 'De...
# ...                                                  ...
# 52034  {'Service options': ['Outdoor seating', 'Deliv...
# 52035  {'Service options': ['Outdoor seating', 'Deliv...
# 52036  {'Service options': ['Outdoor seating', 'Deliv...
# 52037  {'Service options': ['Outdoor seating', 'Deliv...
# 52038  {'Service options': ['Outdoor seating', 'Deliv...
#
# [52039 rows x 20 columns]

# %% [markdown]
# ### Gráfico de los 20 restaurants con más reviews

# %%
local_comment_counts = merged_df['nombre_local'].value_counts().reset_index()
local_comment_counts.columns = ['nombre_local', 'num_of_reviews']

# Seleccionar los 20 locales con más comentarios
top_locals = local_comment_counts.head(20)

# Mostrar el ranking
print(top_locals)
# Out:
#                                nombre_local  num_of_reviews
# 0                                 Tom's Jr.            1944
# 1                 Popeyes Louisiana Kitchen            1667
# 2                                    Subway            1397
# 3                                  Eatalian            1370
# 4                                McDonald's            1327
# 5                                 El Torito            1041
# 6                             King Taco # 1             993
# 7                                  Catch LA             988
# 8                          Bowlero Torrance             811
# 9                                  Chacho's             767
# 10                           Domino's Pizza             754
# 11  California Pizza Kitchen at Santa Clara             600
# 12                             King Eggroll             555
# 13                             Ruby's Diner             518
# 14                           Crimson Coward             500
# 15                                Starbucks             500
# 16                   Puerto Azul Restaurant             465
# 17                              Myzen Ramen             451
# 18                    El Caserio Restaurant             422
# 19                        Taiwan Restaurant             336

# %%
plt.figure(figsize=(12, 8))
plt.bar(top_locals['nombre_local'], top_locals['num_of_reviews'], color='skyblue')

plt.xlabel('Nombre del Local')
plt.ylabel('Número de Comentarios')
plt.title('Top 20 Locales con Más Comentarios')
plt.xticks(rotation=90)  

plt.tight_layout()
plt.show()

# %%
local_comment_counts = merged_df.groupby('nombre_local').agg(
    num_of_reviews=('nombre_local', 'count'),
    avg_rating=('avg_rating', 'mean')
).reset_index()

top_locals = local_comment_counts.sort_values(by='num_of_reviews', ascending=False).head(20)

plt.figure(figsize=(14, 8))
plt.bar(top_locals['nombre_local'], top_locals['avg_rating'], color='skyblue')

plt.xlabel('Nombre del Local')
plt.ylabel('Promedio de Calificación')
plt.title('Top 20 Locales y su Promedio de Calificación')
plt.xticks(rotation=90)  

plt.tight_layout()
plt.show()

# %%
merged_df.to_csv(r"C:\Users\jessi\Desktop\Proyecto Final Henry\merged_df.csv", index=False)
