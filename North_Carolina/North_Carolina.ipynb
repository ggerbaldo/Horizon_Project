# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from textblob import TextBlob
from scipy import stats
import folium as folium
from IPython.display import display
import geopandas as gpd
from shapely.geometry import Point
import contextily as ctx

# %% [markdown]
# ### Lectura del archivo North_Carolina.json

# %%
df= pd.read_json(r"C:\Users\jessi\Desktop\Horizon_Project\North_Carolina\North_Carolina.json",lines=True)

# %%
df.head()
# Out:
#         user_id           name  rating  \
# 0  1.021501e+20  Justin Lowder       1
# 1  1.053475e+20      Ken Chris       1
# 2  1.169910e+20   Stuart Smith       5
# 3  1.088588e+20  Dimja Shireen       5
# 4  1.160022e+20     Tal Kelsey       2
#
#                                                 text  resp  \
# 0  Stopped coming here at night because been aske...  None
# 1  Bathroom was filthy as usual and neither dispe...  None
# 2  This is a very nice gas station. The parking l...  None
# 3  I had to run a few errands in Charlotte about ...  None
# 4  Every single time I have been to this QT, panh...  None
#
#                                  gmap_id
# 0  0x88569f142fa6ea25:0x2bb64edf44b067f4
# 1  0x88569f142fa6ea25:0x2bb64edf44b067f4
# 2  0x88569f142fa6ea25:0x2bb64edf44b067f4
# 3  0x88569f142fa6ea25:0x2bb64edf44b067f4
# 4  0x88569f142fa6ea25:0x2bb64edf44b067f4

# %% [markdown]
# ### Lectura del archivo "df_gastronomico_ciudades.json "

# %%
df2=pd.read_json(r"C:\Users\jessi\Desktop\Horizon_Project\Washington\df_gastronomico_ciudades.json",lines=True)

# %%
df2.head()
# Out:
#                            nombre_local                     direccion  \
# 0  Creole Orleans Catering & Food Truck  2841 Greenbriar Pkwy SW N317
# 1               Biswas Grocery and Cafe            2853 Buford Hwy NE
# 2                           Noodle Cafe        233 Peachtree St # B70
# 3  Creole Orleans Catering & Food Truck  2841 Greenbriar Pkwy SW N317
# 4               Biswas Grocery and Cafe            2853 Buford Hwy NE
#
#     ciudad codigo_postal_cod_ciudad codigo_ciudad codigo_postal  \
# 0  Atlanta                 GA 30331            GA         30331
# 1  Atlanta                 GA 30329            GA         30329
# 2  Atlanta                 GA 30303            GA         30303
# 3  Atlanta                 GA 30331            GA         30331
# 4  Atlanta                 GA 30329            GA         30329
#
#                                  gmap_id   latitude  longitude  \
# 0  0x88f503d71429c049:0xef40e07a5479b1c2  33.689032 -84.495097
# 1  0x88f507f3e1cde31d:0x1bcd2bb2f0555399  33.831454 -84.341647
# 2  0x88f5047831dfc86d:0x985e3a6645f5ca4f  33.760404 -84.386319
# 3  0x88f503d71429c049:0xef40e07a5479b1c2  33.689032 -84.495097
# 4  0x88f507f3e1cde31d:0x1bcd2bb2f0555399  33.831454 -84.341647
#
#                                             category  avg_rating  \
# 0  [Creole restaurant, Caribbean restaurant, Cate...         4.7
# 1  [Organic food store, Convenience store, Phone ...         4.7
# 2                      [Thai restaurant, Restaurant]         4.2
# 3  [Creole restaurant, Caribbean restaurant, Cate...         4.7
# 4  [Organic food store, Convenience store, Phone ...         4.7
#
#    num_of_reviews price                                               MISC
# 0              31  None  {'Service options': ['Delivery', 'Takeout', 'D...
# 1              25  None  {'Service options': ['Delivery', 'In-store sho...
# 2              35  None  {'Service options': ['Takeout', 'Dine-in', 'De...
# 3              31  None  {'Service options': ['Delivery', 'Takeout', 'D...
# 4              25  None  {'Service options': ['Delivery', 'In-store sho...

# %% [markdown]
# ### Informacion General

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16130 entries, 0 to 16129
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   user_id  16130 non-null  float64
#  1   name     16130 non-null  object
#  2   rating   16130 non-null  int64
#  3   text     10008 non-null  object
#  4   resp     1831 non-null   object
#  5   gmap_id  16130 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 756.2+ KB
# None

# %%
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18037 entries, 0 to 18036
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   nombre_local              18037 non-null  object
#  1   direccion                 18037 non-null  object
#  2   ciudad                    18037 non-null  object
#  3   codigo_postal_cod_ciudad  18037 non-null  object
#  4   codigo_ciudad             18037 non-null  object
#  5   codigo_postal             18037 non-null  object
#  6   gmap_id                   18037 non-null  object
#  7   latitude                  18037 non-null  float64
#  8   longitude                 18037 non-null  float64
#  9   category                  18037 non-null  object
#  10  avg_rating                18037 non-null  float64
#  11  num_of_reviews            18037 non-null  int64
#  12  price                     8690 non-null   object
#  13  MISC                      17614 non-null  object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 1.9+ MB
# None

# %% [markdown]
# ### Descripción de los dataframe

# %%
df['rating'].describe()
# Out:
# count    16130.000000
# mean         4.126224
# std          1.255875
# min          1.000000
# 25%          4.000000
# 50%          5.000000
# 75%          5.000000
# max          5.000000
# Name: rating, dtype: float64

# %%
df2.describe()
# Out:
#            latitude     longitude    avg_rating  num_of_reviews
# count  18037.000000  18037.000000  18037.000000    18037.000000
# mean      38.290007    -92.404179      4.137573       70.622276
# std        4.948144     18.621202      0.575608      143.090909
# min       25.993710   -122.805295      1.000000        1.000000
# 25%       34.055071   -118.186637      3.900000       17.000000
# 50%       39.943207    -86.808270      4.200000       38.000000
# 75%       40.831310    -74.145373      4.500000       78.000000
# max       47.682747    -71.145040      5.000000     5321.000000

# %% [markdown]
# ### Análisis de Datos Nulos

# %%
print(df.isnull().sum())
# Out:
# user_id        0
# name           0
# rating         0
# text        6122
# resp       14299
# gmap_id        0
# dtype: int64

# %%
print(df2.isnull().sum())
# Out:
# nombre_local                   0
# direccion                      0
# ciudad                         0
# codigo_postal_cod_ciudad       0
# codigo_ciudad                  0
# codigo_postal                  0
# gmap_id                        0
# latitude                       0
# longitude                      0
# category                       0
# avg_rating                     0
# num_of_reviews                 0
# price                       9347
# MISC                         423
# dtype: int64

# %% [markdown]
# ### Outliers

# %%
rating = df['rating']

# Calcular el IQR para la columna 'rating'
Q1 = rating.quantile(0.25)
Q3 = rating.quantile(0.75)
IQR = Q3 - Q1

# Identificar outliers usando IQR
outliers_iqr = rating[(rating < (Q1 - 1.5 * IQR)) | (rating > (Q3 + 1.5 * IQR))]
print("Outliers en la columna 'rating' usando IQR:")
print(outliers_iqr)

# Calcular Z-score para la columna 'rating'
z_scores = stats.zscore(rating)
abs_z_scores = abs(z_scores)

# Identificar outliers con Z-score mayor que 3
outliers_z = rating[abs_z_scores > 3]
print("Outliers en la columna 'rating' usando Z-score:")
print(outliers_z)

# Graficar el boxplot para 'rating'
plt.figure(figsize=(10, 6))
sns.boxplot(x=rating)
plt.title('Boxplot de rating')
plt.show()
# Out:
# Outliers en la columna 'rating' usando IQR:
# 0        1
# 1        1
# 4        2
# 6        2
# 7        2
#         ..
# 16058    2
# 16061    2
# 16073    1
# 16120    2
# 16129    1
# Name: rating, Length: 2048, dtype: int64
# Outliers en la columna 'rating' usando Z-score:
# Series([], Name: rating, dtype: int64)

# %%
columns_to_check = ['avg_rating']

Q1 = df2[columns_to_check].quantile(0.25)
Q3 = df2[columns_to_check].quantile(0.75)
IQR = Q3 - Q1

outliers_iqr = df2[(df2[columns_to_check] < (Q1 - 1.5 * IQR)) | (df2[columns_to_check] > (Q3 + 1.5 * IQR))]

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.boxplot(x=df2['avg_rating'])
plt.title('Outliers de Average Rating')



plt.show()

# %%
num_of_reviews = df2['num_of_reviews']

Q1 = num_of_reviews.quantile(0.25)
Q3 = num_of_reviews.quantile(0.75)
IQR = Q3 - Q1

outliers_iqr = num_of_reviews[(num_of_reviews < (Q1 - 1.5 * IQR)) | (num_of_reviews > (Q3 + 1.5 * IQR))]
print("Outliers en la columna 'num_of_reviews' usando IQR:")
print(outliers_iqr)

z_scores = stats.zscore(num_of_reviews)
abs_z_scores = abs(z_scores)

outliers_z = num_of_reviews[abs_z_scores > 3]
print("Outliers en la columna 'num_of_reviews' usando Z-score:")
print(outliers_z)

plt.figure(figsize=(10, 6))
sns.boxplot(x=num_of_reviews)
plt.title('Outliers Número de Reviews')
plt.show()
# Out:
# Outliers en la columna 'num_of_reviews' usando IQR:
# 124      798
# 206      178
# 217      496
# 224      214
# 229      768
#         ...
# 18019    238
# 18024    244
# 18027    292
# 18029    178
# 18031    238
# Name: num_of_reviews, Length: 1371, dtype: int64
# Outliers en la columna 'num_of_reviews' usando Z-score:
# 124       798
# 229       768
# 233      1018
# 237      3128
# 238      1373
#          ...
# 17884     798
# 17890    1108
# 17892    1208
# 17893    1351
# 17901     624
# Name: num_of_reviews, Length: 171, dtype: int64

# %% [markdown]
# ### Histogramas de distribución

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['rating'], bins=10)
plt.title('Distribución de Raiting DF')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
avg_rating = df2['avg_rating']
num_of_reviews = df2['num_of_reviews']

plt.figure(figsize=(14, 12))

plt.subplot(2, 2, 1)
sns.histplot(avg_rating, bins=30, kde=False)
plt.title('Histograma de puntaje promedio')
plt.xlabel('avg_rating')
plt.ylabel('Frecuencia')

plt.subplot(2, 2, 3)
sns.histplot(num_of_reviews, bins=20, kde=False)
plt.title('Histograma de número de reviews')
plt.xlabel('num_of_reviews')
plt.ylabel('Frecuencia')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Análisis de sentimientos

# %%
df['text'] = df['text'].fillna('')

# %%
def get_sentiment(text):
    return TextBlob(text).sentiment.polarity

df['review_sentiment'] = df['text'].apply(get_sentiment)

print(df[['text', 'review_sentiment']].head())
# Out:
#                                                 text  review_sentiment
# 0  Stopped coming here at night because been aske...          0.183333
# 1  Bathroom was filthy as usual and neither dispe...         -0.142857
# 2  This is a very nice gas station. The parking l...          0.490000
# 3  I had to run a few errands in Charlotte about ...          0.174258
# 4  Every single time I have been to this QT, panh...          0.125714

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.histplot(df['review_sentiment'], bins=10, kde=True)
plt.title('Distribución de Sentimientos en Reviews')
plt.xlabel('Sentimiento')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ### Unión de datasets

# %%
merged_df = pd.merge(df, df2, on='gmap_id', how='inner')

# %%
merged_df
# Out:
#             user_id               name  rating  \
# 0      1.021501e+20      Justin Lowder       1
# 1      1.021501e+20      Justin Lowder       1
# 2      1.053475e+20          Ken Chris       1
# 3      1.053475e+20          Ken Chris       1
# 4      1.169910e+20       Stuart Smith       5
# ...             ...                ...     ...
# 16181  1.078603e+20  Richard Dougherty       5
# 16182  1.176411e+20         Ross Peele       5
# 16183  1.104843e+20         Donna Belk       5
# 16184  1.119329e+20         K Matthews       5
# 16185  1.177204e+20   Tinabrooks Davis       1
#
#                                                     text  \
# 0      Stopped coming here at night because been aske...
# 1      Stopped coming here at night because been aske...
# 2      Bathroom was filthy as usual and neither dispe...
# 3      Bathroom was filthy as usual and neither dispe...
# 4      This is a very nice gas station. The parking l...
# ...                                                  ...
# 16181
# 16182
# 16183
# 16184
# 16185
#
#                                                     resp  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 16181                                               None
# 16182                                               None
# 16183                                               None
# 16184                                               None
# 16185  {'time': 1580248856441, 'text': 'No fake revie...
#
#                                      gmap_id  review_sentiment  \
# 0      0x88569f142fa6ea25:0x2bb64edf44b067f4          0.183333
# 1      0x88569f142fa6ea25:0x2bb64edf44b067f4          0.183333
# 2      0x88569f142fa6ea25:0x2bb64edf44b067f4         -0.142857
# 3      0x88569f142fa6ea25:0x2bb64edf44b067f4         -0.142857
# 4      0x88569f142fa6ea25:0x2bb64edf44b067f4          0.490000
# ...                                      ...               ...
# 16181  0x88569f8d3eae4f35:0xf79da12d54c4cba2          0.000000
# 16182  0x88569f8d3eae4f35:0xf79da12d54c4cba2          0.000000
# 16183  0x88569f8d3eae4f35:0xf79da12d54c4cba2          0.000000
# 16184  0x88569f8d3eae4f35:0xf79da12d54c4cba2          0.000000
# 16185  0x88569f8d3eae4f35:0xf79da12d54c4cba2          0.000000
#
#            nombre_local        direccion     ciudad codigo_postal_cod_ciudad  \
# 0              QuikTrip   116 Clanton Rd  Charlotte                 NC 28217
# 1              QuikTrip   116 Clanton Rd  Charlotte                 NC 28217
# 2              QuikTrip   116 Clanton Rd  Charlotte                 NC 28217
# 3              QuikTrip   116 Clanton Rd  Charlotte                 NC 28217
# 4              QuikTrip   116 Clanton Rd  Charlotte                 NC 28217
# ...                 ...              ...        ...                      ...
# 16181  Queen City Wings  607 Baldwin Ave  Charlotte                 NC 28204
# 16182  Queen City Wings  607 Baldwin Ave  Charlotte                 NC 28204
# 16183  Queen City Wings  607 Baldwin Ave  Charlotte                 NC 28204
# 16184  Queen City Wings  607 Baldwin Ave  Charlotte                 NC 28204
# 16185  Queen City Wings  607 Baldwin Ave  Charlotte                 NC 28204
#
#       codigo_ciudad codigo_postal   latitude  longitude  \
# 0                NC         28217  35.195087 -80.873683
# 1                NC         28217  35.195087 -80.873683
# 2                NC         28217  35.195087 -80.873683
# 3                NC         28217  35.195087 -80.873683
# 4                NC         28217  35.195087 -80.873683
# ...             ...           ...        ...        ...
# 16181            NC         28204  35.208817 -80.833271
# 16182            NC         28204  35.208817 -80.833271
# 16183            NC         28204  35.208817 -80.833271
# 16184            NC         28204  35.208817 -80.833271
# 16185            NC         28204  35.208817 -80.833271
#
#                                                 category  avg_rating  \
# 0      [Gas station, Beer store, Breakfast restaurant...         3.4
# 1      [Gas station, Beer store, Breakfast restaurant...         3.4
# 2      [Gas station, Beer store, Breakfast restaurant...         3.4
# 3      [Gas station, Beer store, Breakfast restaurant...         3.4
# 4      [Gas station, Beer store, Breakfast restaurant...         3.4
# ...                                                  ...         ...
# 16181                         [Chicken wings restaurant]         4.7
# 16182                         [Chicken wings restaurant]         4.7
# 16183                         [Chicken wings restaurant]         4.7
# 16184                         [Chicken wings restaurant]         4.7
# 16185                         [Chicken wings restaurant]         4.7
#
#        num_of_reviews price                                               MISC
# 0                  34     $  {'Accessibility': ['Wheelchair accessible entr...
# 1                  34     $  {'Accessibility': ['Wheelchair accessible entr...
# 2                  34     $  {'Accessibility': ['Wheelchair accessible entr...
# 3                  34     $  {'Accessibility': ['Wheelchair accessible entr...
# 4                  34     $  {'Accessibility': ['Wheelchair accessible entr...
# ...               ...   ...                                                ...
# 16181             107     $  {'Service options': ['Delivery', 'Takeout'], '...
# 16182             107     $  {'Service options': ['Delivery', 'Takeout'], '...
# 16183             107     $  {'Service options': ['Delivery', 'Takeout'], '...
# 16184             107     $  {'Service options': ['Delivery', 'Takeout'], '...
# 16185             107     $  {'Service options': ['Delivery', 'Takeout'], '...
#
# [16186 rows x 20 columns]

# %% [markdown]
# ### Gráfico de los 20 restaurants con más reviews

# %%
local_comment_counts = merged_df['nombre_local'].value_counts().reset_index()
local_comment_counts.columns = ['nombre_local', 'num_of_reviews']

# Seleccionar los 20 locales con más comentarios
top_locals = local_comment_counts.head(20)

# Mostrar el ranking
print(top_locals)
# Out:
#                               nombre_local  num_of_reviews
# 0                Cheddar's Scratch Kitchen            1906
# 1                                Taco Bell             962
# 2                         Chicken Box Cafe             931
# 3                                   Subway             874
# 4                              Burger King             357
# 5                     Cuzcatlan Restaurant             202
# 6                 Providence Road Sundries             194
# 7                                Pizza Hut             191
# 8                               Oh My Soul             186
# 9                       QDOBA Mexican Eats             175
# 10                       Bruegger's Bagels             169
# 11                                QuikTrip             165
# 12                           The UPS Store             157
# 13                      Zio Casual Italian             155
# 14  Supermercado y Restaurante El Mariachi             139
# 15                          Domino's Pizza             135
# 16                    Barreled at the Lift             135
# 17                          Caribou Coffee             132
# 18                           Smoothie King             131
# 19                 Chicken King Restaurant             130

# %%
plt.figure(figsize=(12, 8))
plt.bar(top_locals['nombre_local'], top_locals['num_of_reviews'], color='skyblue')

plt.xlabel('Nombre del Local')
plt.ylabel('Número de Comentarios')
plt.title('Top 20 Locales con Más Comentarios')
plt.xticks(rotation=90)  

plt.tight_layout()
plt.show()

# %%
local_comment_counts = merged_df.groupby('nombre_local').agg(
    num_of_reviews=('nombre_local', 'count'),
    avg_rating=('avg_rating', 'mean')
).reset_index()

top_locals = local_comment_counts.sort_values(by='num_of_reviews', ascending=False).head(20)

plt.figure(figsize=(14, 8))
plt.bar(top_locals['nombre_local'], top_locals['avg_rating'], color='skyblue')

plt.xlabel('Nombre del Local')
plt.ylabel('Promedio de Calificación')
plt.title('Top 20 Locales y su Promedio de Calificación')
plt.xticks(rotation=90)  

plt.tight_layout()
plt.show()

# %%
merged_df.to_csv(r"C:\Users\jessi\Desktop\Proyecto Final Henry\north_carolina.csv", index=False)
