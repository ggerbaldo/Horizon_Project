# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from textblob import TextBlob
from scipy import stats
import folium as folium
from IPython.display import display
import geopandas as gpd
from shapely.geometry import Point
import contextily as ctx

# %% [markdown]
# ### Lectura del archivo Utah.json

# %%
df= pd.read_json(r"C:\Users\jessi\Desktop\Horizon_Project\Utah\Utah.json",lines=True)

# %%
df.head()
# Out:
#         user_id           name  rating  \
# 0  1.017301e+20          Grant       5
# 1  1.176280e+20  Randy Sartori       3
# 2  1.108786e+20     Rob Haynes       4
# 3  1.140441e+20    David Kraft       5
# 4  1.096292e+20    Waylon Robb       5
#
#                                                 text  resp  \
# 0  This place is a great little fast food joint. ...  None
# 1  Nice neighborhood eatery. Similar to Arctic Ci...  None
# 2  The burgers are bland, but the service and mil...  None
# 3  The place looks run down and the menu, with al...  None
# 4  Well in my opinion this little burger joint is...  None
#
#                                  gmap_id
# 0  0x875289613c18358f:0x7aaf75f9f2b3aaf1
# 1  0x875289613c18358f:0x7aaf75f9f2b3aaf1
# 2  0x875289613c18358f:0x7aaf75f9f2b3aaf1
# 3  0x875289613c18358f:0x7aaf75f9f2b3aaf1
# 4  0x875289613c18358f:0x7aaf75f9f2b3aaf1

# %% [markdown]
# ### Lectura del archivo "df_gastronomico_ciudades.json "

# %%
df2=pd.read_json(r"C:\Users\jessi\Desktop\Horizon_Project\Washington\df_gastronomico_ciudades.json",lines=True)

# %%
df2.head()
# Out:
#                            nombre_local                     direccion  \
# 0  Creole Orleans Catering & Food Truck  2841 Greenbriar Pkwy SW N317
# 1               Biswas Grocery and Cafe            2853 Buford Hwy NE
# 2                           Noodle Cafe        233 Peachtree St # B70
# 3  Creole Orleans Catering & Food Truck  2841 Greenbriar Pkwy SW N317
# 4               Biswas Grocery and Cafe            2853 Buford Hwy NE
#
#     ciudad codigo_postal_cod_ciudad codigo_ciudad codigo_postal  \
# 0  Atlanta                 GA 30331            GA         30331
# 1  Atlanta                 GA 30329            GA         30329
# 2  Atlanta                 GA 30303            GA         30303
# 3  Atlanta                 GA 30331            GA         30331
# 4  Atlanta                 GA 30329            GA         30329
#
#                                  gmap_id   latitude  longitude  \
# 0  0x88f503d71429c049:0xef40e07a5479b1c2  33.689032 -84.495097
# 1  0x88f507f3e1cde31d:0x1bcd2bb2f0555399  33.831454 -84.341647
# 2  0x88f5047831dfc86d:0x985e3a6645f5ca4f  33.760404 -84.386319
# 3  0x88f503d71429c049:0xef40e07a5479b1c2  33.689032 -84.495097
# 4  0x88f507f3e1cde31d:0x1bcd2bb2f0555399  33.831454 -84.341647
#
#                                             category  avg_rating  \
# 0  [Creole restaurant, Caribbean restaurant, Cate...         4.7
# 1  [Organic food store, Convenience store, Phone ...         4.7
# 2                      [Thai restaurant, Restaurant]         4.2
# 3  [Creole restaurant, Caribbean restaurant, Cate...         4.7
# 4  [Organic food store, Convenience store, Phone ...         4.7
#
#    num_of_reviews price                                               MISC
# 0              31  None  {'Service options': ['Delivery', 'Takeout', 'D...
# 1              25  None  {'Service options': ['Delivery', 'In-store sho...
# 2              35  None  {'Service options': ['Takeout', 'Dine-in', 'De...
# 3              31  None  {'Service options': ['Delivery', 'Takeout', 'D...
# 4              25  None  {'Service options': ['Delivery', 'In-store sho...

# %% [markdown]
# ### Informacion General

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10783 entries, 0 to 10782
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   user_id  10783 non-null  float64
#  1   name     10783 non-null  object
#  2   rating   10783 non-null  int64
#  3   text     7087 non-null   object
#  4   resp     1782 non-null   object
#  5   gmap_id  10783 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 505.6+ KB
# None

# %%
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18037 entries, 0 to 18036
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   nombre_local              18037 non-null  object
#  1   direccion                 18037 non-null  object
#  2   ciudad                    18037 non-null  object
#  3   codigo_postal_cod_ciudad  18037 non-null  object
#  4   codigo_ciudad             18037 non-null  object
#  5   codigo_postal             18037 non-null  object
#  6   gmap_id                   18037 non-null  object
#  7   latitude                  18037 non-null  float64
#  8   longitude                 18037 non-null  float64
#  9   category                  18037 non-null  object
#  10  avg_rating                18037 non-null  float64
#  11  num_of_reviews            18037 non-null  int64
#  12  price                     8690 non-null   object
#  13  MISC                      17614 non-null  object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 1.9+ MB
# None

# %% [markdown]
# ### Descripción de los dataframe

# %%
df['rating'].describe()
# Out:
# count    10783.000000
# mean         4.006306
# std          1.317926
# min          1.000000
# 25%          3.000000
# 50%          5.000000
# 75%          5.000000
# max          5.000000
# Name: rating, dtype: float64

# %%
df2.describe()
# Out:
#            latitude     longitude    avg_rating  num_of_reviews
# count  18037.000000  18037.000000  18037.000000    18037.000000
# mean      38.290007    -92.404179      4.137573       70.622276
# std        4.948144     18.621202      0.575608      143.090909
# min       25.993710   -122.805295      1.000000        1.000000
# 25%       34.055071   -118.186637      3.900000       17.000000
# 50%       39.943207    -86.808270      4.200000       38.000000
# 75%       40.831310    -74.145373      4.500000       78.000000
# max       47.682747    -71.145040      5.000000     5321.000000

# %% [markdown]
# ### Análisis de Datos Nulos

# %%
print(df.isnull().sum())
# Out:
# user_id       0
# name          0
# rating        0
# text       3696
# resp       9001
# gmap_id       0
# dtype: int64

# %%
print(df2.isnull().sum())
# Out:
# nombre_local                   0
# direccion                      0
# ciudad                         0
# codigo_postal_cod_ciudad       0
# codigo_ciudad                  0
# codigo_postal                  0
# gmap_id                        0
# latitude                       0
# longitude                      0
# category                       0
# avg_rating                     0
# num_of_reviews                 0
# price                       9347
# MISC                         423
# dtype: int64

# %% [markdown]
# ### Outliers

# %%
rating = df['rating']

# Calcular el IQR para la columna 'rating'
Q1 = rating.quantile(0.25)
Q3 = rating.quantile(0.75)
IQR = Q3 - Q1

# Identificar outliers usando IQR
outliers_iqr = rating[(rating < (Q1 - 1.5 * IQR)) | (rating > (Q3 + 1.5 * IQR))]
print("Outliers en la columna 'rating' usando IQR:")
print(outliers_iqr)

# Calcular Z-score para la columna 'rating'
z_scores = stats.zscore(rating)
abs_z_scores = abs(z_scores)

# Identificar outliers con Z-score mayor que 3
outliers_z = rating[abs_z_scores > 3]
print("Outliers en la columna 'rating' usando Z-score:")
print(outliers_z)

# Graficar el boxplot para 'rating'
plt.figure(figsize=(10, 6))
sns.boxplot(x=rating)
plt.title('Boxplot de rating')
plt.show()
# Out:
# Outliers en la columna 'rating' usando IQR:
# Series([], Name: rating, dtype: int64)
# Outliers en la columna 'rating' usando Z-score:
# Series([], Name: rating, dtype: int64)

# %%
columns_to_check = ['avg_rating']

Q1 = df2[columns_to_check].quantile(0.25)
Q3 = df2[columns_to_check].quantile(0.75)
IQR = Q3 - Q1

outliers_iqr = df2[(df2[columns_to_check] < (Q1 - 1.5 * IQR)) | (df2[columns_to_check] > (Q3 + 1.5 * IQR))]

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.boxplot(x=df2['avg_rating'])
plt.title('Outliers de Average Rating')



plt.show()

# %%
num_of_reviews = df2['num_of_reviews']

Q1 = num_of_reviews.quantile(0.25)
Q3 = num_of_reviews.quantile(0.75)
IQR = Q3 - Q1

outliers_iqr = num_of_reviews[(num_of_reviews < (Q1 - 1.5 * IQR)) | (num_of_reviews > (Q3 + 1.5 * IQR))]
print("Outliers en la columna 'num_of_reviews' usando IQR:")
print(outliers_iqr)

z_scores = stats.zscore(num_of_reviews)
abs_z_scores = abs(z_scores)

outliers_z = num_of_reviews[abs_z_scores > 3]
print("Outliers en la columna 'num_of_reviews' usando Z-score:")
print(outliers_z)

plt.figure(figsize=(10, 6))
sns.boxplot(x=num_of_reviews)
plt.title('Outliers Número de Reviews')
plt.show()
# Out:
# Outliers en la columna 'num_of_reviews' usando IQR:
# 124      798
# 206      178
# 217      496
# 224      214
# 229      768
#         ...
# 18019    238
# 18024    244
# 18027    292
# 18029    178
# 18031    238
# Name: num_of_reviews, Length: 1371, dtype: int64
# Outliers en la columna 'num_of_reviews' usando Z-score:
# 124       798
# 229       768
# 233      1018
# 237      3128
# 238      1373
#          ...
# 17884     798
# 17890    1108
# 17892    1208
# 17893    1351
# 17901     624
# Name: num_of_reviews, Length: 171, dtype: int64

# %% [markdown]
# ### Histogramas de distribución

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['rating'], bins=10)
plt.title('Distribución de Raiting DF')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
avg_rating = df2['avg_rating']
num_of_reviews = df2['num_of_reviews']

plt.figure(figsize=(14, 12))

plt.subplot(2, 2, 1)
sns.histplot(avg_rating, bins=30, kde=False)
plt.title('Histograma de puntaje promedio')
plt.xlabel('avg_rating')
plt.ylabel('Frecuencia')

plt.subplot(2, 2, 3)
sns.histplot(num_of_reviews, bins=20, kde=False)
plt.title('Histograma de número de reviews')
plt.xlabel('num_of_reviews')
plt.ylabel('Frecuencia')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Análisis de sentimientos

# %%
df['text'] = df['text'].fillna('')

# %%
def get_sentiment(text):
    return TextBlob(text).sentiment.polarity

df['review_sentiment'] = df['text'].apply(get_sentiment)

print(df[['text', 'review_sentiment']].head())
# Out:
#                                                 text  review_sentiment
# 0  This place is a great little fast food joint. ...          0.286250
# 1  Nice neighborhood eatery. Similar to Arctic Ci...          0.366667
# 2  The burgers are bland, but the service and mil...          0.295833
# 3  The place looks run down and the menu, with al...          0.234491
# 4  Well in my opinion this little burger joint is...          0.306510

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.histplot(df['review_sentiment'], bins=10, kde=True)
plt.title('Distribución de Sentimientos en Reviews')
plt.xlabel('Sentimiento')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ### Unión de datasets

# %%
merged_df = pd.merge(df, df2, on='gmap_id', how='inner')

# %%
merged_df
# Out:
#             user_id             name  rating  \
# 0      1.017301e+20            Grant       5
# 1      1.017301e+20            Grant       5
# 2      1.176280e+20    Randy Sartori       3
# 3      1.176280e+20    Randy Sartori       3
# 4      1.108786e+20       Rob Haynes       4
# ...             ...              ...     ...
# 10820  1.038601e+20  Annabella Patty       5
# 10821  1.030288e+20  Malynda Daniels       4
# 10822  1.153592e+20    Janette Nolan       3
# 10823  1.025372e+20  Brigitte Wisely       5
# 10824  1.006658e+20         Thiese C       5
#
#                                                     text  resp  \
# 0      This place is a great little fast food joint. ...  None
# 1      This place is a great little fast food joint. ...  None
# 2      Nice neighborhood eatery. Similar to Arctic Ci...  None
# 3      Nice neighborhood eatery. Similar to Arctic Ci...  None
# 4      The burgers are bland, but the service and mil...  None
# ...                                                  ...   ...
# 10820                                                     None
# 10821                                                     None
# 10822                                                     None
# 10823                                                     None
# 10824                                                     None
#
#                                      gmap_id  review_sentiment  \
# 0      0x875289613c18358f:0x7aaf75f9f2b3aaf1          0.286250
# 1      0x875289613c18358f:0x7aaf75f9f2b3aaf1          0.286250
# 2      0x875289613c18358f:0x7aaf75f9f2b3aaf1          0.366667
# 3      0x875289613c18358f:0x7aaf75f9f2b3aaf1          0.366667
# 4      0x875289613c18358f:0x7aaf75f9f2b3aaf1          0.295833
# ...                                      ...               ...
# 10820  0x8752863ba23729a1:0xf37bdb3b2dbfa72d          0.000000
# 10821  0x8752863ba23729a1:0xf37bdb3b2dbfa72d          0.000000
# 10822  0x8752863ba23729a1:0xf37bdb3b2dbfa72d          0.000000
# 10823  0x8752863ba23729a1:0xf37bdb3b2dbfa72d          0.000000
# 10824  0x8752863ba23729a1:0xf37bdb3b2dbfa72d          0.000000
#
#          nombre_local           direccion        ciudad  \
# 0          M&C BURGER      57 W Center St       Midvale
# 1          M&C BURGER      57 W Center St       Midvale
# 2          M&C BURGER      57 W Center St       Midvale
# 3          M&C BURGER      57 W Center St       Midvale
# 4          M&C BURGER      57 W Center St       Midvale
# ...               ...                 ...           ...
# 10820  Domino's Pizza  1067 S Jordan Pkwy  South Jordan
# 10821  Domino's Pizza  1067 S Jordan Pkwy  South Jordan
# 10822  Domino's Pizza  1067 S Jordan Pkwy  South Jordan
# 10823  Domino's Pizza  1067 S Jordan Pkwy  South Jordan
# 10824  Domino's Pizza  1067 S Jordan Pkwy  South Jordan
#
#       codigo_postal_cod_ciudad codigo_ciudad codigo_postal   latitude  \
# 0                     UT 84047            UT         84047  40.610737
# 1                     UT 84047            UT         84047  40.610737
# 2                     UT 84047            UT         84047  40.610737
# 3                     UT 84047            UT         84047  40.610737
# 4                     UT 84047            UT         84047  40.610737
# ...                        ...           ...           ...        ...
# 10820                 UT 84095            UT         84095  40.560282
# 10821                 UT 84095            UT         84095  40.560282
# 10822                 UT 84095            UT         84095  40.560282
# 10823                 UT 84095            UT         84095  40.560282
# 10824                 UT 84095            UT         84095  40.560282
#
#         longitude                                           category  \
# 0     -111.893119                             [Fast food restaurant]
# 1     -111.893119                             [Fast food restaurant]
# 2     -111.893119                             [Fast food restaurant]
# 3     -111.893119                             [Fast food restaurant]
# 4     -111.893119                             [Fast food restaurant]
# ...           ...                                                ...
# 10820 -111.920908  [Pizza delivery, Delivery Restaurant, Takeout ...
# 10821 -111.920908  [Pizza delivery, Delivery Restaurant, Takeout ...
# 10822 -111.920908  [Pizza delivery, Delivery Restaurant, Takeout ...
# 10823 -111.920908  [Pizza delivery, Delivery Restaurant, Takeout ...
# 10824 -111.920908  [Pizza delivery, Delivery Restaurant, Takeout ...
#
#        avg_rating  num_of_reviews price  \
# 0             4.6              38  None
# 1             4.6              38  None
# 2             4.6              38  None
# 3             4.6              38  None
# 4             4.6              38  None
# ...           ...             ...   ...
# 10820         4.1             238     $
# 10821         4.1             238     $
# 10822         4.1             238     $
# 10823         4.1             238     $
# 10824         4.1             238     $
#
#                                                     MISC
# 0      {'Service options': ['Delivery', 'Drive-throug...
# 1      {'Service options': ['Delivery', 'Drive-throug...
# 2      {'Service options': ['Delivery', 'Drive-throug...
# 3      {'Service options': ['Delivery', 'Drive-throug...
# 4      {'Service options': ['Delivery', 'Drive-throug...
# ...                                                  ...
# 10820  {'Service options': ['Curbside pickup', 'No-co...
# 10821  {'Service options': ['Curbside pickup', 'No-co...
# 10822  {'Service options': ['Curbside pickup', 'No-co...
# 10823  {'Service options': ['Curbside pickup', 'No-co...
# 10824  {'Service options': ['Curbside pickup', 'No-co...
#
# [10825 rows x 20 columns]

# %% [markdown]
# ### Gráfico de los 20 restaurants con más reviews

# %%
local_comment_counts = merged_df['nombre_local'].value_counts().reset_index()
local_comment_counts.columns = ['nombre_local', 'num_of_reviews']

# Seleccionar los 20 locales con más comentarios
top_locals = local_comment_counts.head(20)

# Mostrar el ranking
print(top_locals)
# Out:
#                            nombre_local  num_of_reviews
# 0               Romano's Macaroni Grill            1218
# 1                   Chili's Grill & Bar            1039
# 2                               Sizzler             564
# 3                           Burger King             492
# 4                             Taco Bell             433
# 5                           Dairy Queen             418
# 6                                Subway             408
# 7                             Taco Time             368
# 8        Maverik Adventure's First Stop             364
# 9                             Pizza Hut             330
# 10                        Panda Express             276
# 11                         Zaferan Café             206
# 12                    Tacos El Pariente             206
# 13                        The UPS Store             192
# 14  Papa Murphy's | Take 'N' Bake Pizza             188
# 15                      Tacos El Cuñado             180
# 16                                  KFC             174
# 17                        Side Of Aloha             164
# 18   Mystique Dining at Gardner Village             149
# 19                    Aubergine Kitchen             145

# %%
plt.figure(figsize=(12, 8))
plt.bar(top_locals['nombre_local'], top_locals['num_of_reviews'], color='skyblue')

plt.xlabel('Nombre del Local')
plt.ylabel('Número de Comentarios')
plt.title('Top 20 Locales con Más Comentarios')
plt.xticks(rotation=90)  

plt.tight_layout()
plt.show()

# %%
local_comment_counts = merged_df.groupby('nombre_local').agg(
    num_of_reviews=('nombre_local', 'count'),
    avg_rating=('avg_rating', 'mean')
).reset_index()

top_locals = local_comment_counts.sort_values(by='num_of_reviews', ascending=False).head(20)

plt.figure(figsize=(14, 8))
plt.bar(top_locals['nombre_local'], top_locals['avg_rating'], color='skyblue')

plt.xlabel('Nombre del Local')
plt.ylabel('Promedio de Calificación')
plt.title('Top 20 Locales y su Promedio de Calificación')
plt.xticks(rotation=90)  

plt.tight_layout()
plt.show()

# %%
merged_df.to_csv(r"C:\Users\jessi\Desktop\Proyecto Final Henry\Utah.csv", index=False)
